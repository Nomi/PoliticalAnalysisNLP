# %%
# %%capture
# %run ProjectWebScraping.ipynb

# %%
import sys
# !{sys.executable} -m pip install wordcloud
# !{sys.executable} -m pip install gensim
# Out:
# Requirement already satisfied: wordcloud in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (1.21.4)
# Requirement already satisfied: pillow in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: gensim in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (4.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from gensim) (6.0.0)
# Requirement already satisfied: Cython==0.29.23 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from gensim) (0.29.23)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from gensim) (1.21.4)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from gensim) (1.7.3)
# WARNING: There was an error checking the latest version of pip.

# %%
from nltk import FreqDist
from gensim.corpora.dictionary import Dictionary
from IPython.display import Markdown as md
import matplotlib
import matplotlib.pyplot as plt
from wordcloud import WordCloud

matplotlib.rcParams.update(matplotlib.rcParamsDefault)
plt.rcParams['figure.figsize'] = [15, 5]
# %matplotlib inline

# %%
lemmatized_tokens_list = []
lemmatized_tokens_list.append(lemmatized_tokens_dem_platform_2016)
lemmatized_tokens_list.append(lemmatized_tokens_rep_platform_2016)
lemmatized_tokens_list.append(lemmatized_tokens_dem_debate_2016)
lemmatized_tokens_list.append(lemmatized_tokens_rep_debate_2016)
lemmatized_tokens_list.append(lemmatized_tokens_dem_platform_1980)
lemmatized_tokens_list.append(lemmatized_tokens_rep_platform_1980)
lemmatized_tokens_list.append(lemmatized_tokens_dem_debate_1980)
lemmatized_tokens_list.append(lemmatized_tokens_rep_debate_1980)

# %%
tokens_list = []
tokens_list.append(tokens_dem_platform_2016)
tokens_list.append(tokens_rep_platform_2016)
tokens_list.append(tokens_dem_debate_2016)
tokens_list.append(tokens_rep_debate_2016)
tokens_list.append(tokens_dem_platform_1980)
tokens_list.append(tokens_rep_platform_1980)
tokens_list.append(tokens_dem_debate_1980)
tokens_list.append(tokens_rep_debate_1980)

# %%
nltk.download('averaged_perceptron_tagger')
tagged_dem_platform_2016 = nltk.pos_tag(lemmatized_tokens_dem_platform_2016)
tagged_rep_platform_2016 = nltk.pos_tag(lemmatized_tokens_rep_platform_2016)
tagged_dem_debate_2016 = nltk.pos_tag(lemmatized_tokens_dem_debate_2016)
tagged_rep_debate_2016 = nltk.pos_tag(lemmatized_tokens_rep_debate_2016)
tagged_dem_platform_1980 = nltk.pos_tag(lemmatized_tokens_dem_platform_1980)
tagged_rep_platform_1980 = nltk.pos_tag(lemmatized_tokens_rep_platform_1980)
tagged_dem_debate_1980 = nltk.pos_tag(lemmatized_tokens_dem_debate_1980)
tagged_rep_debate_1980 = nltk.pos_tag(lemmatized_tokens_rep_debate_1980)

tagged_list = []
tagged_list.append(tagged_dem_platform_2016)
tagged_list.append(tagged_rep_platform_2016)
tagged_list.append(tagged_dem_debate_2016)
tagged_list.append(tagged_rep_debate_2016)
tagged_list.append(tagged_dem_platform_1980)
tagged_list.append(tagged_rep_platform_1980)
tagged_list.append(tagged_dem_debate_1980)
tagged_list.append(tagged_rep_debate_1980)

# %%
dict_lemmatized_tokens_list = []
for i in range(len(lemmatized_tokens_list)):
    dict_lemmatized_tokens_list.append(Dictionary([lemmatized_tokens_list[i]]))
    
bow_lemmatized_tokens_list = []
bow_lemmatized_tokens_list_ids = []
bow_lemmatized_tokens_list_counts = []
for i in range(len(lemmatized_tokens_list)):
    bow_lemmatized_tokens_list.append(dict_lemmatized_tokens_list[i].doc2bow(lemmatized_tokens_list[i]))
    bow_lemmatized_tokens_list[i] = sorted(bow_lemmatized_tokens_list[i], key=lambda x: x[1], reverse=True)
    term_ids, counts = zip(*bow_lemmatized_tokens_list[i])
    bow_lemmatized_tokens_list_ids.append(term_ids)
    bow_lemmatized_tokens_list_counts.append(counts)

# %% [markdown]
# ## Most often used words in political platforms and debates

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 20))
plt.gca().invert_yaxis()

fig.tight_layout(pad=13.0)
fig.suptitle('Most often used words in the political platforms by both political parties in 1980 and 2016', fontsize=24, y=0.96)

for item in ([ax[0][0].title, ax[0][0].xaxis.label, ax[0][0].yaxis.label] + ax[0][0].get_xticklabels() + ax[0][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[0][1].title, ax[0][1].xaxis.label, ax[0][1].yaxis.label] + ax[0][1].get_xticklabels() + ax[0][1].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][0].title, ax[1][0].xaxis.label, ax[1][0].yaxis.label] + ax[1][0].get_xticklabels() + ax[1][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][1].title, ax[1][1].xaxis.label, ax[1][1].yaxis.label] + ax[1][1].get_xticklabels() + ax[1][1].get_yticklabels()):
        item.set_fontsize(20)
        
for i in range(4):
    if i == 0:
        ax[0][0].barh([dict_lemmatized_tokens_list[0][id] for id in bow_lemmatized_tokens_list_ids[0][:10]], 
                      bow_lemmatized_tokens_list_counts[0][:10])
        ax[0][0].set_xlabel('Frequency')
        ax[0][0].set_title('Democratic Party Platform 2016')
    if i == 1:
        ax[0][1].barh([dict_lemmatized_tokens_list[1][id] for id in bow_lemmatized_tokens_list_ids[1][:10]], 
                      bow_lemmatized_tokens_list_counts[1][:10])
        ax[0][1].set_xlabel('Frequency')
        ax[0][1].set_title('Republican Party Platform 2016')
    if i == 2:
        ax[1][0].barh([dict_lemmatized_tokens_list[4][id] for id in bow_lemmatized_tokens_list_ids[4][:10]],
                      bow_lemmatized_tokens_list_counts[4][:10])
        ax[1][0].set_xlabel('Frequency')
        ax[1][0].set_title('Democratic Party Platform 1980')
    if i == 3:
        ax[1][1].barh([dict_lemmatized_tokens_list[5][id] for id in bow_lemmatized_tokens_list_ids[5][:10]],
                      bow_lemmatized_tokens_list_counts[5][:10])
        ax[1][1].set_xlabel('Frequency')
        ax[1][1].set_title('Republican Party Platform 1980')
    
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 20))
plt.gca().invert_yaxis()

fig.tight_layout(pad=13.0)
fig.suptitle('Most often used words in the political debates by both political parties in 1980 and 2016', fontsize=20, y=0.96)

for item in ([ax[0][0].title, ax[0][0].xaxis.label, ax[0][0].yaxis.label] + ax[0][0].get_xticklabels() + ax[0][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[0][1].title, ax[0][1].xaxis.label, ax[0][1].yaxis.label] + ax[0][1].get_xticklabels() + ax[0][1].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][0].title, ax[1][0].xaxis.label, ax[1][0].yaxis.label] + ax[1][0].get_xticklabels() + ax[1][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][1].title, ax[1][1].xaxis.label, ax[1][1].yaxis.label] + ax[1][1].get_xticklabels() + ax[1][1].get_yticklabels()):
        item.set_fontsize(20)
        
for i in range(4):
    if i == 0:
        ax[0][0].barh([dict_lemmatized_tokens_list[2][id] for id in bow_lemmatized_tokens_list_ids[2][:10]], 
                      bow_lemmatized_tokens_list_counts[2][:10])
        ax[0][0].set_xlabel('Frequency')
        ax[0][0].set_title('Democratic Party Debate 2016')
    if i == 1:
        ax[0][1].barh([dict_lemmatized_tokens_list[3][id] for id in bow_lemmatized_tokens_list_ids[3][:10]], 
                      bow_lemmatized_tokens_list_counts[3][:10])
        ax[0][1].set_xlabel('Frequency')
        ax[0][1].set_title('Republican Party Debate 2016')
    if i == 2:
        ax[1][0].barh([dict_lemmatized_tokens_list[6][id] for id in bow_lemmatized_tokens_list_ids[6][:10]],
                      bow_lemmatized_tokens_list_counts[6][:10])
        ax[1][0].set_xlabel('Frequency')
        ax[1][0].set_title('Democratic Party Debate 1980')
    if i == 3:
        ax[1][1].barh([dict_lemmatized_tokens_list[7][id] for id in bow_lemmatized_tokens_list_ids[7][:10]],
                      bow_lemmatized_tokens_list_counts[7][:10])
        ax[1][1].set_xlabel('Frequency')
        ax[1][1].set_title('Republican Party Debate 1980')
    
plt.show()

# %% [markdown]
# ## Text richness and diversity

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity_list = []
for i in range(len(tokens_list)):
    lexical_diversity_list.append(round(lexical_diversity(tokens_list[i]), 4))

md('''| Text | Ratio | 
| :- | -: |
| Democratic Party Platform 2016| {} |
| Republican Party Platform 2016| {} |
| Democratic Party Debate 2016| {} |
| Republican Party Debate 2016| {} |
| Democratic Party Platform 1980| {} |
| Republican Party Platform 1980| {} |
| Democratic Party Debate 1980| {} |
| Republican Party Debate 1980| {} |'''.format(lexical_diversity_list[0], lexical_diversity_list[1], 
                                   lexical_diversity_list[2], lexical_diversity_list[3],
                                   lexical_diversity_list[4], lexical_diversity_list[5],
                                   lexical_diversity_list[6], lexical_diversity_list[7]))
# Out:
# | Text | Ratio |
# | :- | -: |
# | Democratic Party Platform 2016| 0.2526 |
# | Republican Party Platform 2016| 0.2633 |
# | Democratic Party Debate 2016| 0.2978 |
# | Republican Party Debate 2016| 0.2284 |
# | Democratic Party Platform 1980| 0.2047 |
# | Republican Party Platform 1980| 0.2374 |
# | Democratic Party Debate 1980| 0.3648 |
# | Republican Party Debate 1980| 0.3488 |

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 15))
fig.suptitle('Length of words used in the party platforms and debates by both political parties in 2016', fontsize=16, y=0.94)
for i in range(4):
    freq_dist = FreqDist(len(char) for char in tokens_list[i])
    freq_list = freq_dist.most_common(10)
    freq_x = []
    freq_y = []
    for j in range(len(freq_list)):
        freq_x.append(freq_list[j][0])
        freq_y.append(freq_list[j][1])   
    if i == 0:
        ax[0][0].bar(freq_x, freq_y)
        ax[0][0].set_xlabel('Length')
        ax[0][0].set_ylabel('Count')
        ax[0][0].set_title('Democratic Party Platform')
    if i == 1:
        ax[0][1].bar(freq_x, freq_y)
        ax[0][1].set_xlabel('Length')
        ax[0][1].set_ylabel('Count')
        ax[0][1].set_title('Republican Party Platform')
    if i == 2:
        ax[1][0].bar(freq_x, freq_y)
        ax[1][0].set_xlabel('Length')
        ax[1][0].set_ylabel('Count')
        ax[1][0].set_title('Democratic Party Debate')
    if i == 3:
        ax[1][1].bar(freq_x, freq_y)
        ax[1][1].set_xlabel('Length')
        ax[1][1].set_ylabel('Count')
        ax[1][1].set_title('Republican Party Debate')
    
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 15))
fig.suptitle('Length of words used in the party platforms and debates by both political parties in 1980', 
             fontsize=16, y=0.94)
for i in range(4):
    freq_dist = FreqDist(len(char) for char in tokens_list[i + 4])
    freq_list = freq_dist.most_common(10)
    freq_x = []
    freq_y = []
    for j in range(len(freq_list)):
        freq_x.append(freq_list[j][0])
        freq_y.append(freq_list[j][1])   
    if i == 0:
        ax[0][0].bar(freq_x, freq_y)
        ax[0][0].set_xlabel('Length')
        ax[0][0].set_ylabel('Count')
        ax[0][0].set_title('Democratic Party Platform')
    if i == 1:
        ax[0][1].bar(freq_x, freq_y)
        ax[0][1].set_xlabel('Length')
        ax[0][1].set_ylabel('Count')
        ax[0][1].set_title('Republican Party Platform')
    if i == 2:
        ax[1][0].bar(freq_x, freq_y)
        ax[1][0].set_xlabel('Length')
        ax[1][0].set_ylabel('Count')
        ax[1][0].set_title('Democratic Party Debate')
    if i == 3:
        ax[1][1].bar(freq_x, freq_y)
        ax[1][1].set_xlabel('Length')
        ax[1][1].set_ylabel('Count')
        ax[1][1].set_title('Republican Party Debate')
    
plt.show()

# %%
count_nouns = []
count_verbs = []
count_adjectives = []
count_rest = []
for i in range(len(tagged_list)):
    counter_nouns = 0
    counter_verbs = 0
    counter_adjectives = 0
    counter_rest = 0
    for j in range(len(tagged_list[i])):
        if tagged_list[i][j][1] == 'NN' or tagged_list[i][j][1] == 'NN' or tagged_list[i][j][1] == 'NNS' or tagged_list[i][j][1] == 'NNPS':
            counter_nouns += 1
        elif tagged_list[i][j][1] == 'VB' or tagged_list[i][j][1] == 'VBG' or tagged_list[i][j][1] == 'VBD' or tagged_list[i][j][1] == 'VBN' or tagged_list[i][j][1] == 'VBP' or tagged_list[i][j][1] == 'VBZ':
            counter_verbs += 1
        elif tagged_list[i][j][1] == 'JJ' or tagged_list[i][j][1] == 'JJR' or tagged_list[i][j][1] == 'JJS':
            counter_adjectives += 1
        else:
            counter_rest += 1
    count_nouns.append(counter_nouns)
    count_verbs.append(counter_verbs)
    count_adjectives.append(counter_adjectives)
    count_rest.append(counter_rest)

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 15))
fig.suptitle('Length of words used in the party platforms and debates by both political parties in 2016', 
             fontsize=16, y=0.94)

for i in range(4): 
    if i == 0:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[0], count_verbs[0], count_adjectives[0], count_rest[0]]
        explode = (0, 0, 0, 0.1)
        ax[0][0].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)
        ax[0][0].axis('equal')
        ax[0][0].set_title('Democratic Party Platform')
    if i == 1:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[1], count_verbs[1], count_adjectives[1], count_rest[1]]
        explode = (0, 0, 0, 0.1)
        ax[0][1].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)
        ax[0][1].axis('equal')
        ax[0][1].set_title('Republican Party Platform')
    if i == 2:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[2], count_verbs[2], count_adjectives[2], count_rest[2]]
        explode = (0, 0, 0, 0.1)
        ax[1][0].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)  
        ax[1][0].axis('equal')
        ax[1][0].set_title('Democratic Party Debate')
    if i == 3:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[3], count_verbs[3], count_adjectives[3], count_rest[3]]
        explode = (0, 0, 0, 0.1)
        ax[1][1].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)
        ax[1][1].axis('equal')
        ax[1][1].set_title('Republican Party Debate')
    
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 15))
fig.suptitle('Length of words used in the party platforms and debates by both political parties in 1980', 
             fontsize=16, y=0.94)

for i in range(4): 
    if i == 0:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[4], count_verbs[4], count_adjectives[4], count_rest[4]]
        explode = (0, 0, 0, 0.1)
        ax[0][0].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)
        ax[0][0].axis('equal')
        ax[0][0].set_title('Democratic Party Platform')
    if i == 1:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[5], count_verbs[5], count_adjectives[5], count_rest[5]]
        explode = (0, 0, 0, 0.1)
        ax[0][1].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)
        ax[0][1].axis('equal')
        ax[0][1].set_title('Republican Party Platform')
    if i == 2:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[6], count_verbs[6], count_adjectives[6], count_rest[6]]
        explode = (0, 0, 0, 0.1)
        ax[1][0].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)  
        ax[1][0].axis('equal')
        ax[1][0].set_title('Democratic Party Debate')
    if i == 3:
        labels = 'Nouns', 'Verbs', 'Adjectives', 'Rest'
        sizes = [count_nouns[7], count_verbs[7], count_adjectives[7], count_rest[7]]
        explode = (0, 0, 0, 0.1)
        ax[1][1].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=45)
        ax[1][1].axis('equal')
        ax[1][1].set_title('Republican Party Debate')
    
plt.show()

# %% [markdown]
# ## Lexical dispersion plots

# %%
nltk.Text(lemmatized_tokens_rep_platform_1980 + lemmatized_tokens_rep_platform_2016).dispersion_plot(['america', 'immigration', 'climate', 'constitution', 'tax', 'minority'])

# %%
nltk.Text(lemmatized_tokens_dem_platform_1980 + lemmatized_tokens_dem_platform_2016).dispersion_plot(['america', 'immigration', 'climate', 'constitution', 'tax', 'minority'])

# %% [markdown]
# ## Topic modeling

# %%
lemmatized_tokens_list_nouns = []
for i in range(len(tagged_list)):
    tmp_list = []
    for j in range(len(tagged_list[i])):
        tmp = tagged_list[i][j][1]
        tmp_word = tagged_list[i][j][0]
        if tmp == 'NN' or tmp == 'NNS' or tmp == 'NNP' or tmp == 'NNPS':
            tmp_list.append(tmp_word)
    lemmatized_tokens_list_nouns.append(tmp_list)

# %%
dict_lemmatized_tokens_list_nouns = []
for i in range(len(lemmatized_tokens_list_nouns)):
    dict_lemmatized_tokens_list_nouns.append(Dictionary([lemmatized_tokens_list_nouns[i]]))
    
bow_lemmatized_tokens_list_nouns = []
bow_lemmatized_tokens_list_ids_nouns = []
bow_lemmatized_tokens_list_counts_nouns = []
for i in range(len(lemmatized_tokens_list_nouns)):
    bow_lemmatized_tokens_list_nouns.append(dict_lemmatized_tokens_list_nouns[i].doc2bow(lemmatized_tokens_list_nouns[i]))
    bow_lemmatized_tokens_list_nouns[i] = sorted(bow_lemmatized_tokens_list_nouns[i], key=lambda x: x[1], reverse=True)
    term_ids, counts = zip(*bow_lemmatized_tokens_list_nouns[i])
    bow_lemmatized_tokens_list_ids_nouns.append(term_ids)
    bow_lemmatized_tokens_list_counts_nouns.append(counts)

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 20))
plt.gca().invert_yaxis()

fig.tight_layout(pad=13.0)
fig.suptitle('Topic modeling of political party platforms', fontsize=20, y=0.96)

for item in ([ax[0][0].title, ax[0][0].xaxis.label, ax[0][0].yaxis.label] + ax[0][0].get_xticklabels() + ax[0][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[0][1].title, ax[0][1].xaxis.label, ax[0][1].yaxis.label] + ax[0][1].get_xticklabels() + ax[0][1].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][0].title, ax[1][0].xaxis.label, ax[1][0].yaxis.label] + ax[1][0].get_xticklabels() + ax[1][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][1].title, ax[1][1].xaxis.label, ax[1][1].yaxis.label] + ax[1][1].get_xticklabels() + ax[1][1].get_yticklabels()):
        item.set_fontsize(20)
        
for i in range(4):
    if i == 0:
        ax[0][0].barh([dict_lemmatized_tokens_list_nouns[0][id] for id in bow_lemmatized_tokens_list_ids_nouns[0][:10]], 
                      bow_lemmatized_tokens_list_counts_nouns[0][:10])
        ax[0][0].set_xlabel('Frequency')
        ax[0][0].set_title('Democratic Party Platform 2016')
    if i == 1:
        ax[0][1].barh([dict_lemmatized_tokens_list_nouns[1][id] for id in bow_lemmatized_tokens_list_ids_nouns[1][:10]], 
                      bow_lemmatized_tokens_list_counts_nouns[1][:10])
        ax[0][1].set_xlabel('Frequency')
        ax[0][1].set_title('Republican Party Platform 2016')
    if i == 2:
        ax[1][0].barh([dict_lemmatized_tokens_list_nouns[4][id] for id in bow_lemmatized_tokens_list_ids_nouns[4][:10]],
                      bow_lemmatized_tokens_list_counts_nouns[4][:10])
        ax[1][0].set_xlabel('Frequency')
        ax[1][0].set_title('Democratic Party Platform 1980')
    if i == 3:
        ax[1][1].barh([dict_lemmatized_tokens_list_nouns[5][id] for id in bow_lemmatized_tokens_list_ids_nouns[5][:10]],
                      bow_lemmatized_tokens_list_counts_nouns[5][:10])
        ax[1][1].set_xlabel('Frequency')
        ax[1][1].set_title('Republican Party Platform 1980')
    
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 20))
plt.gca().invert_yaxis()

fig.tight_layout(pad=12.0)
fig.suptitle('Topic modeling of political party debates', fontsize=20, y=0.96)

for item in ([ax[0][0].title, ax[0][0].xaxis.label, ax[0][0].yaxis.label] + ax[0][0].get_xticklabels() + ax[0][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[0][1].title, ax[0][1].xaxis.label, ax[0][1].yaxis.label] + ax[0][1].get_xticklabels() + ax[0][1].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][0].title, ax[1][0].xaxis.label, ax[1][0].yaxis.label] + ax[1][0].get_xticklabels() + ax[1][0].get_yticklabels()):
        item.set_fontsize(20)
for item in ([ax[1][1].title, ax[1][1].xaxis.label, ax[1][1].yaxis.label] + ax[1][1].get_xticklabels() + ax[1][1].get_yticklabels()):
        item.set_fontsize(20)
        
for i in range(4):
    if i == 0:
        ax[0][0].barh([dict_lemmatized_tokens_list_nouns[2][id] for id in bow_lemmatized_tokens_list_ids_nouns[2][:10]], 
                      bow_lemmatized_tokens_list_counts_nouns[2][:10])
        ax[0][0].set_xlabel('Frequency')
        ax[0][0].set_title('Democratic Party Debate 2016')
    if i == 1:
        ax[0][1].barh([dict_lemmatized_tokens_list_nouns[3][id] for id in bow_lemmatized_tokens_list_ids_nouns[3][:10]], 
                      bow_lemmatized_tokens_list_counts_nouns[3][:10])
        ax[0][1].set_xlabel('Frequency')
        ax[0][1].set_title('Republican Party Debate 2016')
    if i == 2:
        ax[1][0].barh([dict_lemmatized_tokens_list_nouns[6][id] for id in bow_lemmatized_tokens_list_ids_nouns[6][:10]],
                      bow_lemmatized_tokens_list_counts_nouns[6][:10])
        ax[1][0].set_xlabel('Frequency')
        ax[1][0].set_title('Democratic Party Debate 1980')
    if i == 3:
        ax[1][1].barh([dict_lemmatized_tokens_list_nouns[7][id] for id in bow_lemmatized_tokens_list_ids_nouns[7][:10]],
                      bow_lemmatized_tokens_list_counts_nouns[7][:10])
        ax[1][1].set_xlabel('Frequency')
        ax[1][1].set_title('Republican Party Debate 1980')
    
plt.show()

# %% [markdown]
# ## Collocations

# %%
collocations_list = []
for i in range(len(tokens_list)):
    list_of_collocations = []
    for j in range(len(nltk.Text(tokens_dem_platform_2016).collocation_list())):
        collocation = ' '.join(nltk.Text(tokens_list[i]).collocation_list()[j])
        list_of_collocations.append(collocation)
    collocations_list.append(list_of_collocations)

# %%
md('''| Democratic Party Platform 2016 | Republican Party Platform 2016 |  Democratic Party Platform 1980 | Republican Party Platform 1980 |
| :- | -: | :- | -: |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
'''.format(collocations_list[0][0], collocations_list[1][0], collocations_list[4][0], collocations_list[5][0],
          collocations_list[0][1], collocations_list[1][1], collocations_list[4][1], collocations_list[5][1],
          collocations_list[0][2], collocations_list[1][2], collocations_list[4][2], collocations_list[5][2],
          collocations_list[0][3], collocations_list[1][3], collocations_list[4][3], collocations_list[5][3],
          collocations_list[0][4], collocations_list[1][4], collocations_list[4][4], collocations_list[5][4],
          collocations_list[0][5], collocations_list[1][5], collocations_list[4][5], collocations_list[5][5],
          collocations_list[0][6], collocations_list[1][6], collocations_list[4][6], collocations_list[5][6],
          collocations_list[0][7], collocations_list[1][7], collocations_list[4][7], collocations_list[5][7],
          collocations_list[0][8], collocations_list[1][8], collocations_list[4][8], collocations_list[5][8],
          collocations_list[0][9], collocations_list[1][9], collocations_list[4][9], collocations_list[5][9]))
# Out:
# | Democratic Party Platform 2016 | Republican Party Platform 2016 |  Democratic Party Platform 1980 | Republican Party Platform 1980 |
# | :- | -: | :- | -: |
# | <center>united states</center> | <center>united states</center> | <center>united states</center> | <center>united states</center> |
# | <center>health care</center> | <center>middle east</center> | <center>human rights</center> | <center>carter administration</center> |
# | <center>donald trump</center> | <center>national security</center> | <center>four years</center> | <center>soviet union</center> |
# | <center>climate change</center> | <center>farmers ranchers</center> | <center>state local</center> | <center>economic growth</center> |
# | <center>clean energy</center> | <center>private sector</center> | <center>federal government</center> | <center>tax rates</center> |
# | <center>democrats believe</center> | <center>current administration's</center> | <center>middle east</center> | <center>foreign policy</center> |
# | <center>middle class</center> | <center>economic growth</center> | <center>must continue</center> | <center>small business</center> |
# | <center>president obama's</center> | <center>federal government</center> | <center>health care</center> | <center>armed forces</center> |
# | <center>wall street</center> | <center>intellectual property</center> | <center>soviet union</center> | <center>four years</center> |
# | <center>good-paying jobs</center> | <center>rule law</center> | <center>civil rights</center> | <center>health care</center> |

# %%
md('''| Democratic Party Platform 2016 | Republican Party Platform 2016 |  Democratic Party Platform 1980 | Republican Party Platform 1980 |
| :- | -: | :- | -: |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
| <center>{}</center> | <center>{}</center> | <center>{}</center> | <center>{}</center> |
'''.format(collocations_list[2][0], collocations_list[3][0], collocations_list[6][0], collocations_list[7][0],
          collocations_list[2][1], collocations_list[3][1], collocations_list[6][1], collocations_list[7][1],
          collocations_list[2][2], collocations_list[3][2], collocations_list[6][2], collocations_list[7][2],
          collocations_list[2][3], collocations_list[3][3], collocations_list[6][3], collocations_list[7][3],
          collocations_list[2][4], collocations_list[3][4], collocations_list[6][4], collocations_list[7][4],
          collocations_list[2][5], collocations_list[3][5], collocations_list[6][5], collocations_list[7][5],
          collocations_list[2][6], collocations_list[3][6], collocations_list[6][6], collocations_list[7][6],
          collocations_list[2][7], collocations_list[3][7], collocations_list[6][7], collocations_list[7][7],
          collocations_list[2][8], collocations_list[3][8], collocations_list[6][8], collocations_list[7][8],
          collocations_list[2][9], collocations_list[3][9], collocations_list[6][9], collocations_list[7][9]))
# Out:
# | Democratic Party Platform 2016 | Republican Party Platform 2016 |  Democratic Party Platform 1980 | Republican Party Platform 1980 |
# | :- | -: | :- | -: |
# | <center>supreme court</center> | <center>we're going</center> | <center>governor reagan</center> | <center>social security</center> |
# | <center>united states</center> | <center>united states</center> | <center>social security</center> | <center>years ago</center> |
# | <center>we're going</center> | <center>hillary clinton</center> | <center>american people</center> | <center>soviet union</center> |
# | <center>second amendment</center> | <center>inner cities</center> | <center>oval office</center> | <center>united states</center> |
# | <center>we've got</center> | <center>second amendment</center> | <center>tax cut</center> | <center>would like</center> |
# | <center>secretary state</center> | <center>take look</center> | <center>soviet union</center> | <center>federal government</center> |
# | <center>tax cuts</center> | <center>bernie sanders</center> | <center>united states</center> | <center>tax increase</center> |
# | <center>president obama</center> | <center>make america</center> | <center>nuclear weapons</center> | <center>business industry</center> |
# | <center>affordable care</center> | <center>bad judgment</center> | <center>minimum wage</center> | <center>arms limitation</center> |
# | <center>make sure</center> | <center>carried interest</center> | <center>health insurance</center> | <center>misery index</center> |

# %% [markdown]
# ## Tagging

# %%
nltk.download('averaged_perceptron_tagger')
tagged_dem_debate_1980 = nltk.pos_tag(tokens_dem_debate_1980)

# %%
patterns= """mychunk:{<NN.?>*<VBD.?>*<JJ.?>*<CC>?}"""
chunker = nltk.RegexpParser(patterns)
output = chunker.parse(tagged_dem_debate_1980)
print("After Chunking",output)
# Out:
# After Chunking (S
#   yes/RB
#   (mychunk mr/NN stone/NN i've/JJ)
#   make/VB
#   (mychunk thousands/NNS decisions/NNS)
#   since/IN
#   (mychunk i've/NN president/NN)
#   serving/VBG
#   (mychunk oval/JJ)
#   (mychunk office/NN)
#   one/CD
#   (mychunk decisions/NNS)
#   affect/VBP
#   (mychunk future/JJ)
#   (mychunk country/NN learned/VBD process/JJ)
#   think/VBP
#   i'm/RB
#   much/RB
#   wiser/RBR
#   (mychunk experienced/JJ)
#   (mychunk man/NN debated/VBD)
#   (mychunk years/NNS)
#   ago/IN
#   (mychunk president/NN ford/NN i've/NN)
#   also/RB
#   (mychunk learned/VBD simple/JJ)
#   (mychunk answers/NNS complicated/VBD)
#   (mychunk questions/NNS)
#   h/VBP
#   (mychunk l/JJ)
#   (mychunk mencken/NN said/VBD)
#   every/DT
#   (mychunk problem/NN there's/NN simple/NN answer/NN)
#   would/MD
#   neat/VB
#   (mychunk plausible/JJ wrong/JJ)
#   (mychunk fact/NN nation/NN years/NNS became/VBD)
#   (mychunk president/NN military/JJ)
#   (mychunk strength/NN decreased/VBD)
#   seven/CD
#   eight/CD
#   (mychunk years/NNS budget/NN commitments/NNS defense/NN went/VBD)
#   (mychunk percent/NN)
#   since/IN
#   (mychunk i've/NN office/NN we've/NN steady/JJ)
#   carefully/RB
#   planned/VBN
#   (mychunk methodical/JJ effective/JJ)
#   (mychunk increase/NN commitment/NN defense/NN we've/NN)
#   done/VBN
#   use/RB
#   (mychunk enormous/JJ)
#   (mychunk power/NN prestige/NN military/JJ)
#   (mychunk strength/NN united/JJ)
#   (mychunk states/NNS)
#   preserve/VBP
#   (mychunk peace/NN we've/NN kept/VBD peace/JJ)
#   (mychunk country/NN we've/VBD able/JJ extend/JJ)
#   (mychunk benefits/NNS peace/NN others/NNS)
#   middle/VBP
#   (mychunk east/JJ)
#   (mychunk we've/NN worked/VBD)
#   (mychunk peace/NN treaty/NN israel/NN)
#   egypt/VBZ
#   successfully/RB
#   tied/VBN
#   together/RB
#   (mychunk israel/JJ)
#   (mychunk egypt/NN common/JJ)
#   (mychunk defense/NN capability/NN good/JJ)
#   (mychunk step/NN)
#   forward/RB
#   (mychunk nation's/JJ)
#   (mychunk security/NN we'll/NN)
#   continue/VBP
#   we've/IN
#   done/VBN
#   (mychunk past/NN)
#   might/MD
#   also/RB
#   add/VB
#   (mychunk decisions/NNS)
#   made/VBN
#   (mychunk oval/JJ)
#   (mychunk office/NN)
#   every/DT
#   (mychunk president/NN)
#   profound/IN
#   (mychunk nature/NN)
#   always/RB
#   (mychunk troublespots/JJ)
#   (mychunk world/NN troubled/VBD)
#   (mychunk areas/NNS)
#   addressed/VBN
#   (mychunk president/NN)
#   alone/RB
#   (mychunk oval/JJ)
#   (mychunk office/NN)
#   affects/VBZ
#   (mychunk nation/NN)
#   directly/RB
#   (mychunk involvement/JJ united/JJ)
#   (mychunk states/NNS)
#   also/RB
#   (mychunk american/JJ)
#   (mychunk interests/NNS basic/JJ)
#   (mychunk decision/NN made/VBD)
#   frequently/RB
#   every/DT
#   (mychunk president/NN)
#   serves/VBZ
#   (mychunk that's/JJ)
#   (mychunk i've/NN)
#   tried/VBN
#   successfully/RB
#   keeping/VBG
#   (mychunk country/NN peace/NN)
#   mr/VBP
#   (mychunk stone/NN state/NN union/NN address/NN)
#   earlier/RBR
#   (mychunk year/NN pointed/VBD)
#   (mychunk threat/NN stability/NN security/NN persian/JJ)
#   (mychunk gulf/NN)
#   would/MD
#   (mychunk threat/NN security/NN country/NN)
#   past/IN
#   (mychunk we've/JJ adequate/JJ military/JJ)
#   (mychunk presence/NN region/NN)
#   two/CD
#   (mychunk major/JJ)
#   (mychunk carrier/NN task/NN forces/NNS access/NN facilities/NNS)
#   five/CD
#   (mychunk different/JJ)
#   (mychunk areas/NNS region/NN we've/NN)
#   made/VBN
#   (mychunk clear/JJ working/JJ)
#   (mychunk allies/NNS others/NNS prepared/VBD)
#   (mychunk address/NN foreseeable/JJ)
#   (mychunk eventuality/NN)
#   might/MD
#   interrupt/VB
#   (mychunk commerce/NN crucial/JJ)
#   (mychunk area/NN world/NN made/VBD sure/JJ address/JJ)
#   (mychunk question/NN)
#   peacefully/RB
#   (mychunk injecting/JJ american/JJ military/JJ)
#   (mychunk forces/NNS)
#   combat/VBP
#   letting/VBG
#   (mychunk strength/NN nation/NN felt/VBD beneficial/JJ)
#   (mychunk way/NN)
#   believe/VBP
#   assured/VBN
#   (mychunk interests/NNS protected/VBD persian/JJ)
#   (mychunk gulf/NN region/NN)
#   we've/IN
#   done/VBN
#   (mychunk middle/NN east/NN)
#   throughout/IN
#   (mychunk world/NN)
#   well/RB
#   (mychunk various/JJ)
#   (mychunk elements/NNS defense/NN)
#   one/CD
#   (mychunk control/NN nuclear/JJ)
#   (mychunk weapons/NNS)
#   hope/VBP
#   we'll/RB
#   get/VB
#   later/RB
#   (mychunk that's/JJ important/JJ single/JJ)
#   (mychunk issue/NN campaign/NN)
#   another/DT
#   one/CD
#   (mychunk address/NN troubled/VBD)
#   (mychunk areas/NNS world/NN)
#   think/VBP
#   habitually/RB
#   governor/VBP
#   (mychunk reagan/JJ advocated/JJ)
#   (mychunk injection/NN military/JJ)
#   (mychunk forces/NNS troubled/VBD)
#   (mychunk areas/NNS predecessors/NNS)
#   democrats/NNPS
#   republicans/VBP
#   advocated/VBN
#   resolving/VBG
#   (mychunk troubles/NNS difficult/JJ)
#   (mychunk areas/NNS world/NN)
#   peacefully/RB
#   diplomatically/RB
#   (mychunk negotiation/JJ)
#   (mychunk addition/NN buildup/NN military/JJ)
#   (mychunk forces/NNS good/JJ)
#   (mychunk country/NN we've/NN got/VBD military/JJ)
#   (mychunk strength/NN order/NN preserve/NN peace/NN i'll/NN)
#   always/RB
#   remember/VB
#   (mychunk best/JJS)
#   (mychunk weapons/NNS ones/NNS)
#   never/RB
#   (mychunk fired/VBD)
#   (mychunk combat/NN best/JJS soldier/JJR)
#   one/CD
#   never/RB
#   (mychunk lay/VBD)
#   (mychunk life/NN field/NN battle/NN strength/NN imperative/JJ)
#   (mychunk peace/NN)
#   two/CD
#   must/MD
#   go/VB
#   (mychunk hand/NN hand/NN important/JJ)
#   (mychunk put/NN situation/NN perspective/NN so-called/JJ)
#   (mychunk oil/NN shock/NN wherein/NN price/NN opec/NN oil/NN)
#   raised/VBN
#   (mychunk extraordinary/JJ)
#   (mychunk degree/NN)
#   even/RB
#   (mychunk worse/JJR)
#   (mychunk oil/NN shock/NN worst/JJS)
#   (mychunk recession/NN deepest/JJS)
#   penetrating/VBG
#   (mychunk recession/NN)
#   since/IN
#   (mychunk second/JJ)
#   (mychunk world/NN war/NN recession/NN resulted/VBD)
#   (mychunk time/NN briefest/JJS)
#   (mychunk we've/NN)
#   since/IN
#   (mychunk second/JJ)
#   (mychunk world/NN war/NN addition/NN we've/VBD)
#   brought/VBN
#   (mychunk inflation/NN)
#   earlier/RBR
#   (mychunk year/NN)
#   first/RB
#   (mychunk quarter/NN severe/JJ)
#   (mychunk inflation/NN pressure/NN brought/VBD opec/JJ)
#   (mychunk price/NN increase/NN averaged/VBD percent/JJ first/JJ)
#   (mychunk quarter/NN year/NN second/JJ)
#   (mychunk quarter/NN dropped/VBD percent/JJ recent/JJ)
#   (mychunk figures/NNS last/JJ)
#   (mychunk months/NNS third/JJ)
#   (mychunk quarter/NN year/NN inflation/NN rate/NN percent/NN)
#   still/RB
#   (mychunk high/JJ)
#   (mychunk illustrates/NNS)
#   vividly/RB
#   (mychunk addition/NN)
#   providing/VBG
#   (mychunk enormous/JJ)
#   (mychunk number/NN jobs/NNS)
#   million/CD
#   (mychunk new/JJ)
#   (mychunk jobs/NNS last/JJ)
#   (mychunk years/NNS inflationary/JJ)
#   (mychunk threat/NN)
#   still/RB
#   (mychunk urgent/JJ)
#   us/PRP
#   (mychunk noticed/VBD)
#   (mychunk governor/NN reagan/NN)
#   recently/RB
#   (mychunk mentioned/VBD reagan-kemp-roth/JJ)
#   (mychunk proposal/NN)
#   running/VBG
#   mate/VB
#   (mychunk george/NN bush/NN)
#   described/VBN
#   (mychunk voodoo/JJ)
#   (mychunk economics/NNS said/VBD)
#   would/MD
#   result/VB
#   (mychunk percent/JJ)
#   (mychunk
#     inflation/NN
#     rate/NN
#     business/NN
#     week/NN
#     publication/NN
#     said/VBD
#     reagan-kemp-roth/JJ)
#   (mychunk proposal/NN)
#   quote/VBZ
#   (mychunk think-was/JJ)
#   completely/RB
#   (mychunk irresponsible/JJ)
#   would/MD
#   result/VB
#   (mychunk inflationary/JJ)
#   (mychunk pressures/NNS)
#   would/MD
#   destroy/VB
#   (mychunk nation/NN proposals/NNS)
#   sound/VBP
#   carefully/RB
#   considered/VBN
#   (mychunk stimulate/NN jobs/NNS)
#   improve/VBP
#   (mychunk industrial/JJ complex/JJ)
#   (mychunk country/NN create/NN tools/NNS american/JJ)
#   (mychunk workers/NNS time/NN)
#   would/MD
#   (mychunk anti-inflationary/JJ)
#   (mychunk nature/NN)
#   add/VB
#   million/CD
#   (mychunk new/JJ)
#   (mychunk jobs/NNS control/NN inflation/NN plan/NN future/JJ)
#   (mychunk energy/NN policy/NN intact/JJ)
#   (mychunk foundation/NN plan/NN years/NNS)
#   ahead/RB
#   yes/RB
#   yes/RB
#   (mychunk demanded/JJ american/JJ)
#   (mychunk people/NNS)
#   sacrifice/VBP
#   they've/RB
#   done/VBN
#   well/RB
#   matter/RBR
#   (mychunk fact/NN)
#   we're/IN
#   importing/VBG
#   (mychunk today/NN one-third/JJ less/JJR)
#   (mychunk oil/NN)
#   overseas/IN
#   (mychunk year/NN)
#   ago/RB
#   (mychunk we've/VBD)
#   (mychunk percent/NN reduction/NN)
#   since/IN
#   (mychunk first/JJ)
#   (mychunk year/NN office/NN time/NN said/VBD)
#   earlier/RBR
#   (mychunk added/JJ)
#   million/CD
#   (mychunk net/JJ new/JJ)
#   (mychunk jobs/NNS period/NN time/NN record/NN)
#   never/RB
#   achieved/VBN
#   also/RB
#   (mychunk new/JJ)
#   (mychunk energy/NN policy/NN predicated/VBD)
#   two/CD
#   (mychunk factors/NNS)
#   one/CD
#   (mychunk conservation/NN)
#   requires/VBZ
#   (mychunk sacrifice/JJ)
#   one/CD
#   (mychunk increase/NN production/NN american/JJ)
#   (mychunk energy/NN)
#   going/VBG
#   along/RB
#   well/RB
#   (mychunk coal/NN year/NN)
#   ever/RB
#   (mychunk history/NN oil/NN gas/NN wells/NNS drilled/VBD)
#   (mychunk year/NN)
#   ever/RB
#   (mychunk history/NN new/JJ economic/JJ)
#   (mychunk
#     revitalization/NN
#     program/NN
#     mind/NN
#     implemented/VBD
#     next/JJ)
#   (mychunk year/NN)
#   would/MD
#   result/VB
#   (mychunk tax/NN credits/NNS)
#   would/MD
#   let/VB
#   (mychunk business/NN)
#   invest/VB
#   (mychunk new/JJ)
#   (mychunk tools/NNS new/JJ)
#   (mychunk factories/NNS)
#   create/VBP
#   even/RB
#   (mychunk new/JJ)
#   (mychunk jobs/NNS)
#   million/CD
#   (mychunk next/JJ)
#   (mychunk years/NNS)
#   also/RB
#   (mychunk planned/VBD youth/JJ)
#   (mychunk employment/NN program/NN)
#   would/MD
#   encompass/VB
#   (mychunk jobs/NNS young/JJ)
#   (mychunk people/NNS)
#   already/RB
#   passed/VBN
#   (mychunk house/NN excellent/JJ prospect/JJ)
#   (mychunk
#     pass/NN
#     senate/NN
#     governor/NN
#     reagan's/NN
#     proposal/NN
#     reagan-kemp-roth/JJ)
#   (mychunk proposal/NN)
#   one/CD
#   highly/RB
#   (mychunk inflationary/JJ)
#   (mychunk ideas/NNS)
#   ever/RB
#   (mychunk presented/VBD american/JJ)
#   (mychunk public/NN)
#   would/MD
#   actually/RB
#   cut/VB
#   (mychunk government/NN)
#   spending/VBG
#   (mychunk least/JJS)
#   billion/CD
#   (mychunk order/NN balance/NN budget/NN ridiculous/JJ)
#   (mychunk proposal/NN)
#   noticed/VBN
#   (mychunk task/NN force/NN that's/NN)
#   working/VBG
#   (mychunk future/JJ)
#   (mychunk plans/NNS ideas/NNS revealed/VBD wall/JJ)
#   (mychunk street/NN journal/NN week/NN)
#   one/CD
#   (mychunk ideas/NN repeal/NN minimum/JJ)
#   (mychunk wage/NN several/JJ)
#   (mychunk times/NNS year/NN governor/NN reagan/NN said/VBD major/JJ)
#   (mychunk
#     cause/NN
#     unemployment/NN
#     minimum/NN
#     wage/NN
#     heartless/NN
#     kind/NN
#     approach/NN)
#   working/VBG
#   (mychunk families/NNS country/NN typical/JJ many/JJ)
#   (mychunk leaders/NNS past/JJ)
#   think/VBP
#   accentuated/VBN
#   (mychunk governor/NN reagan/NN california/VBD)
#   (mychunk i'm/NNS surprised/VBD)
#   (mychunk governor/NN reagan/NN brought/VBD)
#   three/CD
#   (mychunk largest/JJS)
#   (mychunk
#     tax/NN
#     increases/NNS
#     history/NN
#     state/NN
#     administration/NN
#     doubled/VBD)
#   (mychunk
#     state/NN
#     spending/NN
#     governor/NN
#     percent/NN
#     increase/NN
#     percent/NN)
#   increase/VB
#   (mychunk number/NN employees/NNS)
#   california/VBP
#   (mychunk thank/NN sir/NN thank/NN)
#   mr/FW
#   (mychunk hilliard/NN campaigning/NN)
#   everywhere/RB
#   (mychunk went/VBD)
#   (mychunk mayors/NNS local/JJ)
#   (mychunk officials/NNS)
#   despair/VBP
#   rapidly/RB
#   deteriorating/VBG
#   (mychunk central/JJ)
#   (mychunk cities/NNS nation/NN)
#   initiated/VBN
#   (mychunk fine/JJ urban/JJ)
#   (mychunk renewal/NN program/NN)
#   working/VBG
#   (mychunk mayors/NNS governors/NNS interested/JJ)
#   (mychunk officials/NNS successful/JJ)
#   (mychunk effort/NN that's/VBD)
#   one/CD
#   (mychunk main/JJ)
#   (mychunk reasons/NNS)
#   we've/VBP
#   increase/VB
#   (mychunk number/NN people/NNS)
#   employed/VBN
#   million/CD
#   (mychunk people/NNS)
#   put/VBP
#   work/VB
#   (mychunk new/JJ)
#   (mychunk jobs/NNS)
#   since/IN
#   (mychunk i've/NN office/NN)
#   million/CD
#   among/IN
#   (mychunk black/JJ)
#   (mychunk americans/NNS)
#   another/DT
#   million/CD
#   among/IN
#   (mychunk speak/JJ spanish/JJ)
#   (mychunk planning/NN continue/JJ)
#   (mychunk revitalization/NN program/NN increased/VBD)
#   (mychunk commitments/NNS rapid/JJ transit/JJ)
#   (mychunk mass/NN transit/NN)
#   windfall/VB
#   (mychunk profits/NNS tax/NN)
#   expect/VBP
#   spend/VB
#   billion/CD
#   (mychunk next/JJ)
#   (mychunk years/NNS rebuild/JJ)
#   (mychunk transportation/NN systems/NNS country/NN)
#   also/RB
#   pursuing/VBG
#   (mychunk housing/NN programs/NNS)
#   we've/VBP
#   (mychunk percent/JJ)
#   (mychunk increase/NN allotment/NN federal/JJ)
#   (mychunk funds/NNS)
#   improved/VBN
#   (mychunk education/NN kinds/NNS efforts/NNS worked/VBD joint/JJ)
#   (mychunk basis/NN community/NN leaders/NNS)
#   particularly/RB
#   (mychunk minority/NN areas/NNS central/JJ)
#   (mychunk cities/NNS)
#   deteriorating/VBG
#   rapidly/RB
#   (mychunk past/JJ important/JJ)
#   us/PRP
#   done/VBN
#   (mychunk full/JJ)
#   (mychunk involvement/NN minority/NN citizens/NNS i've/JJ)
#   brought/VBN
#   (mychunk top/JJ)
#   (mychunk levels/NNS government/NN white/JJ)
#   (mychunk house/NN administrative/JJ)
#   (mychunk offices/NNS)
#   executive/VBP
#   (mychunk branch/NN judicial/JJ)
#   (mychunk system/NN)
#   highly/RB
#   (mychunk qualified/JJ black/JJ spanish/JJ)
#   (mychunk citizens/NNS women/NNS)
#   past/RB
#   (mychunk excluded/VBD noticed/JJ)
#   (mychunk governor/NN reagan/NN said/VBD younger/JJR)
#   (mychunk man/NN)
#   knowledge/VBP
#   (mychunk racial/JJ)
#   (mychunk problem/NN country/NN suffered/VBD)
#   (mychunk discrimination/NN race/NN sex/NN)
#   certainly/RB
#   (mychunk knew/VBD racial/JJ)
#   (mychunk problem/NN)
#   gone/VBN
#   (mychunk long/JJ)
#   (mychunk way/NN)
#   toward/IN
#   correcting/VBG
#   (mychunk problems/NNS)
#   still/RB
#   long/RB
#   (mychunk way/NN)
#   go/VBP
#   (mychunk nation/NN refugees/NNS nation/NN immigrants/NNS)
#   almost/RB
#   (mychunk citizens/NNS came/VBD)
#   lands/VBZ
#   (mychunk hopes/NNS)
#   realized/VBN
#   better/RBR
#   (mychunk life/NN)
#   preserving/VBG
#   (mychunk ethnic/JJ)
#   (mychunk commitments/NNS family/NN)
#   structures/VBZ
#   (mychunk religious/JJ)
#   (mychunk beliefs/NNS)
#   preserving/VBG
#   (mychunk relationships/NNS)
#   relatives/VBZ
#   (mychunk foreign/JJ)
#   (mychunk countries/NNS)
#   still/RB
#   forming/VBG
#   together/RB
#   (mychunk coherent/JJ)
#   (mychunk society/NN)
#   gives/VBZ
#   (mychunk nation/NN strength/NN)
#   past/IN
#   (mychunk minority/NN groups/NNS)
#   often/RB
#   (mychunk excluded/VBD)
#   (mychunk participation/NN affairs/NNS government/NN)
#   since/IN
#   (mychunk i've/NN president/NN i've/NN)
#   appointed/VBN
#   (mychunk instance/NN)
#   twice/RB
#   (mychunk many/JJ black/JJ federal/JJ)
#   (mychunk judges/NNS previous/JJ)
#   (mychunk presidents/NNS history/NN country/NN)
#   i've/VBZ
#   done/VBN
#   (mychunk thing/NN appointment/NN women/NNS)
#   also/RB
#   (mychunk spanish-speaking/JJ)
#   (mychunk americans/NNS)
#   involve/VBP
#   (mychunk administration/NN government/NN)
#   feeling/VBG
#   (mychunk belong/JJ societal/JJ)
#   (mychunk structure/NN)
#   makes/VBZ
#   (mychunk decisions/NNS judiciary/JJ)
#   (mychunk executive/NN branch/NN important/JJ)
#   (mychunk commitment/NN)
#   trying/VBG
#   (mychunk realize/NN continue/NN future/JJ)
#   well/RB
#   (mychunk obvious/JJ)
#   still/RB
#   (mychunk long/JJ)
#   (mychunk way/NN)
#   go/VBP
#   fully/RB
#   (mychunk incorporating/JJ)
#   (mychunk minority/NN groups/NNS)
#   mainstream/VBP
#   (mychunk american/JJ)
#   (mychunk life/NN made/VBD good/JJ)
#   (mychunk progress/NN there's/NN doubt/NN mind/NN commitment/JJ)
#   (mychunk unemployment/NN compensation/NN minimum/NN wage/NN)
#   welfare/VBP
#   (mychunk national/JJ)
#   (mychunk health/NN insurance/NN)
#   kinds/VBZ
#   (mychunk commitments/NNS typified/VBD)
#   (mychunk party/NN)
#   since/IN
#   (mychunk ancient/JJ)
#   (mychunk history/NN)
#   country's/VB
#   (mychunk political/JJ)
#   (mychunk life/NN important/JJ)
#   (mychunk element/NN future/JJ)
#   (mychunk elements/NNS)
#   governor/VBP
#   (mychunk reagan/NNS)
#   repeatedly/RB
#   spoken/VBN
#   shows/VBZ
#   (mychunk great/JJ)
#   (mychunk insensitivity/NN)
#   giving/VBG
#   (mychunk deprived/JJ)
#   (mychunk families/NNS)
#   better/RBR
#   (mychunk chance/NN life/NN important/JJ)
#   (mychunk difference/NN election/NN)
#   believe/VBP
#   (mychunk american/JJ)
#   (mychunk people/NNS)
#   judge/VBP
#   accordingly/RB
#   doubt/VB
#   (mychunk mind/NN downtown/JJ central/JJ)
#   (mychunk cities/NNS new/JJ commitment/JJ)
#   (mychunk energy/NN policy/NN chance/NN revitalize/NN homes/NNS)
#   make/VBP
#   (mychunk fuel-efficient/JJ)
#   (mychunk chance/NN synthetic/JJ)
#   (mychunk fuels/NNS program/NN solar/JJ)
#   (mychunk power/NN)
#   give/VBP
#   us/PRP
#   (mychunk additional/JJ)
#   (mychunk opportunity/NN jobs/NNS)
#   pay/VBP
#   (mychunk rich/JJ)
#   (mychunk dividends/NNS)
#   barbara/VBP
#   one/CD
#   (mychunk blights/NN world/NN threat/NN activities/NNS)
#   terrorists/VBZ
#   one/CD
#   (mychunk recent/JJ economic/JJ)
#   (mychunk summit/NN conferences/NNS leaders/NNS stern/JJ)
#   (mychunk world/NN committed/VBD)
#   (mychunk take/NN strong/JJ)
#   (mychunk action/NN terrorism/NN airplane/NN)
#   hijacking/VBG
#   one/CD
#   (mychunk elements/NNS commitment/JJ)
#   (mychunk doubt/NN)
#   seen/VBN
#   (mychunk recent/JJ)
#   (mychunk years/NNS recent/JJ)
#   (mychunk months/NNS additional/JJ)
#   (mychunk acts/NNS violence/JJ)
#   (mychunk jews/NNS france/NN course/NN live/JJ)
#   (mychunk israel/NN plo/JJ terrorist/JJ)
#   (mychunk organizations/NNS)
#   ultimately/RB
#   (mychunk serious/JJ terrorist/JJ)
#   (mychunk threat/NN)
#   one/CD
#   (mychunk radical/JJ)
#   (mychunk nations/NNS)
#   believe/VBP
#   (mychunk terrorism/NN policy/NN atomic/JJ)
#   (mychunk weapons/NNS predecessors/NNS)
#   deep/VBP
#   (mychunk commitment/NN)
#   controlling/VBG
#   (mychunk proliferation/NN nuclear/JJ)
#   (mychunk weapons/NNS countries/NNS)
#   like/IN
#   (mychunk libya/NN iraq/NN)
#   even/RB
#   (mychunk alienated/VBD closest/JJS)
#   (mychunk trade/NN partners/NNS insisted/VBD)
#   upon/IN
#   (mychunk control/NN spread/JJ nuclear/JJ)
#   (mychunk weapons/NNS)
#   potentially/RB
#   (mychunk terrorist/JJ)
#   (mychunk countries/NNS)
#   governor/VBP
#   (mychunk reagan/JJ)
#   (mychunk asked/VBD)
#   makes/VBZ
#   disturbing/VBG
#   (mychunk comment/JJ)
#   (mychunk nonproliferation/NN control/NN spread/JJ nuclear/JJ)
#   (mychunk weapons/NNS none/NN business/NN asked/VBD)
#   specifically/RB
#   recently/RB
#   iraq/VBN
#   (mychunk said/VBD there's/JJ)
#   (mychunk nothing/NN ultimate/JJ)
#   (mychunk terrorist/NN threat/NN fearsome/JJ)
#   (mychunk part/NN pattern/JJ)
#   (mychunk country/NN)
#   must/MD
#   stand/VB
#   (mychunk firm/NN control/NN terrorism/NN)
#   kinds/VBZ
#   (mychunk maintain/JJ)
#   (mychunk position/NN neutrality/NN iran/JJ)
#   (mychunk iraq/NNP war/NN plans/NNS)
#   sell/VBP
#   (mychunk additional/JJ)
#   (mychunk materiel/NN goods/NNS iran/NN)
#   might/MD
#   warlike/VB
#   (mychunk nature/NN)
#   made/VBN
#   (mychunk decision/NN stop/NN trade/NN iran/NN result/NN)
#   taking/VBG
#   (mychunk hostages/NNS announced/VBD)
#   consistently/RB
#   maintained/VBN
#   since/IN
#   (mychunk hostages/NNS)
#   released/VBN
#   safely/RB
#   would/MD
#   make/VB
#   (mychunk delivery/NN items/NNS iran/JJ)
#   owns/VBZ
#   bought/VBN
#   paid/VBN
#   (mychunk for-also/JJ frozen/JJ iranian/JJ)
#   (mychunk assets/NNS)
#   would/MD
#   released/VBN
#   that's/VB
#   (mychunk consistent/JJ)
#   (mychunk policy/NN)
#   one/CD
#   (mychunk intend/NN carry/NN hear/JJ)
#   (mychunk comment/NN governor/NN reagan/NN)
#   would/MD
#   stop/VB
#   reduce/VB
#   (mychunk terrorism/NN future/JJ western/JJ)
#   (mychunk allies/NNS)
#   decide/VBP
#   (mychunk stop/JJ)
#   (mychunk air/NN flights-commercial/JJ)
#   (mychunk air/NN flights/NNS nation/NN)
#   involved/VBN
#   (mychunk terrorism/NN)
#   hijacking/VBG
#   (mychunk airplanes/NNS)
#   harboring/VBG
#   (mychunk hijackers/NNS)
#   secondly/RB
#   (mychunk committed/VBD)
#   (mychunk predecessors/NNS oval/JJ)
#   (mychunk office/NN permit/NN)
#   spread/VBP
#   (mychunk nuclear/JJ)
#   (mychunk weapons/NNS terrorist/JJ)
#   (mychunk nation/NN nation/NN)
#   presently/RB
#   (mychunk weapons/NNS capabilities/NNS)
#   explosives/VBZ
#   (mychunk third/JJ)
#   make/VB
#   (mychunk sales/NNS)
#   materiel/VB
#   (mychunk weapons/NNS nation/NN)
#   involved/VBN
#   (mychunk terrorist/JJ)
#   (mychunk activities/NNS)
#   lastly/RB
#   deal/VBP
#   (mychunk plo/JJ)
#   unless/IN
#   (mychunk plo/NN)
#   recognizes/VBZ
#   (mychunk israel's/JJ right/JJ)
#   (mychunk exist/NN)
#   recognizes/VBZ
#   (mychunk u/JJ n/JJ)
#   (mychunk resolution/NN basis/NN middle/JJ)
#   east/RB
#   (mychunk peace/JJ)
#   (mychunk things/NNS nation/NN committed/VBD continue/JJ)
#   (mychunk commitments/NNS)
#   yes/RB
#   i'd/VBP
#   (mychunk glad/JJ)
#   (mychunk inflation/NN unemployment/NN cities-all/JJ important/JJ)
#   (mychunk issues/NNS)
#   pale/VBP
#   (mychunk insignificance/NN life/NN duties/NNS president/NN)
#   compared/VBN
#   (mychunk control/NN nuclear/JJ)
#   (mychunk weapons/NNS)
#   every/DT
#   (mychunk president/NN served/VBD oval/JJ)
#   (mychunk office/NN)
#   since/IN
#   (mychunk harry/NN truman/NN)
#   dedicated/VBN
#   (mychunk proposition/NN)
#   controlling/VBG
#   (mychunk nuclear/JJ)
#   (mychunk weapons/NNS)
#   negotiate/VBP
#   (mychunk soviet/JJ)
#   (mychunk union/NN balanced/VBD)
#   controlled/VBN
#   (mychunk observable/JJ)
#   (mychunk reducing/NN levels/NNS atomic/JJ)
#   (mychunk weaponry/NN)
#   disturbing/VBG
#   (mychunk pattern/JJ)
#   (mychunk attitude/NN governor/NN reagan/NN)
#   never/RB
#   (mychunk supported/VBD)
#   (mychunk arms/NNS control/NN agreements/NNS limited/JJ)
#   (mychunk test/NN ban/NN salt/NN antiballistic/JJ)
#   (mychunk missile/NN treaty/NN vladivostok/NN treaty/NN)
#   negotiated/VBN
#   (mychunk soviet/JJ)
#   (mychunk union/NN president/NN ford/NN)
#   wants/VBZ
#   throw/VBP
#   (mychunk wastebasket/NN treaty/NN control/NN nuclear/JJ)
#   (mychunk weapons/NNS balanced/VBD equal/JJ)
#   (mychunk basis/NN soviet/JJ)
#   (mychunk union/NN negotiated/VBD)
#   (mychunk year/NN period/NN)
#   two/CD
#   (mychunk predecessors/NNS)
#   senate/VBP
#   voted/VBN
#   yet/RB
#   (mychunk strategic/JJ)
#   (mychunk arms/NNS limitation/NN treaty/NN preliminary/JJ)
#   (mychunk skirmishings/NNS committees/NNS)
#   senate/VBP
#   (mychunk treaty/NN)
#   never/RB
#   come/VBN
#   (mychunk floor/NN senate/NN)
#   either/DT
#   (mychunk debate/NN vote/NN understandable/JJ)
#   (mychunk senator/NN preliminary/JJ)
#   (mychunk debates/NNS)
#   make/VBP
#   (mychunk irresponsible/JJ)
#   (mychunk statement/NN)
#   maybe/RB
#   (mychunk ill-advised/JJ)
#   (mychunk statement/NN got/VBD)
#   (mychunk senators/NNS)
#   correct/VBP
#   (mychunk mistake/JJ)
#   (mychunk mistake/NN man/NN)
#   hopes/VBZ
#   (mychunk president/NN)
#   says/VBZ
#   take/VB
#   (mychunk treaty/NN discard/JJ)
#   (mychunk vote/NN debate/NN)
#   explore/RB
#   (mychunk issues/NNS)
#   finally/RB
#   capitalize/VB
#   (mychunk long/JJ)
#   (mychunk negotiation/NN dangerous/JJ)
#   disturbing/VBG
#   (mychunk thing/NN yes/NNS)
#   governor/VBP
#   (mychunk reagan/JJ)
#   making/VBG
#   (mychunk misleading/JJ disturbing/JJ)
#   (mychunk statements/NNS)
#   advocates/VBZ
#   scrapping/VBG
#   (mychunk treaty/NN)
#   know/VBP
#   (mychunk men/NNS)
#   quotes/VBZ
#   treaty/VBP
#   (mychunk final/JJ)
#   (mychunk form/NN)
#   also/RB
#   advocates/VBZ
#   (mychunk possibility-he/NN said/VBD)
#   missing/VBG
#   (mychunk element-of/JJ)
#   (mychunk playing/NN trump/NN card/NN soviet/JJ)
#   (mychunk union/NN nuclear/JJ)
#   (mychunk arms/NNS race/NN)
#   insisting/VBG
#   upon/IN
#   (mychunk nuclear/JJ)
#   (mychunk
#     superiority/NN
#     nation/NN
#     predication/NN
#     negotiation/NN
#     future/NN
#     soviet/JJ)
#   (mychunk union/NN president/NN brezhnev/NN said/VBD)
#   (mychunk scrap/NN treaty/NN negotiated/VBD)
#   three/CD
#   (mychunk american/JJ)
#   (mychunk presidents/NNS year/NN period/NN time/NN insist/JJ)
#   upon/IN
#   (mychunk nuclear/JJ)
#   (mychunk superiority/NN basis/NN future/JJ)
#   (mychunk negotiations/NNS)
#   believe/VBP
#   launching/VBG
#   (mychunk nuclear/JJ)
#   (mychunk arms/NNS race/NN good/JJ)
#   (mychunk basis/NN future/JJ)
#   (mychunk negotiations/NNS obvious/JJ)
#   (mychunk president/NN americans/NNS)
#   would/MD
#   reject/VB
#   (mychunk proposition/NN)
#   would/MD
#   mean/VB
#   (mychunk resumption/NN dangerous/JJ nuclear/JJ)
#   (mychunk arms/NNS race/NN)
#   would/MD
#   disturbing/VB
#   (mychunk american/JJ)
#   (mychunk people/NNS)
#   would/MD
#   change/VB
#   (mychunk basic/JJ)
#   (mychunk tone/NN commitment/NN nation/NN experienced/VBD)
#   ever/RB
#   since/IN
#   (mychunk second/JJ)
#   (mychunk world/NN war/NN presidents/NNS)
#   would/MD
#   also/RB
#   disturbing/VBG
#   (mychunk allies/NNS)
#   support/VBP
#   (mychunk nuclear/JJ)
#   (mychunk arms/NNS treaty/NN addition/NN adversarial/JJ)
#   (mychunk relationship/NN soviet/JJ)
#   (mychunk union/NN)
#   would/MD
#   undoubtedly/RB
#   deteriorate/VB
#   rapidly/RB
#   attitude/VBP
#   extremely/RB
#   (mychunk dangerous/JJ)
#   (mychunk belligerent/NN tone/NN)
#   although/IN
#   (mychunk said/VBD quiet/JJ)
#   (mychunk voice/NN)
#   think/VBP
#   (mychunk close/JJ)
#   (mychunk discussion/NN)
#   would/MD
#   better/VB
#   put/VB
#   (mychunk perspective/JJ)
#   (mychunk we're/NN)
#   talking/VBG
#   (mychunk discussion/NN daughter/NN amy/JJ)
#   (mychunk day/NN came/VBD)
#   ask/RB
#   (mychunk important/JJ)
#   (mychunk issue/NN said/VBD)
#   thought/VBN
#   (mychunk nuclear/JJ)
#   (mychunk weaponry/NN control/NN nuclear/JJ)
#   (mychunk arms/NNS formidable/JJ)
#   (mychunk force/NN weapons/NNS megatons/NNS explosion/NN put/VBD)
#   (mychunk tons/NNS)
#   tnt/VBP
#   one/CD
#   (mychunk railroad/NN cars/NNS)
#   would/MD
#   trainload/VB
#   (mychunk tnt/NN)
#   stretching/VBG
#   across/IN
#   (mychunk nation/NN that's/NN)
#   one/CD
#   (mychunk major/JJ)
#   (mychunk war/NN explosion/NN warhead/VBD)
#   (mychunk thousands/NNS equivalent/JJ)
#   megaton/CD
#   million/CD
#   (mychunk tons/NNS tnt/JJ)
#   (mychunk warheads/NNS control/NN weapons/NNS single/JJ major/JJ)
#   (mychunk responsibility/NN president/NN cast/VBD commitment/JJ)
#   (mychunk presidents/NNS slight/JJ)
#   (mychunk technicalities/NNS)
#   corrected/VBN
#   (mychunk dangerous/JJ)
#   (mychunk approach/NN)
#   think/VBP
#   (mychunk there's/JJ)
#   (mychunk doubt/NN future/NN cost/NN oil/NN)
#   going/VBG
#   go/VB
#   (mychunk i've/JJ basic/JJ)
#   (mychunk commitment/NN)
#   since/IN
#   (mychunk i've/NN president/NN)
#   reduce/VB
#   (mychunk dependence/NN foreign/JJ)
#   (mychunk oil/NN)
#   done/VBN
#   two/CD
#   (mychunk ways/NNS)
#   one/CD
#   (mychunk conserve/NN energy/NN)
#   stop/VB
#   (mychunk waste/NN energy/NN)
#   secondly/RB
#   produce/VBP
#   (mychunk american/JJ)
#   (mychunk energy/NN we've/NNS successful/JJ)
#   (mychunk cases/NNS)
#   we've/VBP
#   reduced/VBN
#   (mychunk importing/JJ foreign/JJ)
#   (mychunk oil/NN last/JJ)
#   (mychunk year/NN)
#   alone/RB
#   onethird/RB
#   imported/VBN
#   (mychunk today/NN)
#   million/CD
#   (mychunk barrels/NNS oil/NN)
#   less/RBR
#   (mychunk day/NN year/NN)
#   ago/RB
#   (mychunk commitment/VBD)
#   opening/VBG
#   (mychunk bright/JJ)
#   (mychunk vista/NN nation/NN future/NN)
#   windfall/VB
#   (mychunk profits/NNS tax/NN base/NN opportunity/NN)
#   use/VBP
#   (mychunk american/JJ)
#   (mychunk technology/NN american/JJ)
#   (mychunk ability/NN american/JJ natural/JJ)
#   (mychunk resources/NNS)
#   expand/VBP
#   rapidly/RB
#   (mychunk production/NN synthetic/JJ)
#   (mychunk fuels/NNS)
#   yes/RB
#   expand/VBP
#   rapidly/RB
#   (mychunk production/NN solar/JJ)
#   (mychunk energy/NN yes/NNS)
#   also/RB
#   produce/VBP
#   (mychunk conventional/JJ)
#   (mychunk kinds/NNS american/JJ)
#   (mychunk energy/NN)
#   drill/VB
#   (mychunk
#     oil/NN
#     gas/NN
#     wells/NNS
#     year/NN
#     year/NN
#     history/NN
#     we'll/NN
#     produce/NN
#     coal/NN
#     year/NN
#     year/NN
#     history/NN)
#   we're/IN
#   exporting/VBG
#   (mychunk coal/NN year/NN year/NN history/NN opportunity/NN)
#   improved/VBN
#   (mychunk transportation/NN systems/NNS)
#   improved/VBN
#   (mychunk loading/JJ)
#   (mychunk facilities/NNS ports/NNS)
#   see/VBP
#   (mychunk good/JJ)
#   (mychunk opportunity/NN world/NN international/JJ)
#   (mychunk market/NN)
#   replace/VB
#   (mychunk opec/JJ)
#   (mychunk oil/NN american/JJ)
#   (mychunk coal/NN basic/JJ)
#   (mychunk energy/NN source/NN)
#   exciting/VBG
#   (mychunk future/JJ)
#   give/VBP
#   us/PRP
#   (mychunk energy/NN security/NN)
#   also/RB
#   (mychunk open/JJ vast/JJ)
#   (mychunk opportunities/NNS)
#   americans/VBP
#   (mychunk live/JJ better/JJR)
#   (mychunk life/NN millions/NNS new/JJ)
#   (mychunk jobs/NNS)
#   associated/VBN
#   (mychunk new/JJ dynamic/JJ)
#   (mychunk industry/NN)
#   prospect/VBP
#   (mychunk new/JJ)
#   (mychunk energy/NN policy/NN we've/NN put/VBD)
#   (mychunk effect/NN yes/NN sir/NN repeat/NN year/NN opportunity/NN)
#   we'll/VBP
#   realize/VB
#   (mychunk produce/NN)
#   million/CD
#   (mychunk tons/NNS coal/NN unequaled/JJ)
#   (mychunk record/NN history/NN country/NN governor/NN reagan/NN)
#   says/VBZ
#   (mychunk good/JJ)
#   (mychunk achievement/NN)
#   blames/VBZ
#   (mychunk
#     restraints/NNS
#     coal/NN
#     production/NN
#     regulations/NNS
#     regulations/NNS)
#   affect/VBP
#   (mychunk life/NN health/NN safety/NN miners/NNS)
#   also/RB
#   (mychunk regulations/NNS)
#   protect/VBP
#   (mychunk
#     purity/NN
#     air/NN
#     quality/NN
#     water/NN
#     land/NN
#     cannot/NN
#     cast/VBD
#     aside/JJ)
#   (mychunk regulations/NNS chance/NN next/JJ)
#   (mychunk years/NNS)
#   insisting/VBG
#   upon/IN
#   (mychunk health/NN safety/NN workers/NNS mines/NNS)
#   also/RB
#   preserving/VBG
#   (mychunk high/JJ)
#   (mychunk air/NN water/NN pollution/NN standards/NNS triple/JJ)
#   (mychunk amount/NN coal/NN)
#   produce/VBP
#   (mychunk governor/NN reagan's/NN approach/NN energy/NN policy/NN)
#   already/RB
#   proven/RB
#   (mychunk effectiveness/JJ)
#   (mychunk repeal/NN change/NN)
#   substantially/RB
#   (mychunk windfall/JJ)
#   (mychunk profits/NNS tax/NN return/NN major/JJ)
#   (mychunk portion/NN)
#   billion/CD
#   back/RB
#   (mychunk oil/NN companies/NNS)
#   away/RP
#   (mychunk department/NN energy/NN shortcircuit/NN synthetic/JJ)
#   (mychunk fuels/NNS program/NN)
#   put/VBN
#   (mychunk minimal/JJ)
#   (mychunk emphasis/NN solar/JJ)
#   (mychunk power/NN)
#   emphasize/VB
#   strongly/RB
#   (mychunk nuclear/JJ)
#   (mychunk powerplants/NNS major/JJ)
#   (mychunk source/NN energy/NN future/NN)
#   wants/VBZ
#   put/VBN
#   (mychunk eggs/NNS)
#   one/CD
#   (mychunk basket/NN)
#   give/VB
#   (mychunk basket/NN major/JJ)
#   (mychunk oil/NN companies/NNS)
#   sure/VBP
#   (mychunk matter/JJ)
#   (mychunk fact/NN air/NN pollution/NN standard/NN laws/NNS)
#   passed/VBN
#   (mychunk california/NN passed/VBD)
#   (mychunk objections/NNS governor/NN)
#   reagan/VBP
#   well/RB
#   known/VBN
#   (mychunk fact/NN)
#   also/RB
#   recently/RB
#   (mychunk someone/NN suggested/VBD occupational/JJ)
#   (mychunk safety/NN health/NN act/NN abolished/VBD)
#   (mychunk governor/NN reagan/NN responded/VBD)
#   (mychunk amen/NNS)
#   offshore/RB
#   drilling/VBG
#   (mychunk rights/NNS question/NN governor/NN reagan/NN)
#   raises/VBZ
#   often/RB
#   (mychunk matter/JJ)
#   (mychunk fact/NN proposal/NN)
#   alaska/IN
#   (mychunk lands/NNS legislation/NN percent/NN)
#   offshore/IN
#   (mychunk lands/NNS)
#   would/MD
#   open/VB
#   (mychunk exploration/NN percent/NN alaska/NN)
#   lands/VBZ
#   suspected/VBN
#   (mychunk believed/JJ)
#   (mychunk minerals/NNS)
#   might/MD
#   exist/VB
#   (mychunk year/NN plan/NN)
#   leasing/VBG
#   (mychunk offshore/JJR)
#   (mychunk lands/NNS)
#   proposed/VBN
#   (mychunk land/NN)
#   drilled/VBN
#   (mychunk opened/VBD)
#   drilling/VBG
#   since/IN
#   (mychunk program/NN)
#   first/RB
#   (mychunk started/VBD we're/JJ)
#   putting/VBG
#   (mychunk restraints/NNS american/JJ)
#   (mychunk exploration/NN we're/NN)
#   encouraging/VBG
#   every/DT
#   (mychunk way/NN long/JJ)
#   (mychunk there's/NN president/NN white/JJ)
#   (mychunk house/NN strong/JJ viable/JJ social/JJ)
#   (mychunk security/NN system/NN free/JJ)
#   (mychunk threat/NN bankruptcy/NN)
#   although/IN
#   (mychunk governor/NN reagan/NNS changed/VBD)
#   (mychunk position/NN)
#   lately/RB
#   four/CD
#   (mychunk different/JJ)
#   (mychunk occasions/NNS advocated/VBD)
#   making/VBG
#   (mychunk social/JJ)
#   (mychunk security/NN voluntary/JJ)
#   (mychunk system/NN)
#   would/MD
#   (mychunk effect/NN)
#   quickly/RB
#   bankrupt/VB
#   (mychunk noticed/NNS)
#   also/RB
#   wall/VBP
#   (mychunk street/NN journal/NN)
#   earlier/RBR
#   (mychunk week/NN preliminary/JJ)
#   (mychunk report/NN task/NN force/NN)
#   advocates/VBZ
#   making/VBG
#   (mychunk social/JJ)
#   (mychunk security/NN sound/NN)
#   reducing/VBG
#   (mychunk adjustments/NNS social/JJ)
#   (mychunk security/NN retired/VBD)
#   (mychunk people/NNS compensate/JJ)
#   (mychunk impact/NN inflation/NN)
#   kinds/VBZ
#   (mychunk approaches/NNS dangerous/JJ)
#   (mychunk security/NN well-being/JJ)
#   (mychunk peace/NN mind/NN retired/JJ)
#   (mychunk people/NNS country/NN)
#   approaching/VBG
#   (mychunk retirement/NN age/NN matter/NN)
#   takes/VBZ
#   (mychunk future/JJ)
#   keep/VB
#   (mychunk social/JJ)
#   (mychunk security/NN sound/NN)
#   must/MD
#   kept/VB
#   (mychunk way/NN)
#   although/IN
#   (mychunk serious/JJ)
#   (mychunk threat/NN social/JJ)
#   (mychunk security/NN system/NN integrity/NN campaign/NN became/VBD)
#   (mychunk president/NN action/NN congress/NN)
#   working/VBG
#   put/VBN
#   (mychunk social/JJ)
#   (mychunk security/NN)
#   back/RB
#   (mychunk sound/JJ financial/JJ)
#   (mychunk basis/NN that's/NN way/NN)
#   stay/VBP
#   (mychunk fine/JJ constant/JJ)
#   (mychunk suggestions/NNS basic/JJ social/JJ)
#   (mychunk security/NN system/NN changed/VBD)
#   (mychunk cause/NN concern/NN consternation/NN)
#   among/IN
#   (mychunk aged/JJ)
#   (mychunk country/NN obvious/JJ commitment/JJ social/JJ)
#   (mychunk security/NN benefits/NNS)
#   taxed/VBN
#   would/MD
#   peremptory/VB
#   (mychunk change/NN standards/NNS social/JJ)
#   (mychunk security/NN payments/NNS)
#   made/VBN
#   (mychunk retired/JJ)
#   (mychunk people/NNS)
#   also/RB
#   need/VBP
#   continue/VBP
#   (mychunk index/NN social/JJ)
#   (mychunk security/NN payments/NNS inflation/NN)
#   rises/VBZ
#   (mychunk social/JJ)
#   (mychunk security/NN payments/NNS)
#   would/MD
#   rise/VB
#   (mychunk commensurate/NN degree/NN let/VBD)
#   buying/VBG
#   (mychunk power/NN social/JJ)
#   (mychunk security/NN check/NN)
#   continue/VBP
#   (mychunk intact/JJ)
#   past/IN
#   (mychunk relationship/NN social/JJ)
#   (mychunk security/NN medicare/NN important/JJ)
#   (mychunk provide/NN modicum/NN aid/NN senior/JJ)
#   (mychunk citizens/NNS retention/NN health/NN benefits/NNS)
#   governor/VBP
#   (mychunk reagan/JJ)
#   (mychunk matter/NN fact/NN began/VBD political/JJ)
#   (mychunk career/NN)
#   campaigning/VBG
#   around/IN
#   (mychunk nation/NN medicare/NN opportunity/NN)
#   move/VBP
#   toward/IN
#   (mychunk national/JJ)
#   (mychunk
#     health/NN
#     insurance/NN
#     emphasis/NN
#     prevention/NN
#     disease/NN
#     emphasis/NN
#     outpatient/NN
#     care/NN
#     inpatient/NN
#     care/NN
#     emphasis/NN
#     hospital/NN
#     cost/NN
#     containment/NN
#     hold/NN
#     cost/NN
#     hospital/NN
#     care/NN
#     ill/JJ)
#   (mychunk emphasis/NN catastrophic/JJ)
#   (mychunk health/NN insurance/NN family/NN threatened/VBD)
#   wiped/VBN
#   economically/RB
#   (mychunk high/JJ medical/JJ)
#   (mychunk bill/NN insurance/NN)
#   would/MD
#   help/VB
#   pay/VB
#   (mychunk kind/NN elements/NNS national/JJ)
#   (mychunk health/NN insurance/NN important/JJ american/JJ)
#   (mychunk people/NNS)
#   governor/VBP
#   (mychunk reagan/JJ)
#   typically/RB
#   (mychunk proposal/NN)
#   think/VBP
#   debate/VB
#   (mychunk social/JJ)
#   (mychunk security/NN medicare/NNP national/JJ)
#   (mychunk health/NN insurance/NN typifies/NNS)
#   vividly/RB
#   (mychunk subject/JJ)
#   (mychunk tonight/NN basic/JJ historical/JJ)
#   (mychunk differences/NNS party/NN party/NN allusions/NNS basic/JJ)
#   (mychunk changes/NNS minimum/JJ)
#   (mychunk wage/NN)
#   another/DT
#   (mychunk deleterious/JJ)
#   (mychunk comments/NNS governor/NN reagan/NN made/VBD)
#   (mychunk unemployment/NN compensation/NN commitments/NNS party/NN)
#   historically/RB
#   (mychunk made/VBD)
#   working/VBG
#   (mychunk families/NNS nation/NN)
#   extremely/RB
#   (mychunk important/JJ)
#   (mychunk growth/NN stature/NN)
#   better/RBR
#   (mychunk quality/NN life/NN noticed/VBD)
#   recently/RB
#   governor/VBN
#   (mychunk reagan/NN)
#   frequently/RB
#   quotes/VBZ
#   (mychunk presidents/NNS acceptance/NN address/NN)
#   otherwise/RB
#   never/RB
#   heard/VBN
#   (mychunk candidate/NN president/NN)
#   quote/VB
#   (mychunk president/NN)
#   get/VB
#   (mychunk office/NN try/NN)
#   govern/VBP
#   like/IN
#   (mychunk republicans/NNS good/JJ american/JJ)
#   (mychunk people/NNS)
#   remember/VBP
#   (mychunk sharp/JJ basic/JJ historical/JJ)
#   (mychunk
#     difference/NN
#     governor/NN
#     reagan/JJ
#     crucial/JJ
#     issues-also/JJ)
#   two/CD
#   (mychunk parties/NNS)
#   represent/VBP
#   (mychunk â/JJ)
#   (mychunk
#     mr/NN
#     smith/NN
#     thank/NN
#     mr/NN
#     president/NN
#     governor/NN
#     reagan/NN
#     â/NNP)
#   go/VBP
#   another/DT
#   (mychunk
#     question/NN
#     question/NN
#     president/NN
#     carter/NN
#     barbara/NN
#     walters/NNS)
#   assessments/VBP
#   (mychunk opponent/JJ)
#   (mychunk barbara/NN reluctant/JJ)
#   say/VBP
#   (mychunk anything/NN critical/JJ)
#   (mychunk governor/NN reagan/JJ)
#   try/VB
#   (mychunk answer/JJR)
#   (mychunk question/NN laughter/NN)
#   first/RB
#   (mychunk there's/JJ historical/JJ)
#   (mychunk perspective/NN)
#   described/VBN
#   (mychunk contest/JJ)
#   (mychunk democrat/NN mainstream/NN party/NN exemplified/VBD)
#   (mychunk actions/NNS)
#   i've/VBP
#   taken/VBN
#   (mychunk oval/JJ)
#   (mychunk office/NN last/JJ)
#   (mychunk years/NNS contrasted/VBD)
#   (mychunk governor/NN reagan/NN cases/NNS)
#   typify/VBP
#   (mychunk party/NN cases/NNS radical/JJ)
#   (mychunk
#     departure/NN
#     heritage/NN
#     eisenhower/NN
#     others/NNS
#     important/JJ
#     crucial/JJ)
#   (mychunk
#     difference/NN
#     election/NN
#     campaign/NN
#     judgment/NN
#     approach/NN
#     control/NN
#     nuclear/JJ
#     weaponry/JJ)
#   (mychunk inclination/NN control/NN control/NN)
#   spread/VBP
#   (mychunk atomic/JJ)
#   (mychunk weapons/NNS nations/NNS)
#   presently/RB
#   particularly/RB
#   (mychunk terrorist/JJ)
#   (mychunk
#     nations/NNS
#     inclination/NN
#     governor/NN
#     reagan/VBD
#     exemplified/VBD
#     many/JJ
#     troubled/JJ)
#   (mychunk times/NNS)
#   since/IN
#   (mychunk he's/NN)
#   running/VBG
#   (mychunk president/NN think/NN)
#   since/IN
#   (mychunk inject/JJ american/JJ military/JJ)
#   (mychunk forces/NNS places/NNS)
#   like/IN
#   (mychunk north/JJ)
#   korea/FW
#   (mychunk put/NN blockade/NN)
#   around/IN
#   (mychunk cuba/JJ)
#   (mychunk year/NN instances/NNS)
#   project/VBP
#   (mychunk american/JJ)
#   (mychunk forces/NNS)
#   fishing/VBG
#   (mychunk dispute/NN small/JJ)
#   (mychunk nation/NN ecuador/NN west/JJS)
#   (mychunk coast/NN south/NN america/JJ typical/JJ)
#   (mychunk longstanding/NN inclination/NN)
#   use/IN
#   (mychunk american/JJ)
#   (mychunk power/NN resolve/NN)
#   disputes/VBZ
#   diplomatically/RB
#   peacefully/RB
#   show/VBP
#   exercise/RB
#   (mychunk military/JJ)
#   (mychunk power/NN best/JJS)
#   proven/RB
#   (mychunk actual/JJ)
#   (mychunk use/NN)
#   obviously/RB
#   (mychunk president/NN)
#   wants/VBZ
#   (mychunk war/NN)
#   certainly/RB
#   believe/VBP
#   (mychunk governor/NN reagan/JJ)
#   (mychunk president/NN)
#   would/MD
#   want/VB
#   (mychunk war/NN president/NN oval/JJ)
#   (mychunk office/NN make/NN judgment/NN)
#   almost/RB
#   (mychunk daily/JJ)
#   (mychunk basis/NN exercise/NN enormous/JJ)
#   (mychunk power/NN country/NN peace/NN diplomacy/NN careless/JJ)
#   (mychunk way/NN belligerent/JJ)
#   (mychunk attitude/NN exemplified/VBD)
#   (mychunk attitudes/NNS past/JJ)
#   (mychunk yes/NNS mentioned/VBD radical/JJ)
#   (mychunk departure/NN governor/NN reagan/JJ)
#   (mychunk principles/NNS ideals/NNS historical/JJ perspective/JJ)
#   (mychunk party/NN)
#   think/VBP
#   better/RB
#   illustrated/VBN
#   (mychunk case/NN)
#   guaranteeing/VBG
#   (mychunk women/NNS equal/JJ)
#   (mychunk
#     rights/NNS
#     constitution/NN
#     nation/NN
#     years/NNS
#     party/NN
#     platforms/NNS
#     called/VBD)
#   guaranteeing/VBG
#   (mychunk women/NNS equal/JJ)
#   (mychunk rights/NNS constitutional/JJ)
#   (mychunk amendment/NN)
#   six/CD
#   (mychunk predecessors/NNS)
#   mine/VBP
#   served/VBN
#   (mychunk oval/JJ)
#   (mychunk office/NN)
#   called/VBN
#   (mychunk guarantee/NN women's/NN rights/NNS)
#   governor/VBP
#   (mychunk reagan/JJ new/JJ)
#   (mychunk party/NN departed/VBD)
#   (mychunk commitment/NN)
#   severe/RB
#   (mychunk blow/JJ)
#   (mychunk opportunity/NN women/NNS)
#   finally/RB
#   (mychunk correct/JJ)
#   (mychunk discrimination/NN suffered/VBD)
#   (mychunk man/NN woman/NN amount/NN work/NN man/NN)
#   gets/VBZ
#   paid/VBN
#   (mychunk dollar/NN woman/NN)
#   gets/VBZ
#   paid/VBN
#   (mychunk cents/NNS equal/JJ)
#   (mychunk rights/NNS amendment/NN)
#   says/VBZ
#   (mychunk equality/NN rights/NNS)
#   shall/MD
#   abridged/VB
#   (mychunk women/NNS federal/JJ)
#   (mychunk government/NN state/NN governments/NNS)
#   that's/VBP
#   says/VBZ
#   (mychunk simple/JJ)
#   (mychunk
#     guarantee/NN
#     equality/NN
#     opportunity/NN
#     typifies/NNS
#     party/NN
#     important/JJ)
#   (mychunk commitment/NN mine/NN)
#   contrasted/VBN
#   (mychunk governor/NN reagan's/NN radical/JJ)
#   (mychunk departure/NN longstanding/NN policy/NN party/NN)
#   yes/RB
#   (mychunk howard/JJ)
#   (mychunk i'm/NN southerner/NN share/NN basic/JJ beliefs/JJ)
#   (mychunk region/NN excessive/JJ)
#   (mychunk government/NN intrusion/NN private/JJ)
#   (mychunk affairs/NNS american/JJ)
#   (mychunk citizens/NNS)
#   also/RB
#   (mychunk private/JJ)
#   (mychunk affairs/NNS free/JJ)
#   (mychunk enterprise/NN system/NN)
#   one/CD
#   (mychunk commitments/NNS)
#   made/VBN
#   (mychunk deregulate/NN major/JJ)
#   (mychunk industries/NNS country/NN)
#   we've/VBZ
#   remarkably/RB
#   (mychunk successful/JJ)
#   (mychunk help/NN congress/NN we've/NN)
#   deregulated/VBN
#   (mychunk
#     air/NN
#     industry/NN
#     rail/NN
#     industry/NN
#     trucking/NN
#     industry/NN
#     financial/JJ)
#   (mychunk institutions/NNS)
#   working/VBG
#   (mychunk communications/NNS industry/NN addition/NN)
#   believe/VBP
#   (mychunk element/NN discrimination/NN something/NN south/JJ)
#   seen/VBN
#   vividly/RB
#   (mychunk blight/JJ)
#   (mychunk region/NN country/NN corrected/VBD racial/JJ)
#   (mychunk discrimination/NN discrimination/NN people/NNS)
#   work/VBP
#   living/VBG
#   trying/VBG
#   (mychunk pick/JJ)
#   (mychunk bootstraps/NNS)
#   since/IN
#   (mychunk long/JJ)
#   (mychunk depression/NN years/NNS)
#   lead/VBP
#   (mychunk full/JJ useful/JJ)
#   (mychunk life/NN affairs/NNS country/NN we've/VBD)
#   made/VBN
#   (mychunk remarkable/JJ)
#   (mychunk success/NN part/NN consciousness/NN commitment/NN)
#   continue/VBP
#   (mychunk
#     progress/NN
#     heritage/NN
#     southerner/NN
#     experience/NN
#     oval/JJ)
#   (mychunk office/NN convinces/NNS)
#   i've/VBP
#   described/VBN
#   (mychunk proper/JJ)
#   (mychunk course/NN future/NN)
#   first/RB
#   i'd/VBZ
#   like/IN
#   (mychunk thank/NN league/NN women/NNS voters/NNS)
#   making/VBG
#   (mychunk debate/NN possible/JJ)
#   (mychunk think/NN constructive/JJ)
#   (mychunk debate/NN hope/NN helped/VBD)
#   acquaint/VB
#   (mychunk american/JJ)
#   (mychunk people/NNS sharp/JJ)
#   (mychunk differences/NNS governor/NN reagan/NNS)
#   also/RB
#   want/VBP
#   (mychunk thank/JJ)
#   (mychunk people/NNS)
#   cleveland/VBP
#   ohio/RB
#   (mychunk hospitable/JJ)
#   (mychunk hosts/NNS last/JJ)
#   (mychunk hours/NNS life/NN i've/NN president/NN)
#   almost/RB
#   (mychunk years/NNS)
#   i've/VBP
#   make/VB
#   (mychunk thousands/NNS decisions/NNS)
#   one/CD
#   (mychunk decisions/NNS)
#   learning/VBG
#   (mychunk process/NN i've/NN)
#   seen/VBN
#   (mychunk strength/NN nation/NN i've/NN)
#   seen/VBN
#   (mychunk crises/NNS approached/VBD tentative/JJ)
#   (mychunk way/NN i've/JJ)
#   (mychunk deal/NN crises/NNS)
#   best/RB
#   could/MD
#   i've/VB
#   studied/VBN
#   (mychunk record/NN governor/NN reagan/JJ)
#   (mychunk i've/NN)
#   impressed/VBN
#   (mychunk stark/JJ)
#   (mychunk differences/NNS)
#   exist/VBP
#   us/PRP
#   think/VBP
#   (mychunk results/NNS)
#   debate/VB
#   (mychunk indicate/JJ)
#   (mychunk fact/NN true/JJ)
#   (mychunk consider/NN mainstream/NN party/NN)
#   consider/VBP
#   (mychunk mainstream/JJ)
#   even/RB
#   (mychunk bipartisan/JJ)
#   (mychunk list/NN presidents/NNS)
#   who've/VBP
#   served/VBN
#   (mychunk united/JJ)
#   (mychunk states/NNS)
#   must/MD
#   (mychunk nation/NN strong/JJ united/JJ)
#   (mychunk states/NNS)
#   must/MD
#   (mychunk nation/NN)
#   secure/VB
#   must/MD
#   society/VB
#   (mychunk that's/JJ fair/JJ)
#   must/MD
#   extend/VB
#   (mychunk benefits/NNS commitment/JJ)
#   (mychunk peace/NN create/NN peaceful/JJ)
#   (mychunk world/NN)
#   believe/VBP
#   since/IN
#   (mychunk i've/NN office/NN there've/NN)
#   six/CD
#   eight/CD
#   (mychunk areas/NNS combat/NN evolve/NN parts/NNS world/NN case/NN)
#   alone/RB
#   (mychunk determine/JJ)
#   (mychunk interests/NNS country/NN)
#   degree/VBP
#   (mychunk involvement/JJ)
#   (mychunk country/NN)
#   i've/VB
#   done/VBN
#   (mychunk moderation/NN care/NN thoughtfulness/NN)
#   sometimes/RB
#   consulting/VBG
#   (mychunk experts/NNS i've/NN)
#   learned/VBN
#   (mychunk last/JJ)
#   (mychunk years/NNS)
#   issue/VBP
#   extremely/RB
#   (mychunk difficult/JJ)
#   (mychunk call/NN close/JJ)
#   (mychunk chances/NNS experts/NNS divided/VBD)
#   almost/RB
#   (mychunk final/JJ)
#   (mychunk judgment/NN future/JJ)
#   (mychunk
#     nation/NN
#     war/NN
#     peace/NN
#     involvement/NN
#     reticence/NN
#     thoughtfulness/NN
#     care/NN
#     consideration/NN
#     concern/NN)
#   made/VBN
#   (mychunk man/NN oval/JJ)
#   (mychunk office/NN)
#   lonely/RB
#   (mychunk job/NN involvement/JJ american/JJ)
#   (mychunk people/NNS)
#   process/IN
#   (mychunk open/JJ)
#   (mychunk government/NN job/NN)
#   gratifying/VBG
#   one/CD
#   (mychunk american/JJ)
#   (mychunk people/NNS)
#   facing/VBG
#   (mychunk next/JJ)
#   (mychunk tuesday/NN lonely/JJ)
#   (mychunk decision/NN)
#   listening/VBG
#   (mychunk voice/NNS)
#   make/VBP
#   (mychunk judgment/JJ future/JJ)
#   (mychunk country/NN)
#   think/VBP
#   ought/MD
#   remember/VB
#   one/CD
#   (mychunk vote/NN)
#   make/VBP
#   (mychunk lot/NN difference/NN)
#   one/CD
#   (mychunk vote/NN)
#   per/IN
#   (mychunk precinct/NN changed/VBD john/JJ)
#   (mychunk kennedy/NN)
#   would/MD
#   never/RB
#   (mychunk president/NN nation/NN people/NNS)
#   gone/VBN
#   (mychunk polls/NNS voted/VBD hubert/JJ)
#   (mychunk humphrey/NN)
#   would/MD
#   (mychunk president/NN)
#   richard/VB
#   (mychunk nixon/NN)
#   would/MD
#   (mychunk partnership/NN)
#   involved/VBN
#   (mychunk nation/NN stay/NN strong/JJ)
#   (mychunk stay/NN peace/NN)
#   raise/VB
#   (mychunk high/JJ)
#   (mychunk banner/NN human/JJ)
#   (mychunk rights/NNS)
#   set/VBN
#   (mychunk example/NN rest/NN world/NN let/VBD deep/JJ beliefs/JJ)
#   (mychunk commitments/NNS felt/VBD)
#   (mychunk others/NNS nations/NNS)
#   plan/VBP
#   (mychunk future/JJ ask/JJ american/JJ)
#   (mychunk people/NNS)
#   join/VBP
#   (mychunk partnership/NN john/NN b/NN anderson/NN)
#   miss/VBP
#   (mychunk loomis/NN)
#   think/VBP
#   (mychunk appropriate/JJ first/JJ)
#   (mychunk question/NN)
#   first/RB
#   (mychunk debate/NN campaign/NN relate/JJ)
#   (mychunk economy/NN country/NN)
#   seems/VBZ
#   (mychunk people/NNS)
#   watching/VBG
#   us/PRP
#   (mychunk tonight/JJ)
#   million/CD
#   (mychunk americans/NNS)
#   truly/RB
#   (mychunk concerned/JJ poor/JJ)
#   (mychunk rate/NN performance/NN american/JJ)
#   (mychunk economy/NN last/JJ)
#   four/CD
#   (mychunk years/NNS)
#   governor/VBP
#   (mychunk reagan/JJ responsible/JJ)
#   happened/VBN
#   (mychunk last/JJ)
#   four/CD
#   (mychunk years/NNS man/NN tonight/VBD)
#   (mychunk respond/NN charges/NNS)
#   chose/VBP
#   (mychunk attend/JJ)
#   want/VBP
#   (mychunk answer/NN)
#   specifically/RB
#   (mychunk question/NN put/VBD)
#   let/VB
#   tell/VB
#   first/RB
#   (mychunk oppose/JJ)
#   (mychunk election/NN year/NN tax/NN cut/NN)
#   whether/IN
#   (mychunk across-the-board/JJ)
#   (mychunk tax/NN cut/NN)
#   promised/VBN
#   (mychunk taxpayers/NNS opponent/JJ)
#   (mychunk debate/NN tonight/VBD)
#   whether/IN
#   billion/CD
#   (mychunk tax/NN cut/NN)
#   promised/VBN
#   (mychunk th/JJ august/JJ)
#   (mychunk president/NN carter/NN)
#   simply/RB
#   think/VB
#   confronting/VBG
#   (mychunk budget/NN deficit/NN year/NN fiscal/JJ)
#   (mychunk year/NN end/NN days/NNS)
#   confronted/VBN
#   (mychunk possibility/NN deficit/NN)
#   billion/CD
#   perhaps/RB
#   (mychunk much/JJ)
#   billion/CD
#   simply/RB
#   would/MD
#   irresponsible/VB
#   (mychunk printing/JJ)
#   (mychunk presses/NNS)
#   start/VBP
#   (mychunk
#     roll/NN
#     see/NN
#     monetization/NN
#     debt/NN
#     result/NN
#     higher/JJR)
#   (mychunk rate/NN inflation/NN)
#   even/RB
#   though/IN
#   (mychunk we've/NN)
#   seen/VBN
#   (mychunk hopeful/JJ)
#   (mychunk signs/NNS)
#   perhaps/RB
#   (mychunk flash/JJ)
#   (mychunk report/NN third/JJ)
#   (mychunk quarter/NN)
#   perhaps/RB
#   (mychunk economy/NN)
#   coming/VBG
#   (mychunk recession/NN we've/NN)
#   also/RB
#   seen/VBN
#   (mychunk rise/NN rate/NN prime/JJ)
#   seen/VBN
#   (mychunk mortgage/NN rates/NNS)
#   back/RB
#   (mychunk sure/JJ)
#   (mychunk sign/NN inflation/NN housing/NN industry/NN)
#   would/MD
#   propose/VB
#   (mychunk proposed/JJ)
#   (mychunk way/NN)
#   back/RB
#   (mychunk march/JJ)
#   (mychunk candidate/NN state/NN illinois/NNS proposed/VBD)
#   billion/CD
#   specifically/RB
# ...
#     loan/NN
#     guarantees/NNS
#     direct/JJ)
#   (mychunk loans/NNS credits/NNS)
#   i'm/VBP
#   (mychunk happy/JJ)
#   say/VBP
#   (mychunk contrast/JJ anderson-lucey/JJ)
#   (mychunk platform/NN america/NN program/NN)
#   devoted/VBN
#   (mychunk considerable/JJ)
#   (mychunk time/NN specific/JJ)
#   (mychunk detail/NN talked/VBD)
#   two/CD
#   (mychunk things/NNS)
#   ought/MD
#   done/VBN
#   (mychunk aid/NN urban/NN)
#   america/IN
#   (mychunk call/NN first/JJ)
#   (mychunk creation/NN)
#   billion/CD
#   (mychunk urban/JJ)
#   (mychunk reinvestment/NN trust/NN fund/NN)
#   exactly/RB
#   (mychunk spoke/VBD)
#   (mychunk question/NN rebuild/NN streets/NNS)
#   rebuild/VBP
#   (mychunk cities/NNS)
#   leaking/VBG
#   (mychunk water/NN mains/NNS north/JJ)
#   pittsburgh/RB
#   think/VBP
#   (mychunk weeks/NNS)
#   ago/RB
#   (mychunk campaign/NN water/NN mains/NNS city/NN)
#   begun/VBN
#   (mychunk leak/JJ)
#   literally/RB
#   (mychunk money/NN available/JJ fix/JJ)
#   (mychunk begin/NN)
#   recreate/VBP
#   (mychunk basic/JJ)
#   (mychunk infrastructure/NN great/JJ)
#   (mychunk cities/NNS)
#   america/VBP
#   particularly/RB
#   (mychunk upper/JJ midwest/JJS)
#   (mychunk northeast/NN)
#   simply/RB
#   going/VBG
#   provide/IN
#   (mychunk kind/NN economic/JJ)
#   (mychunk climate/NN enable/JJ)
#   (mychunk retain/NN industry/NN enable/JJ)
#   (mychunk retain/NN kind/NN solid/JJ industrial/JJ)
#   (mychunk base/NN)
#   need/MD
#   provide/VB
#   (mychunk jobs/NNS)
#   also/RB
#   provided/VBN
#   (mychunk program/NN)
#   billion/CD
#   (mychunk community/NN trust/NN fund/NN we've/NN told/VBD)
#   (mychunk money/NN)
#   coming/VBG
#   going/VBG
#   (mychunk come/JJ)
#   (mychunk dedication/NN excise/NN revenues/NNS today/NN)
#   collected/VBN
#   (mychunk federal/JJ)
#   (mychunk government/NN alcohol/NN tobacco/NN money/NN)
#   think/VBP
#   ought/MD
#   put/VB
#   rebuilding/VBG
#   (mychunk base/NN cities/NNS addition/NN jobs/NNS programs/NNS)
#   re-employ/VBP
#   (mychunk youth/JJ)
#   (mychunk cities/NNS)
#   would/MD
#   high/VB
#   (mychunk priority/NN list/NN youth/NN opportunities/NNS)
#   act/VBP
#   (mychunk billion-dollar/JJ)
#   (mychunk program/NN)
#   would/MD
#   recommend/VB
#   put/VB
#   youth/PRP
#   work/VB
#   (mychunk energy/NN projects/NNS)
#   conservation/VBP
#   (mychunk projects/NNS projects/NNS)
#   would/MD
#   carry/VB
#   (mychunk great/JJ national/JJ)
#   (mychunk goals/NNS country/NN)
#   well/RB
#   (mychunk course/NN private/JJ)
#   (mychunk sector/NN governor/NN reagan/JJ)
#   (mychunk years/NNS cities/NNS)
#   deteriorating/VBG
#   seems/VBZ
#   (mychunk deny/JJ)
#   (mychunk responsibility/NN federal/JJ)
#   (mychunk government/NN something/NN)
#   crumbling/VBG
#   (mychunk cities/NNS)
#   deny/VBP
#   (mychunk opportunity/NN)
#   one/CD
#   (mychunk thing/NN black/JJ)
#   (mychunk population/NN country/NN locked/VBD)
#   within/IN
#   (mychunk inner/JJ)
#   (mychunk cities/NNS)
#   metropolitan/VBP
#   (mychunk areas/NNS country/NN)
#   simply/RB
#   (mychunk cannot/JJ)
#   (mychunk ignore/NN fact/NN cities/NNS today/NN)
#   youth/VBP
#   (mychunk unemployment/NN)
#   among/IN
#   (mychunk black/JJ hispanic/JJ)
#   (mychunk youth/NN lost/VBD)
#   (mychunk industry/NN lost/VBD)
#   (mychunk industry/NN)
#   longer/RBR
#   (mychunk present/JJ)
#   (mychunk kind/NN viable/JJ economic/JJ)
#   (mychunk climate/NN)
#   makes/VBZ
#   (mychunk possible/JJ)
#   (mychunk industry/NN)
#   remain/VBP
#   (mychunk locate/JJ think/JJ)
#   (mychunk government/NN responsibility/NN)
#   find/VBP
#   (mychunk jobs/NNS)
#   youth/RB
#   (mychunk country/NN place/JJ)
#   start/VBP
#   assist/VB
#   (mychunk important/JJ necessary/JJ)
#   (mychunk task/NN)
#   helping/VBG
#   (mychunk cities/NNS)
#   rebuild/VBP
#   (mychunk miss/JJ)
#   (mychunk quinn/NN)
#   would/MD
#   happy/VB
#   accept/IN
#   (mychunk challenge/JJ)
#   (mychunk question/NN tonight/NN tell/NN voters/NNS country/NN)
#   exactly/RB
#   think/VBP
#   going/VBG
#   (mychunk cost/NN)
#   believe/VBP
#   often/RB
#   (mychunk past/JJ)
#   (mychunk elections/NNS politicians/NNS)
#   simply/RB
#   promising/VBG
#   (mychunk people/NNS things/NNS)
#   cannot/VBP
#   deliver/RB
#   (mychunk presidential/JJ)
#   (mychunk debates/NNS held/VBD)
#   four/CD
#   (mychunk years/NNS)
#   ago/RB
#   remember/VB
#   (mychunk incumbent/JJ)
#   (mychunk president/NN willing/JJ)
#   (mychunk debate/NN president/NN ford/NN telling/JJ american/JJ)
#   (mychunk people/NNS)
#   simply/RB
#   (mychunk ought/JJ)
#   (mychunk vote/NN somebody/NN promised/VBD)
#   could/MD
#   deliver/VB
#   well/RB
#   we've/RB
#   seen/VBN
#   happened/VBN
#   gotten/RBR
#   (mychunk either/CC)
#   (mychunk economies/JJ)
#   (mychunk government/NN promised/VBD gotten/JJ)
#   (mychunk inflation/NN supposed/VBD)
#   get/VB
#   (mychunk end/JJ)
#   (mychunk mr/NN carter's/NN first/JJ)
#   (mychunk term/NN)
#   instead/RB
#   think/VBP
#   (mychunk second/JJ)
#   (mychunk quarter/NN consumer/NN price/NN index/NN)
#   registering/VBG
#   around/IN
#   (mychunk nobody/NN)
#   really/RB
#   knows/VBZ
#   (mychunk latest/JJS)
#   (mychunk increase/NN wholesale/JJ)
#   (mychunk price/NN index/NN that's/VBD)
#   annualized/VBN
#   (mychunk basis/NN)
#   going/VBG
#   (mychunk let/NNS)
#   say/VB
#   think/VB
#   (mychunk programs/NNS)
#   far/RB
#   (mychunk less/JJR inflationary/JJ)
#   (mychunk governor/NN reagan/NN)
#   running/VBG
#   (mychunk mate/NN)
#   running/VBG
#   (mychunk presidency/NN said/VBD)
#   would/MD
#   cost/VB
#   (mychunk inflation/NN)
#   inside/IN
#   two/CD
#   (mychunk years/NNS cited/VBD leading/JJ economic/JJ)
#   (mychunk advisor/NN)
#   distinguished/VBN
#   (mychunk
#     economist/NN
#     paul/NN
#     macavoy/NN
#     source/NN
#     information/NN
#     went/VBD)
#   far/RB
#   (mychunk call/JJ brutal/JJ)
#   (mychunk economics/NNS)
#   i've/VBP
#   (mychunk careful/JJ careful/JJ)
#   saying/VBG
#   (mychunk i'm/NN)
#   going/VBG
#   (mychunk bring/JJ federal/JJ)
#   (mychunk spending/NN control/NN)
#   first/RB
#   would/MD
#   like/VB
#   stand/VB
#   (mychunk promise/JJ american/JJ)
#   (mychunk people/NNS tax/NN cut/NN governor/NN)
#   reagan/VBZ
#   done/VBN
#   (mychunk know/JJ)
#   (mychunk
#     gotten/NNS
#     difference/NN
#     somebody/NN
#     worked/VBD
#     figured/JJ)
#   (mychunk tax/NN cut/NN governor/NN)
#   reagan/VBP
#   (mychunk promising/JJ american/JJ)
#   (mychunk people/NNS tax/NN cut/NN jimmy/NN carter/NN)
#   promising/VBG
#   (mychunk worth/JJ dear/JJ)
#   (mychunk voters/NNS)
#   auction/VBP
#   block/RB
#   two/CD
#   (mychunk candidates/NNS)
#   bidding/VBG
#   votes/VBZ
#   one/CD
#   going/VBG
#   (mychunk give/JJ happen/JJ)
#   (mychunk range/NN a-year/JJ)
#   (mychunk income/NN i'm/NN)
#   going/VBG
#   (mychunk wait/JJ)
#   see/VB
#   (mychunk inflation/NN rate/NN)
#   going/VBG
#   even/RB
#   begin/VB
#   (mychunk phase/NN business/NN tax/NN cuts/NNS)
#   i've/VBP
#   talked/VBN
#   think/VBP
#   improving/VBG
#   (mychunk productivity/NN)
#   would/MD
#   far/RB
#   (mychunk less/JJR inflationary/JJ consumption-oriented/JJ)
#   (mychunk tax/NN cut/NN governor/NN)
#   reagan/VBP
#   recommending/VBG
#   (mychunk mr/NN moyers/NNS)
#   i'm/VBP
#   (mychunk debate/NN governor/NN reagan's/NN record/NN governor/NN)
#   know/VBP
#   despite/IN
#   (mychunk pledge/NN)
#   reduce/VB
#   (mychunk state/NN government/NN spending/NN rose/VBD)
#   billion/CD
#   (mychunk took/VBD)
#   (mychunk office/NN)
#   billion/CD
#   eight/CD
#   (mychunk
#     years/NNS
#     office/NN
#     spending/NN
#     words/NNS
#     doubled/VBD
#     rose/VBD)
#   faster/RBR
#   (mychunk rate/NN spending/NN)
#   rising/VBG
#   (mychunk federal/JJ)
#   (mychunk government/NN optimistic/JJ)
#   (mychunk figures/NNS tax/NN cut/NN)
#   producing/VBG
#   (mychunk balanced/JJ)
#   (mychunk budget/NN fact/NN)
#   using/VBG
#   says/VBZ
#   (mychunk figures/NNS)
#   senate/VBP
#   (mychunk budget/NN committee/NN)
#   senate/VBP
#   (mychunk budget/NN committee/NN report/NN)
#   accommodate/VBP
#   reagan/VBN
#   (mychunk defense/NN plans/NNS)
#   accommodate/VBP
#   (mychunk expenditures/NNS)
#   calls/VBZ
#   (mychunk accelerated/JJ)
#   (mychunk development/NN deployment/NN new/JJ)
#   manned/VBN
#   (mychunk strategic/JJ)
#   (mychunk bomber/NN permanent/JJ)
#   (mychunk fleet/NN indian/JJ ocean/JJ)
#   (mychunk
#     restoration/NN
#     fleet/NN
#     ships/NNS
#     development/NN
#     deployment/NN)
#   dedicated/VBN
#   (mychunk modern/JJ)
#   (mychunk aircraft/NN interceptor/NN words/NNS)
#   seen/VBN
#   (mychunk program/NN)
#   costed/VBN
#   (mychunk point/NN)
#   would/MD
#   amount/VB
#   million/CD
#   (mychunk year/NN military/JJ)
#   (mychunk think/NN figures/NNS)
#   given/VBN
#   simply/RB
#   going/VBG
#   stand/VBP
#   (mychunk ms/JJ golden/JJ)
#   certainly/RB
#   (mychunk church/NN right/JJ)
#   take/VB
#   (mychunk position/NN moral/JJ)
#   (mychunk issues/NNS)
#   try/VB
#   (mychunk occurred/VBD)
#   (mychunk case/NN)
#   mentioned/VBN
#   (mychunk specific/JJ)
#   (mychunk case/NN)
#   try/VB
#   (mychunk tell/NN parishioners/NNS)
#   church/VBP
#   (mychunk denomination/NN vote/NN vote/NN)
#   think/VBP
#   violates/VBZ
#   (mychunk principle/JJ)
#   (mychunk separation/NN church/NN state/NN governor/NN reagan/NN)
#   running/VBG
#   (mychunk platform/NN)
#   calls/VBZ
#   (mychunk constitutional/JJ)
#   (mychunk amendment/NN)
#   banning/VBG
#   (mychunk abortion/NN)
#   think/VBP
#   (mychunk moral/JJ)
#   (mychunk issue/NN)
#   ought/MD
#   left/VBN
#   (mychunk freedom/NN conscience/NN individual/JJ)
#   (mychunk state/NN interfere/JJ constitutional/JJ)
#   (mychunk amendment/NN tell/NN woman/NN)
#   must/MD
#   carry/VB
#   (mychunk pregnancy/JJ)
#   (mychunk term/NN regardless/JJ personal/JJ)
#   (mychunk belief/NN)
#   think/VBP
#   violates/VBZ
#   (mychunk freedom/JJ)
#   (mychunk conscience/NN much/JJ)
#   (mychunk anything/NN think/NN)
#   also/RB
#   running/VBG
#   (mychunk platform/NN)
#   suggests/VBZ
#   (mychunk litmus/JJ)
#   (mychunk test/NN selection/NN judges/NNS judges/NNS)
#   hold/VBP
#   (mychunk certain/JJ quote/JJ)
#   (mychunk view/NN sanctity/NN family/NN life/NN)
#   ought/MD
#   appointed/VBN
#   (mychunk federal/JJ)
#   (mychunk judiciary/NN)
#   one/CD
#   three/CD
#   (mychunk great/JJ independent/JJ)
#   (mychunk branches/NNS government/NN)
#   believe/VBP
#   (mychunk freedom/NN choice/NN)
#   believe/VBP
#   (mychunk constitutional/JJ)
#   (mychunk amendments/NNS)
#   would/MD
#   interfere/VB
#   believe/VB
#   trying/VBG
#   (mychunk legislate/JJ new/JJ)
#   (mychunk tests/NNS)
#   selection/VBP
#   (mychunk federal/JJ judiciary/JJ)
#   (mychunk amendment/NN)
#   mentioned/VBN
#   abandoned/CD
#   (mychunk years/NNS)
#   ago/RB
#   (mychunk said/VBD)
#   freely/RB
#   (mychunk country/NN)
#   mistake/VB
#   (mychunk anyone/NN)
#   ever/RB
#   try/VB
#   (mychunk put/VBD judeo-christian/JJ)
#   (mychunk
#     heritage/NN
#     country/NN
#     important/JJ
#     important/JJ
#     religious/JJ)
#   (mychunk faith/NN deeply/NN personal/JJ)
#   (mychunk matter/NN)
#   try/VB
#   (mychunk pluralistic/JJ)
#   (mychunk society/NN try/NN frame/NN definition/NN)
#   whatever/WDT
#   (mychunk belief/NN wrong/JJ)
#   twice/RB
#   (mychunk voted/VBD)
#   (mychunk floor/NN house/NN representatives/NNS constitutional/JJ)
#   (mychunk amendment/NN tried/VBD)
#   (mychunk bring/NN prayer/NN)
#   back/RB
#   (mychunk public/JJ)
#   (mychunk schools/NNS)
#   think/VBP
#   mother/RB
#   ought/MD
#   whisper/VB
#   (mychunk johnny/NN susie/NN button/NN coats/NNS morning/NN)
#   leave/VBP
#   (mychunk classroom/NN sure/JJ)
#   say/VBP
#   (mychunk prayer/JJ)
#   (mychunk start/NN day's/NN work/NN)
#   think/VBP
#   (mychunk state/NN board/NN)
#   regents/VBZ
#   (mychunk board/NN education/NN state/NN official/JJ)
#   (mychunk try/NN compose/VBD prayer/JJ)
#   (mychunk child/NN recite/NN)
#   also/RB
#   think/VBP
#   (mychunk unborn/JJ)
#   (mychunk child/NN right/NN wanted/VBD)
#   also/RB
#   believe/VBP
#   (mychunk sir/JJ personal/JJ)
#   (mychunk intimate/NN decision/NN woman/NN)
#   ever/RB
#   (mychunk called/VBD)
#   (mychunk upon/NNS)
#   make/VBP
#   (mychunk decision/NN)
#   whether/IN
#   shall/MD
#   carry/VB
#   (mychunk pregnancy/JJ)
#   (mychunk term/NN state/NN interfere/JJ)
#   (mychunk decision/NN)
#   whatever/WDT
#   (mychunk guise/NN)
#   whatever/WDT
#   (mychunk rationale/JJ)
#   (mychunk state/NN try/NNS)
#   take/VBP
#   (mychunk situation/NN edict/NN command/NN individual/JJ)
#   shall/MD
#   substitute/VB
#   (mychunk individual's/JJ)
#   (mychunk conscience/NN)
#   right/RB
#   (mychunk consult/NN rabbi/JJ)
#   (mychunk
#     minister/NN
#     priest/NN
#     doctor/NN
#     counselor/NN
#     choice/NN
#     think/NN)
#   goes/VBZ
#   beyond/IN
#   (mychunk want/JJ)
#   ever/RB
#   see/VBP
#   (mychunk accomplished/JJ)
#   (mychunk country/NN)
#   really/RB
#   believe/VB
#   (mychunk first/JJ)
#   (mychunk amendment/NN)
#   really/RB
#   believe/VB
#   (mychunk freedom/NN choice/NN)
#   right/RB
#   (mychunk individual/JJ)
#   (mychunk mr/NN movers/NNS president/NN)
#   carter/RB
#   (mychunk right/JJ)
#   (mychunk weeks/NNS)
#   ago/RB
#   (mychunk said/VBD american/JJ)
#   (mychunk people/NNS confronted/VBD)
#   two/CD
#   (mychunk choices/NNS)
#   two/CD
#   (mychunk men/NNS)
#   two/CD
#   (mychunk parties/NNS)
#   think/VBP
#   seen/VBN
#   (mychunk tonight/JJ)
#   (mychunk debate/NN governor/NN)
#   reagan/VBP
#   (mychunk agreed/VBD)
#   exactly/RB
#   one/CD
#   (mychunk
#     thing/NN
#     reimposition/NN
#     peacetime/NN
#     draft/NN
#     disagreed/VBD)
#   believe/VBP
#   virtually/RB
#   every/DT
#   (mychunk issue/NN respect/NN)
#   showing/VBG
#   (mychunk tonight/JJ)
#   appearing/VBG
#   (mychunk thank/NN league/NN women/NNS voters/NNS opportunity/NN)
#   given/VBN
#   running/VBG
#   (mychunk president/NN independent/JJ)
#   believe/VBP
#   (mychunk country/NN trouble/NN)
#   believe/VBP
#   us/PRP
#   going/VBG
#   (mychunk begin/JJ)
#   (mychunk work/NN)
#   together/RB
#   solve/VB
#   (mychunk problems/NNS)
#   think/VBP
#   (mychunk spoiler/JJR consider/JJR)
#   (mychunk facts/NNS)
#   really/RB
#   think/VBP
#   (mychunk economy/NN healthy/JJ)
#   really/RB
#   think/VBP
#   million/CD
#   (mychunk americans/NNS)
#   work/VBP
#   (mychunk unemployment/NN)
#   among/IN
#   (mychunk youth/JJ)
#   (mychunk country/NN acceptable/JJ)
#   really/RB
#   think/VBP
#   (mychunk armed/JJ)
#   (mychunk forces/NNS)
#   really/RB
#   acceptably/RB
#   (mychunk strong/JJ)
#   (mychunk areas/NNS conventional/JJ)
#   (mychunk capability/NN)
#   think/VBP
#   (mychunk political/JJ)
#   (mychunk institutions/NNS)
#   working/VBG
#   (mychunk way/NN)
#   literally/RB
#   (mychunk half/JJ)
#   (mychunk citizens/NNS)
#   vote/VBP
#   think/VBP
#   think/VBP
#   therefore/RB
#   think/VBP
#   ought/MD
#   consider/VB
#   (mychunk something/NN)
#   voting/VBG
#   (mychunk independent/JJ know/JJ)
#   (mychunk
#     generation/NN
#     office/NN
#     seekers/NNS
#     tried/VBD
#     tell/JJ
#     american/JJ)
#   (mychunk people/NNS)
#   could/MD
#   get/VB
#   (mychunk something/NN nothing/NN time/NN)
#   therefore/IN
#   (mychunk illusion/NN false/JJ)
#   hopes/VBZ
#   (mychunk longer/JJR)
#   continues/VBZ
#   (mychunk dangerous/JJ)
#   (mychunk becomes/NNS)
#   we've/VBP
#   got/VBN
#   (mychunk stop/JJ)
#   drifting/VBG
#   (mychunk wish/JJ)
#   (mychunk tonight/NN)
#   desperately/RB
#   (mychunk time/NN talk/NN issues/NNS)
#   fundamentally/RB
#   (mychunk important/JJ great/JJ historian/JJ)
#   (mychunk henry/NN steele/NN commager/NN said/VBD lust/JJ)
#   (mychunk victory/NN)
#   neither/DT
#   (mychunk traditional/JJ)
#   (mychunk party/NN)
#   looking/VBG
#   beyond/IN
#   (mychunk november/NNP went/VBD cite/JJ)
#   three/CD
#   (mychunk issues/NNS platforms/NNS)
#   totally/RB
#   ignore/VBP
#   (mychunk atomic/JJ)
#   (mychunk warfare/NN presidential/JJ)
#   (mychunk directive/NN)
#   notwithstanding/VBG
#   (mychunk resolve/NNS issue/NN others/NNS)
#   become/VBP
#   (mychunk irrelevant/JJ)
#   (mychunk issue/NN natural/JJ)
#   (mychunk resources/NNS right/JJ)
#   (mychunk posterity/NN)
#   inherit/VBP
#   (mychunk earth/NN kind/NN earth/JJ)
#   (mychunk issue/NN nationalism/NN recognition/NN)
#   says/VBZ
#   every/DT
#   (mychunk major/JJ)
#   (mychunk problem/NN)
#   confronting/VBG
#   us/PRP
#   (mychunk global/JJ)
#   (mychunk cannot/NN solved/VBD)
#   (mychunk nationalism/NN)
#   elsewhere/RB
#   (mychunk chauvinistic/JJ parochial/JJ anachronistic/JJ)
#   (mychunk states/NNS rights/NNS days/NNS jefferson/NN)
#   davis/VBZ
#   (mychunk great/JJ)
#   (mychunk issues/NNS)
#   atomic/VBP
#   (mychunk warfare/NN use/NN natural/JJ)
#   (mychunk resources/NNS issue/NN nationalism/NN)
#   intend/VBP
#   talking/VBG
#   remaining/VBG
#   six/CD
#   (mychunk weeks/NNS campaign/NN)
#   dare/VBP
#   (mychunk hope/JJ american/JJ)
#   (mychunk people/NNS)
#   listening/VBG
#   (mychunk see/JJ independent/JJ)
#   (mychunk government/NN john/NN anderson/NN patrick/JJ)
#   (mychunk lucey/NN)
#   give/VBP
#   us/PRP
#   (mychunk kind/NN coalition/NN government/NN)
#   need/VBP
#   begin/VB
#   solve/VB
#   (mychunk problems/NNS)
#   thank/VB)

# %%
tagged_dem_platform_2016= nltk.pos_tag(tokens_dem_platform_2016)

tagged_rep_platform_2016= nltk.pos_tag(tokens_rep_platform_2016)

tagged_dem_debate_2016= nltk.pos_tag(tokens_dem_debate_2016)

tagged_rep_debate_2016=nltk.pos_tag(tokens_rep_debate_2016)

tagged_rep_platform_1980= nltk.pos_tag(tokens_rep_platform_1980)

tagged_rep_platform_1980
# Out:
# [('adopted', 'VBN'),
#  ('national', 'JJ'),
#  ('convention', 'NN'),
#  ('july', 'NN'),
#  ('detroit', 'NNP'),
#  ('mich', 'NNP'),
#  ('party', 'NN'),
#  ('convenes', 'NNS'),
#  ('presents', 'NNS'),
#  ('platform', 'JJ'),
#  ('selects', 'NNS'),
#  ('nominees', 'JJ'),
#  ('time', 'NN'),
#  ('crisis', 'NN'),
#  ('america', 'JJ'),
#  ('adrift', 'JJ'),
#  ('country', 'NN'),
#  ('moves', 'NNS'),
#  ('agonizingly', 'RB'),
#  ('aimlessly', 'RB'),
#  ('almost', 'RB'),
#  ('helplessly', 'RB'),
#  ('one', 'CD'),
#  ('dangerous', 'JJ'),
#  ('disorderly', 'RB'),
#  ('periods', 'NNS'),
#  ('history', 'NN'),
#  ('home', 'NN'),
#  ('economy', 'NN'),
#  ('careens', 'VBZ'),
#  ('whiplashed', 'JJ'),
#  ('one', 'CD'),
#  ('extreme', 'NN'),
#  ('another', 'DT'),
#  ('earlier', 'JJR'),
#  ('year', 'NN'),
#  ('inflation', 'NN'),
#  ('skyrocketed', 'VBD'),
#  ('highest', 'JJS'),
#  ('levels', 'NNS'),
#  ('century', 'NN'),
#  ('weeks', 'NNS'),
#  ('later', 'RB'),
#  ('economy', 'NN'),
#  ('plummeted', 'VBD'),
#  ('suffering', 'JJ'),
#  ('steepest', 'JJ'),
#  ('slide', 'NN'),
#  ('record', 'NN'),
#  ('prices', 'NNS'),
#  ('escalate', 'VBP'),
#  ('percent', 'JJ'),
#  ('year', 'NN'),
#  ('eight', 'CD'),
#  ('million', 'CD'),
#  ('people', 'NNS'),
#  ('seek', 'JJ'),
#  ('employment', 'NN'),
#  ('manufacturing', 'NN'),
#  ('plants', 'NNS'),
#  ('lie', 'VBP'),
#  ('idle', 'JJ'),
#  ('across', 'IN'),
#  ('country', 'NN'),
#  ('hopes', 'VBZ'),
#  ('aspirations', 'NNS'),
#  ('people', 'NNS'),
#  ('smothered', 'VBD'),
#  ('overseas', 'JJ'),
#  ('conditions', 'NNS'),
#  ('already', 'RB'),
#  ('perilous', 'JJ'),
#  ('deteriorate', 'NN'),
#  ('soviet', 'JJ'),
#  ('union', 'NN'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('acquiring', 'VBG'),
#  ('means', 'NNS'),
#  ('obliterate', 'JJ'),
#  ('cripple', 'JJ'),
#  ('land-based', 'JJ'),
#  ('missile', 'NN'),
#  ('system', 'NN'),
#  ('blackmail', 'VBP'),
#  ('us', 'PRP'),
#  ('submission', 'JJ'),
#  ('marxist', 'JJ'),
#  ('tyrannies', 'NNS'),
#  ('spread', 'VBP'),
#  ('rapidly', 'RB'),
#  ('third', 'JJ'),
#  ('world', 'NN'),
#  ('latin', 'NN'),
#  ('america', 'JJ'),
#  ('alliances', 'NNS'),
#  ('frayed', 'VBN'),
#  ('europe', 'VBP'),
#  ('elsewhere', 'RB'),
#  ('energy', 'NN'),
#  ('supplies', 'NNS'),
#  ('become', 'VBP'),
#  ('even', 'RB'),
#  ('dependent', 'JJ'),
#  ('uncertain', 'JJ'),
#  ('foreign', 'JJ'),
#  ('suppliers', 'NNS'),
#  ('ultimate', 'JJ'),
#  ('humiliation', 'NN'),
#  ('militant', 'NN'),
#  ('terrorists', 'VBZ'),
#  ('iran', 'JJ'),
#  ('continue', 'VBP'),
#  ('toy', 'JJ'),
#  ('lives', 'NNS'),
#  ('americans', 'VBZ'),
#  ('events', 'NNS'),
#  ('isolated', 'VBN'),
#  ('unrelated', 'JJ'),
#  ('signposts', 'NNS'),
#  ('mark', 'VBP'),
#  ('continuing', 'VBG'),
#  ('downward', 'JJ'),
#  ('spiral', 'JJ'),
#  ('economic', 'JJ'),
#  ('vitality', 'NN'),
#  ('international', 'JJ'),
#  ('influence', 'NN'),
#  ('trend', 'NN'),
#  ('continue', 'VBP'),
#  ('promise', 'RB'),
#  ('dangerous', 'JJ'),
#  ('years', 'NNS'),
#  ('since', 'IN'),
#  ('world', 'NN'),
#  ('war', 'NN'),
#  ('ii', 'JJ'),
#  ('history', 'NN'),
#  ('could', 'MD'),
#  ('record', 'VB'),
#  ('let', 'VB'),
#  ('drift', 'VB'),
#  ('go', 'VB'),
#  ('american', 'JJ'),
#  ('experiment', 'NN'),
#  ('marvelously', 'RB'),
#  ('successful', 'JJ'),
#  ('years', 'NNS'),
#  ('came', 'VBD'),
#  ('strangely', 'RB'),
#  ('needlessly', 'RB'),
#  ('tragically', 'RB'),
#  ('dismal', 'JJ'),
#  ('end', 'VBP'),
#  ('early', 'JJ'),
#  ('third', 'JJ'),
#  ('century', 'NN'),
#  ('far', 'RB'),
#  ('galling', 'VBG'),
#  ('aspect', 'JJ'),
#  ('chief', 'JJ'),
#  ('architects', 'NNS'),
#  ('decline', 'VBP'),
#  ('politicians', 'NNS'),
#  ('without', 'IN'),
#  ('program', 'NN'),
#  ('ideas', 'NNS'),
#  ('reverse', 'VBP'),
#  ('divided', 'VBN'),
#  ('leaderless', 'NN'),
#  ('unseeing', 'VBG'),
#  ('uncomprehending', 'JJ'),
#  ('plod', 'NN'),
#  ('listless', 'JJ'),
#  ('offerings', 'NNS'),
#  ('pale', 'JJ'),
#  ('imitations', 'NNS'),
#  ('policies', 'NNS'),
#  ('pursued', 'VBD'),
#  ('long', 'JJ'),
#  ('knowing', 'NN'),
#  ('full', 'JJ'),
#  ('well', 'RB'),
#  ('futility', 'NN'),
#  ('carter', 'NN'),
#  ('administration', 'NN'),
#  ('unhappy', 'JJ'),
#  ('inevitable', 'JJ'),
#  ('consequence', 'NN'),
#  ('decades', 'NNS'),
#  ('increasingly', 'RB'),
#  ('outmoded', 'VBN'),
#  ('domination', 'NN'),
#  ('national', 'JJ'),
#  ('life', 'NN'),
#  ('past', 'IN'),
#  ('four', 'CD'),
#  ('years', 'NNS'),
#  ('repeatedly', 'RB'),
#  ('demonstrated', 'VBD'),
#  ('basic', 'JJ'),
#  ('goals', 'NNS'),
#  ('perpetuation', 'NN'),
#  ('rule', 'NN'),
#  ('guiding', 'VBG'),
#  ('principle', 'NN'),
#  ('fleeting', 'VBG'),
#  ('insights', 'NNS'),
#  ('provided', 'VBN'),
#  ('latest', 'JJS'),
#  ('opinion', 'NN'),
#  ('poll', 'NN'),
#  ('policies', 'NNS'),
#  ('announced', 'VBD'),
#  ('one', 'CD'),
#  ('day', 'NN'),
#  ('disavowed', 'VBD'),
#  ('ignored', 'VBN'),
#  ('next', 'JJ'),
#  ('sowing', 'JJ'),
#  ('confusion', 'NN'),
#  ('among', 'IN'),
#  ('americans', 'NNS'),
#  ('home', 'VBP'),
#  ('havoc', 'NN'),
#  ('among', 'IN'),
#  ('friends', 'NNS'),
#  ('abroad', 'RB'),
#  ('republicans', 'VBZ'),
#  ('democrats', 'JJ'),
#  ('independents', 'NNS'),
#  ('watching', 'VBG'),
#  ('reading', 'NN'),
#  ('signs', 'NNS'),
#  ('watching', 'VBG'),
#  ('incredulously', 'RB'),
#  ('disaster', 'NN'),
#  ('disaster', 'NN'),
#  ('unfolds', 'NNS'),
#  ('enough', 'IN'),
#  ('rising', 'VBG'),
#  ('say', 'VBP'),
#  ('confusion', 'NN'),
#  ('must', 'MD'),
#  ('end', 'VB'),
#  ('drift', 'NN'),
#  ('must', 'MD'),
#  ('end', 'VB'),
#  ('must', 'MD'),
#  ('pull', 'VB'),
#  ('together', 'RB'),
#  ('people', 'NNS'),
#  ('slide', 'VBP'),
#  ('irretrievably', 'RB'),
#  ('abyss', 'JJ'),
#  ('way', 'NN'),
#  ('stay', 'JJ'),
#  ('way', 'NN'),
#  ('party', 'NN'),
#  ('hold', 'VBP'),
#  ('forth', 'JJ'),
#  ('party', 'NN'),
#  ('best', 'JJS'),
#  ('able', 'JJ'),
#  ('arrest', 'NN'),
#  ('reverse', 'NN'),
#  ('decline', 'NN'),
#  ('offer', 'VBP'),
#  ('new', 'JJ'),
#  ('ideas', 'NNS'),
#  ('candidates', 'NNS'),
#  ('top', 'JJ'),
#  ('ticket', 'NN'),
#  ('bottom', 'NN'),
#  ('bring', 'VBG'),
#  ('local', 'JJ'),
#  ('national', 'JJ'),
#  ('leadership', 'NN'),
#  ('firm', 'NN'),
#  ('steady', 'JJ'),
#  ('hands', 'NNS'),
#  ('confidence', 'NN'),
#  ('eagerness', 'NN'),
#  ('unparalleled', 'JJ'),
#  ('unity', 'NN'),
#  ('within', 'IN'),
#  ('ranks', 'NNS'),
#  ('especially', 'RB'),
#  ('presidential', 'JJ'),
#  ('nominee', 'JJ'),
#  ('congressional', 'JJ'),
#  ('membership', 'NN'),
#  ('important', 'JJ'),
#  ('go', 'VB'),
#  ('forth', 'JJ'),
#  ('people', 'NNS'),
#  ('ideas', 'NNS'),
#  ('programs', 'NNS'),
#  ('future', 'VBP'),
#  ('powerful', 'JJ'),
#  ('compelling', 'JJ'),
#  ('fresh', 'JJ'),
#  ('together', 'RB'),
#  ('offer', 'VBP'),
#  ('new', 'JJ'),
#  ('beginning', 'VBG'),
#  ('america', 'JJ'),
#  ('foremost', 'JJ'),
#  ('goal', 'NN'),
#  ('home', 'NN'),
#  ('simple', 'JJ'),
#  ('economic', 'JJ'),
#  ('growth', 'NN'),
#  ('full', 'JJ'),
#  ('employment', 'NN'),
#  ('without', 'IN'),
#  ('inflation', 'NN'),
#  ('sweeping', 'VBG'),
#  ('change', 'JJ'),
#  ('economic', 'JJ'),
#  ('policy', 'NN'),
#  ('america', 'NN'),
#  ('needed', 'VBD'),
#  ('mr', 'NN'),
#  ("carter's", 'NN'),
#  ('promise', 'NN'),
#  ('hard', 'JJ'),
#  ('times', 'NNS'),
#  ('austerity', 'VBP'),
#  ('one', 'CD'),
#  ('promise', 'NN'),
#  ('well', 'RB'),
#  ('kept', 'VBD'),
#  ('replaced', 'JJ'),
#  ('policies', 'NNS'),
#  ('promise', 'VBP'),
#  ('economic', 'JJ'),
#  ('growth', 'NN'),
#  ('job', 'NN'),
#  ('creation', 'NN'),
#  ('belief', 'NN'),
#  ('stagflation', 'NN'),
#  ('recent', 'JJ'),
#  ('years', 'NNS'),
#  ('consigned', 'VBD'),
#  ('millions', 'NNS'),
#  ('citizens', 'NNS'),
#  ('hardship', 'NN'),
#  ('also', 'RB'),
#  ('bottled', 'VBD'),
#  ('enormous', 'JJ'),
#  ('ingenuity', 'NN'),
#  ('creative', 'JJ'),
#  ('powers', 'NNS'),
#  ('people', 'NNS'),
#  ('energies', 'NNS'),
#  ('released', 'VBN'),
#  ('sterile', 'JJ'),
#  ('policies', 'NNS'),
#  ('past', 'IN'),
#  ('specifically', 'RB'),
#  ('reject', 'JJ'),
#  ('carter', 'NN'),
#  ('doctrine', 'NN'),
#  ('inflation', 'NN'),
#  ('reduced', 'VBD'),
#  ('throwing', 'VBG'),
#  ('people', 'NNS'),
#  ('work', 'VBP'),
#  ('prosperity', 'NN'),
#  ('regained', 'VBN'),
#  ('simply', 'RB'),
#  ('government', 'NN'),
#  ('fiat', 'NN'),
#  ('rather', 'RB'),
#  ('must', 'MD'),
#  ('offer', 'VB'),
#  ('broad', 'JJ'),
#  ('new', 'JJ'),
#  ('incentives', 'NNS'),
#  ('labor', 'NN'),
#  ('capital', 'NN'),
#  ('stimulate', 'NN'),
#  ('great', 'JJ'),
#  ('outpouring', 'VBG'),
#  ('private', 'JJ'),
#  ('goods', 'NNS'),
#  ('services', 'NNS'),
#  ('create', 'VBP'),
#  ('abundance', 'NN'),
#  ('jobs', 'NNS'),
#  ("america's", 'VBP'),
#  ('grass', 'NN'),
#  ('roots', 'NNS'),
#  ('white', 'JJ'),
#  ('house', 'NN'),
#  ('stand', 'NN'),
#  ('united', 'VBD'),
#  ('party', 'NN'),
#  ('behind', 'IN'),
#  ('bold', 'JJ'),
#  ('program', 'NN'),
#  ('tax', 'NN'),
#  ('rate', 'NN'),
#  ('reductions', 'NNS'),
#  ('spending', 'NN'),
#  ('restraints', 'NNS'),
#  ('regulatory', 'JJ'),
#  ('reforms', 'NNS'),
#  ('inject', 'VBP'),
#  ('new', 'JJ'),
#  ('life', 'NN'),
#  ('economic', 'JJ'),
#  ('bloodstream', 'NN'),
#  ('country', 'NN'),
#  ('overseas', 'JJ'),
#  ('goal', 'NN'),
#  ('equally', 'RB'),
#  ('simple', 'JJ'),
#  ('direct', 'JJ'),
#  ('preserve', 'NN'),
#  ('world', 'NN'),
#  ('peace', 'NN'),
#  ('keeping', 'VBG'),
#  ('america', 'JJ'),
#  ('strong', 'JJ'),
#  ('philosophy', 'NN'),
#  ('occupied', 'VBD'),
#  ('hallowed', 'JJ'),
#  ('place', 'NN'),
#  ('american', 'JJ'),
#  ('diplomacy', 'NN'),
#  ('casually', 'RB'),
#  ('even', 'RB'),
#  ('cavalierly', 'RB'),
#  ('dismissed', 'VBN'),
#  ('outset', 'RP'),
#  ('carter', 'JJ'),
#  ('administration', 'NN'),
#  ('results', 'NNS'),
#  ('shattering', 'VBG'),
#  ('never', 'RB'),
#  ('modern', 'JJ'),
#  ('history', 'NN'),
#  ('united', 'JJ'),
#  ('states', 'NNS'),
#  ('endured', 'VBD'),
#  ('many', 'JJ'),
#  ('humiliations', 'NNS'),
#  ('insults', 'NNS'),
#  ('defeats', 'NNS'),
#  ('past', 'IN'),
#  ('four', 'CD'),
#  ('years', 'NNS'),
#  ('ambassadors', 'NNS'),
#  ('murdered', 'VBD'),
#  ('embassies', 'NNS'),
#  ('burned', 'VBN'),
#  ('warnings', 'NNS'),
#  ('ignored', 'VBN'),
#  ('diplomacy', 'NN'),
#  ('scorned', 'VBD'),
#  ('diplomats', 'NNS'),
#  ('kidnapped', 'VBD'),
#  ('carter', 'JJR'),
#  ('administration', 'NN'),
#  ('shown', 'VBN'),
#  ('neither', 'DT'),
#  ('understands', 'JJ'),
#  ('totalitarianism', 'NN'),
#  ('appreciates', 'VBZ'),
#  ('way', 'NN'),
#  ('tyrants', 'NNS'),
#  ('take', 'VBP'),
#  ('advantage', 'NN'),
#  ('weakness', 'NN'),
#  ('brutal', 'JJ'),
#  ('invasion', 'NN'),
#  ('afghanistan', 'NN'),
#  ('promises', 'VBZ'),
#  ('forerunner', 'RB'),
#  ('much', 'JJ'),
#  ('serious', 'JJ'),
#  ('threats', 'NNS'),
#  ('west', 'VBP'),
#  ('world', 'NN'),
#  ('peace', 'NN'),
#  ('carter', 'NN'),
#  ('administration', 'NN'),
#  ('somehow', 'RB'),
#  ('cling', 'VBG'),
#  ('power', 'NN'),
#  ('republicans', 'NNS'),
#  ('united', 'JJ'),
#  ('belief', 'NN'),
#  ("america's", 'JJ'),
#  ('international', 'JJ'),
#  ('humiliation', 'NN'),
#  ('decline', 'NN'),
#  ('reversed', 'VBN'),
#  ('strong', 'JJ'),
#  ('presidential', 'JJ'),
#  ('leadership', 'NN'),
#  ('consistent', 'JJ'),
#  ('far-sighted', 'JJ'),
#  ('foreign', 'JJ'),
#  ('policy', 'NN'),
#  ('supported', 'VBD'),
#  ('major', 'JJ'),
#  ('upgrading', 'JJ'),
#  ('military', 'JJ'),
#  ('forces', 'NNS'),
#  ('strengthening', 'VBG'),
#  ('commitments', 'NNS'),
#  ('allies', 'NNS'),
#  ('resolve', 'VBP'),
#  ('national', 'JJ'),
#  ('interests', 'NNS'),
#  ('vigorously', 'RB'),
#  ('protected', 'VBD'),
#  ('ultimately', 'RB'),
#  ('practice', 'NN'),
#  ('strength', 'NN'),
#  ('firmness', 'NN'),
#  ('truly', 'RB'),
#  ('guard', 'JJ'),
#  ('peace', 'NN'),
#  ('platform', 'NN'),
#  ('addresses', 'VBZ'),
#  ('many', 'JJ'),
#  ('concerns', 'NNS'),
#  ('party', 'NN'),
#  ('seek', 'NN'),
#  ('restore', 'NN'),
#  ('family', 'NN'),
#  ('neighborhood', 'NN'),
#  ('community', 'NN'),
#  ('workplace', 'VBP'),
#  ('vital', 'JJ'),
#  ('alternatives', 'NNS'),
#  ('national', 'JJ'),
#  ('life', 'NN'),
#  ('ever-expanding', 'JJ'),
#  ('federal', 'JJ'),
#  ('power', 'NN'),
#  ('affirm', 'NN'),
#  ('deep', 'JJ'),
#  ('commitment', 'NN'),
#  ('fulfillment', 'NN'),
#  ('hopes', 'VBZ'),
#  ('aspirations', 'NNS'),
#  ('americans', 'NNS'),
#  ('blacks', 'NNS'),
#  ('whites', 'NNS'),
#  ('women', 'NNS'),
#  ('men', 'NNS'),
#  ('young', 'JJ'),
#  ('old', 'JJ'),
#  ('rural', 'JJ'),
#  ('urban', 'JJ'),
#  ('many', 'JJ'),
#  ('years', 'NNS'),
#  ('political', 'JJ'),
#  ('debate', 'NN'),
#  ('america', 'NN'),
#  ('conducted', 'VBD'),
#  ('terms', 'NNS'),
#  ('set', 'VBN'),
#  ('democrats', 'NNS'),
#  ('believe', 'VBP'),
#  ('every', 'DT'),
#  ('time', 'NN'),
#  ('new', 'JJ'),
#  ('problems', 'NNS'),
#  ('arise', 'VBP'),
#  ('beyond', 'IN'),
#  ('power', 'NN'),
#  ('men', 'NNS'),
#  ('women', 'NNS'),
#  ('individuals', 'NNS'),
#  ('solve', 'VBP'),
#  ('becomes', 'NNS'),
#  ('duty', 'JJ'),
#  ('government', 'NN'),
#  ('solve', 'VBD'),
#  ('never', 'RB'),
#  ('alternative', 'JJ'),
#  ('republicans', 'NNS'),
#  ('disagree', 'VBP'),
#  ('always', 'RB'),
#  ('taken', 'VBN'),
#  ('side', 'JJ'),
#  ('individual', 'JJ'),
#  ('whose', 'WP$'),
#  ('freedoms', 'NNS'),
#  ('threatened', 'VBD'),
#  ('big', 'JJ'),
#  ('government', 'NN'),
#  ('idea', 'NN'),
#  ('spawned', 'VBD'),
#  ('case', 'NN'),
#  ('individual', 'NN'),
#  ('stronger', 'JJR'),
#  ('ever', 'RB'),
#  ('defense', 'NN'),
#  ('individual', 'JJ'),
#  ('government', 'NN'),
#  ('never', 'RB'),
#  ('needed', 'VBD'),
#  ('continue', 'NN'),
#  ('mount', 'NN'),
#  ('redefine', 'NN'),
#  ('broaden', 'JJ'),
#  ('debate', 'NN'),
#  ('transcending', 'VBG'),
#  ('narrow', 'JJ'),
#  ('terms', 'NNS'),
#  ('government', 'NN'),
#  ('individual', 'JJ'),
#  ('two', 'CD'),
#  ('realities', 'NNS'),
#  ('america', 'VBP'),
#  ('society', 'NN'),
#  ('consists', 'VBZ'),
#  ('political', 'JJ'),
#  ('debate', 'NN'),
#  ('reemphasize', 'VB'),
#  ('vital', 'JJ'),
#  ('communities', 'NNS'),
#  ('like', 'IN'),
#  ('family', 'NN'),
#  ('neighborhood', 'NN'),
#  ('workplace', 'NN'),
#  ('others', 'NNS'),
#  ('found', 'VBD'),
#  ('center', 'NN'),
#  ('society', 'NN'),
#  ('government', 'NN'),
#  ('individual', 'JJ'),
#  ('restore', 'RB'),
#  ('strengthen', 'JJ'),
#  ('ability', 'NN'),
#  ('solve', 'VBP'),
#  ('problems', 'NNS'),
#  ('places', 'NNS'),
#  ('people', 'NNS'),
#  ('spend', 'VBP'),
#  ('daily', 'JJ'),
#  ('lives', 'NNS'),
#  ('turn', 'VBP'),
#  ('support', 'NN'),
#  ('help', 'NN'),
#  ('seek', 'VB'),
#  ('energy', 'NN'),
#  ('independence', 'NN'),
#  ('economic', 'JJ'),
#  ('policies', 'NNS'),
#  ('free', 'JJ'),
#  ('energy', 'NN'),
#  ('production', 'NN'),
#  ('encourage', 'NN'),
#  ('conservation', 'NN'),
#  ('seek', 'JJ'),
#  ('improvements', 'NNS'),
#  ('health', 'NN'),
#  ('care', 'NN'),
#  ('education', 'NN'),
#  ('housing', 'NN'),
#  ('opportunities', 'NNS'),
#  ('youth', 'VBP'),
#  ('seek', 'JJ'),
#  ('new', 'JJ'),
#  ('avenues', 'NNS'),
#  ('needy', 'JJ'),
#  ('break', 'JJ'),
#  ('tragic', 'JJ'),
#  ('cycle', 'NN'),
#  ('dependency', 'NN'),
#  ('goals', 'NNS'),
#  ('many', 'JJ'),
#  ('others', 'NNS'),
#  ('confidently', 'RB'),
#  ('expect', 'VBP'),
#  ('achieve', 'JJ'),
#  ('rebirth', 'NN'),
#  ('liberty', 'NN'),
#  ('resurgence', 'NN'),
#  ('private', 'JJ'),
#  ('initiatives', 'NNS'),
#  ('believe', 'VBP'),
#  ('root', 'NN'),
#  ('troubles', 'NNS'),
#  ('today', 'NN'),
#  ('misguided', 'VBD'),
#  ('discredited', 'JJ'),
#  ('philosophy', 'NN'),
#  ('all-powerful', 'JJ'),
#  ('government', 'NN'),
#  ('ceaselessly', 'RB'),
#  ('striving', 'VBG'),
#  ('subsidize', 'VB'),
#  ('manipulate', 'JJ'),
#  ('control', 'NN'),
#  ('individuals', 'NNS'),
#  ('individual', 'JJ'),
#  ('government', 'NN'),
#  ('reigns', 'NNS'),
#  ('center', 'NN'),
#  ('philosophy', 'NN'),
#  ('democrats', 'NNS'),
#  ('say', 'VBP'),
#  ('americans', 'NNS'),
#  ('must', 'MD'),
#  ('content', 'VB'),
#  ('passively', 'RB'),
#  ('accept', 'JJ'),
#  ('gradual', 'JJ'),
#  ('inexorable', 'JJ'),
#  ('decline', 'NN'),
#  ('america', 'NN'),
#  ('answer', 'VBP'),
#  ('american', 'JJ'),
#  ('people', 'NNS'),
#  ('hardly', 'RB'),
#  ('begun', 'VBN'),
#  ('marshal', 'JJ'),
#  ('talents', 'NNS'),
#  ('resources', 'NNS'),
#  ('realize', 'VBP'),
#  ('accomplishments', 'NNS'),
#  ('dreams', 'JJ'),
#  ('freedom', 'NN'),
#  ('inspire', 'NN'),
#  ('democrats', 'NNS'),
#  ('say', 'VBP'),
#  ('face', 'VBP'),
#  ('age', 'NN'),
#  ('limits', 'NNS'),
#  ('ask', 'VBP'),
#  ('knows', 'VBZ'),
#  ('limit', 'NN'),
#  ('americans', 'NNS'),
#  ('capacity', 'NN'),
#  ('work', 'NN'),
#  ('creativity', 'NN'),
#  ('optimism', 'NN'),
#  ('faith', 'NN'),
#  ('enhanced', 'VBD'),
#  ('supported', 'VBN'),
#  ('strong', 'JJ'),
#  ('responsive', 'JJ'),
#  ('political', 'JJ'),
#  ('leadership', 'NN'),
#  ('ideals', 'NNS'),
#  ('mr', 'VBP'),
#  ('carter', 'JJ'),
#  ('say', 'VBP'),
#  ('american', 'JJ'),
#  ('people', 'NNS'),
#  ('suffer', 'VBP'),
#  ('national', 'JJ'),
#  ('malaise', 'NN'),
#  ('respond', 'NN'),
#  ('malaise', 'NN'),
#  ('country', 'NN'),
#  ('found', 'VBD'),
#  ('leadership', 'NN'),
#  ('party', 'NN'),
#  ('white', 'JJ'),
#  ('house', 'NN'),
#  ('congress', 'NN'),
#  ('symptoms', 'NNS'),
#  ('incompetence', 'RB'),
#  ('lead', 'JJ'),
#  ('refusal', 'NN'),
#  ('change', 'NN'),
#  ('reluctance', 'NN'),
#  ('act', 'NN'),
#  ('malaise', 'NN'),
#  ('become', 'VBP'),
#  ('epidemic', 'JJ'),
#  ('washington', 'JJ'),
#  ('cure', 'NN'),
#  ('government', 'NN'),
#  ('led', 'VBD'),
#  ('republicans', 'NNS'),
#  ('share', 'NN'),
#  ('values', 'NNS'),
#  ('majority', 'NN'),
#  ('americans', 'NNS'),
#  ('republicans', 'VBP'),
#  ('pledge', 'JJ'),
#  ('restoration', 'NN'),
#  ('balance', 'NN'),
#  ('american', 'JJ'),
#  ('society', 'NN'),
#  ('society', 'NN'),
#  ('cannot', 'NN'),
#  ('balanced', 'VBD'),
#  ('actions', 'NNS'),
#  ('government', 'NN'),
#  ('individuals', 'NNS'),
#  ('alone', 'RB'),
#  ('balance', 'NN'),
#  ('found', 'VBD'),
#  ("society's", 'JJ'),
#  ('vital', 'JJ'),
#  ('center', 'NN'),
#  ('find', 'VBP'),
#  ('family', 'NN'),
#  ('neighborhood', 'NN'),
#  ('workplace', 'NN'),
#  ('america', 'NN'),
#  ('however', 'RB'),
#  ('achieve', 'JJ'),
#  ('goals', 'NNS'),
#  ('present', 'JJ'),
#  ('course', 'NN'),
#  ('present', 'JJ'),
#  ('leadership', 'NN'),
#  ('uncharted', 'JJ'),
#  ('course', 'NN'),
#  ('mr', 'NN'),
#  ('carter', 'NN'),
#  ('lead', 'VBP'),
#  ('surely', 'RB'),
#  ('catastrophe', 'JJ'),
#  ('reversing', 'VBG'),
#  ('economic', 'JJ'),
#  ('decline', 'NN'),
#  ('reversing', 'VBG'),
#  ('international', 'JJ'),
#  ('decline', 'NN'),
#  ('resurrect', 'NN'),
#  ('dreams', 'VBZ'),
#  ('platform', 'VBP'),
#  ('call', 'JJ'),
#  ('american', 'JJ'),
#  ('people', 'NNS'),
#  ("god's", 'VBP'),
#  ('help', 'NN'),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('together', 'RB'),
#  ('make', 'VBP'),
#  ('america', 'JJ'),
#  ('great', 'JJ'),
#  ('let', 'VB'),
#  ('us', 'PRP'),
#  ('together', 'RB'),
#  ('make', 'VBP'),
#  ('new', 'JJ'),
#  ('beginning', 'VBG'),
#  ('long', 'JJ'),
#  ('fundamental', 'JJ'),
#  ('conviction', 'NN'),
#  ('party', 'NN'),
#  ('government', 'NN'),
#  ('foster', 'NN'),
#  ('society', 'NN'),
#  ('climate', 'NN'),
#  ('maximum', 'JJ'),
#  ('individual', 'JJ'),
#  ('liberty', 'NN'),
#  ('freedom', 'NN'),
#  ('choice', 'NN'),
#  ('properly', 'RB'),
#  ('informed', 'VBN'),
#  ('people', 'NNS'),
#  ('individuals', 'NNS'),
#  ('acting', 'VBG'),
#  ('instruments', 'NNS'),
#  ('popular', 'JJ'),
#  ('consultation', 'NN'),
#  ('make', 'VB'),
#  ('right', 'JJ'),
#  ('decisions', 'NNS'),
#  ('affecting', 'VBG'),
#  ('personal', 'JJ'),
#  ('general', 'JJ'),
#  ('welfare', 'NN'),
#  ('free', 'JJ'),
#  ('pervasive', 'JJ'),
#  ('heavy-handed', 'JJ'),
#  ('intrusion', 'NN'),
#  ('central', 'JJ'),
#  ('government', 'NN'),
#  ('decisionmaking', 'VBG'),
#  ('process', 'NN'),
#  ('tenet', 'NN'),
#  ('genius', 'NN'),
#  ('representative', 'JJ'),
#  ('democracy', 'NN'),
#  ('republicans', 'NNS'),
#  ('also', 'RB'),
#  ('treasure', 'VBP'),
#  ('ethnic', 'JJ'),
#  ('cultural', 'JJ'),
#  ('regional', 'JJ'),
#  ('diversity', 'NN'),
#  ('people', 'NNS'),
#  ('diversity', 'NN'),
#  ('fosters', 'NNS'),
#  ('dynamism', 'VBP'),
#  ('american', 'JJ'),
#  ('society', 'NN'),
#  ('envy', 'NN'),
#  ('world', 'NN'),
#  ('elsewhere', 'RB'),
#  ('platform', 'VB'),
#  ('discuss', 'JJ'),
#  ('benefits', 'NNS'),
#  ('society', 'NN'),
#  ('whole', 'JJ'),
#  ('reduced', 'JJ'),
#  ('taxation', 'NN'),
#  ('particularly', 'RB'),
#  ('terms', 'NNS'),
#  ('economic', 'JJ'),
#  ('growth', 'NN'),
#  ('believe', 'VBP'),
#  ('essential', 'JJ'),
#  ('cut', 'VBD'),
#  ('personal', 'JJ'),
#  ('tax', 'NN'),
#  ('rates', 'NNS'),
#  ('fairness', 'VBP'),
#  ('individual', 'JJ'),
#  ('presently', 'RB'),
#  ('aggregate', 'VBP'),
#  ('burden', 'JJ'),
#  ('taxation', 'NN'),
#  ('great', 'JJ'),
#  ('average', 'JJ'),
#  ('american', 'JJ'),
#  ('spends', 'VBZ'),
#  ('substantial', 'JJ'),
#  ('part', 'NN'),
#  ('every', 'DT'),
#  ('year', 'NN'),
#  ('effect', 'NN'),
#  ('working', 'VBG'),
#  ('government', 'NN'),
#  ('substantial', 'JJ'),
#  ('tax', 'NN'),
#  ('rate', 'NN'),
#  ('reductions', 'NNS'),
#  ('needed', 'VBN'),
#  ('offset', 'RB'),
#  ('massive', 'JJ'),
#  ('tax', 'NN'),
#  ('increases', 'NNS'),
#  ('facing', 'VBG'),
#  ('working', 'VBG'),
#  ('men', 'NNS'),
#  ('women', 'NNS'),
#  ('country', 'NN'),
#  ('next', 'IN'),
#  ('four', 'CD'),
#  ('years', 'NNS'),
#  ('federal', 'JJ'),
#  ('taxes', 'NNS'),
#  ('projected', 'VBN'),
#  ('increase', 'NN'),
#  ('billion', 'CD'),
#  ('due', 'JJ'),
#  ('carter', 'NN'),
#  ("administration's", 'NN'),
#  ('policies', 'NNS'),
#  ('american', 'JJ'),
#  ('families', 'NNS'),
#  ('already', 'RB'),
#  ('paying', 'VBG'),
#  ('taxes', 'NNS'),
#  ('higher', 'RBR'),
#  ('rates', 'NNS'),
#  ('ever', 'RB'),
#  ('history', 'NN'),
#  ('result', 'NN'),
#  ('carter', 'NN'),
#  ('policies', 'NNS'),
#  ('rates', 'NNS'),
#  ('go', 'VBP'),
#  ('even', 'RB'),
#  ('higher', 'JJR'),
#  ('direct', 'JJ'),
#  ('indirect', 'JJ'),
#  ('burden', 'NN'),
#  ('federal', 'JJ'),
#  ('taxes', 'NNS'),
#  ('alone', 'RB'),
#  ('imposed', 'VBN'),
#  ('average', 'JJ'),
#  ('family', 'NN'),
#  ('earning', 'VBG'),
#  ('risen', 'JJ'),
#  ('percent', 'NN'),
#  ("family's", 'NN'),
#  ('gross', 'JJ'),
#  ('income', 'NN'),
#  ...]

# %%
from collections import Counter
import nltk
counts_dem_deb1980 = Counter( tag for word,  tag in tagged_dem_debate_1980)
counts_rep_platform2016 = Counter( tag for word,  tag in tagged_rep_platform_2016)
count_dem_platform2016 = Counter( tag for word,  tag in tagged_dem_platform_2016)
counts_rep_platform1980 = Counter( tag for word,  tag in tagged_rep_platform_1980)
counts_rep_deb2016 = Counter( tag for word,  tag in tagged_rep_debate_2016)
counts_dem_deb2016 = Counter( tag for word,  tag in tagged_dem_debate_2016)
countsDemDeb1980 = Counter( tag for word,  tag in tagged_dem_debate_1980)
print(counts_rep_platform1980)
# Out:
# Counter({'NN': 6567, 'JJ': 4600, 'NNS': 3130, 'VBP': 1072, 'RB': 836, 'VBG': 648, 'VBD': 611, 'VBN': 413, 'VB': 379, 'VBZ': 280, 'IN': 277, 'MD': 174, 'CD': 143, 'JJR': 91, 'JJS': 62, 'RBR': 32, 'DT': 29, 'PRP': 11, 'RP': 10, 'NNPS': 9, 'CC': 8, 'WP$': 7, 'FW': 6, 'NNP': 5, 'WDT': 3, 'WRB': 3, 'RBS': 2, ':': 2, 'PDT': 1})

# %%
import numpy as np
labels1, values1 = zip(*counts_dem_deb1980.items())
labels2, values2 = zip(*count_dem_platform2016.items())
labels3, values3 = zip(*counts_rep_platform1980.items())
labels4, values4 = zip(*counts_rep_deb2016.items())
labels5, values5 = zip(*counts_dem_deb2016.items())
labels6, values6 = zip(*countsDemDeb1980.items())


indexes1 = np.arange(len(labels1))
indexes2 = np.arange(len(labels2))
indexes3 = np.arange(len(labels3))
indexes4 = np.arange(len(labels4))
indexes5 = np.arange(len(labels5))
indexes6 = np.arange(len(labels6))


width = 1

#fig, ax = plt.subplots(figsize=(10, 6))
#plt.barh(top_terms, top_term_counts)
#plt.gca().invert_yaxis()
#ax.set_xlabel('frequency')
#ax.set_ylabel('terms')
#ax.set_title('Most Frequently Used Words')
#plt.show()
#fig, ax = plt.subplots(figsize=(10, 6))
plt.figure(figsize=(15, 6))
plt.bar(indexes1, values1, width)
plt.xticks(indexes1 + width * 0.5, labels1)
plt.title("counts_dem_deb1980")
plt.show()

plt.figure(figsize=(15, 6))
plt.bar(indexes2, values2, width)
plt.xticks(indexes2 + width * 0.5, labels2)
plt.title("count_dem_platform2016")
plt.show()

plt.figure(figsize=(15, 6))
plt.bar(indexes3, values3, width)
plt.xticks(indexes3 + width * 0.5, labels3)
plt.title("counts_rep_platform1980")
plt.show()

plt.figure(figsize=(15, 6))
plt.bar(indexes4, values4, width)
plt.xticks(indexes4 + width * 0.5, labels4)
plt.title("counts_rep_deb2016")
plt.show()

plt.figure(figsize=(15, 6))
plt.bar(indexes5, values5, width)
plt.xticks(indexes5 + width * 0.5, labels5)
plt.title("counts_dem_deb2016")
plt.show()

plt.figure(figsize=(15, 6))
plt.bar(indexes6, values6, width)
plt.xticks(indexes6 + width * 0.5, labels6)
plt.title("countsDemDeb1980")
plt.show()

# %%
len(nltk.Text(tokens_rep_platform_2016))
# Out:
# 20048

# %%
counts_dem_deb1980
count_dem_platform2016
counts_rep_platform1980
counts_rep_deb2016
counts_dem_deb2016
countsDemDeb1980
# Out:
# Counter({'RB': 289,
#          'NN': 1707,
#          'JJ': 920,
#          'VB': 162,
#          'NNS': 560,
#          'IN': 85,
#          'VBG': 149,
#          'CD': 109,
#          'VBP': 242,
#          'VBD': 184,
#          'RBR': 13,
#          'DT': 13,
#          'MD': 89,
#          'VBN': 142,
#          'VBZ': 68,
#          'NNPS': 1,
#          'JJS': 14,
#          'JJR': 18,
#          'PRP': 12,
#          'FW': 2,
#          'NNP': 4,
#          'RP': 2,
#          ':': 2,
#          'UH': 1,
#          'CC': 1,
#          'WDT': 3})

# %%
deb2016 = Counter()
plat2016 = Counter()
dem2016vs1980 = Counter()


def compare_tokens_in_texts_with_ratio(counter_a, counter_b, tokenized_a, tokenized_b):
    ratio = len(tokenized_a) / len(tokenized_b)
    
    return_counter = Counter()
    for ele in counter_a:
        if (counter_a[ele]):
            return_counter.update(((ele,counter_b[ele] / counter_a[ele]/ ratio) ))
    return return_counter

# %%
dep_2016_counter = compare_tokens_in_texts_with_ratio(counts_dem_deb2016, counts_rep_deb2016, tokens_dem_debate_2016, tokens_rep_debate_2016)
platform_2016_counter = compare_tokens_in_texts_with_ratio(counts_rep_platform2016, count_dem_platform2016, tokens_dem_platform_2016, tokens_rep_platform_2016)
dep_2016_1980_counter = compare_tokens_in_texts_with_ratio(counts_dem_deb2016, counts_dem_deb1980,tokens_dem_debate_2016,tokens_dem_debate_1980)

# %%
for ele in dep_2016_counter:
    print(ele)
# Out:
# RB
# 1.2284002592609355
# JJ
# 1.1506176647342456
# NN
# 1.031316261621269
# NNS
# 0.9702765815253123
# VBP
# 0.9708957129606289
# VBG
# 1.3089783320577644
# PRP
# 0.4375281109908414
# VB
# 0.9949703140751449
# VBZ
# 0.741823977657404
# VBN
# 1.109785977179409
# FW
# 0.5729534786784828
# VBD
# MD
# 0.6827023140309809
# JJR
# 1.2375795139455228
# DT
# 0.6094141545943862
# CD
# 1.42295534831289
# RP
# 0.6562921664862621
# IN
# 1.321011840728367
# JJS
# 1.1024415210434253
# WDT
# 0.2062632523242538
# :
# 0.8471526434746137
# NNP
# 0.8438042140537656
# RBR
# 1.9153016287252138
# NNPS
# 0.0
# WP$
# UH
# 2.5782906540531725
# PRP$
# CC
# 4.125265046485076

# %%
for ele in platform_2016_counter:
    print(ele)
# Out:
# JJ
# 0.9528838945311806
# NN
# 0.9231027259229664
# VBP
# 1.2984670472346944
# NNS
# 1.10834436880125
# IN
# 0.8677086489280177
# RB
# 0.9911261967249346
# VBD
# 0.6955525868858004
# VBG
# 1.3640428390213077
# VBN
# 0.5038730465117448
# MD
# 0.9149694685864064
# VB
# 1.3604572255817111
# JJS
# 1.009398135798938
# VBZ
# 0.9309379380824443
# DT
# 1.0674643800174741
# PRP
# 0.5146703260798536
# JJR
# 1.5466103233207722
# RBR
# 1.4148755146049794
# RBS
# 3.275174802326341
# RP
# 2.1288636215121217
# NNPS
# 3.9302097627916095
# NNP
# 0.6550349604652682
# CD
# WRB
# 0.43668997364351214
# CC
# FW
# 1.0189432718348617
# WDT
# 0.13100699209305366
# WP$
# 0.374305691694439
# POS
# WP
# 0.0

# %%
for ele in dep_2016_1980_counter:
    print(ele)
# Out:
# RB
# 0.5913164665706251
# JJ
# 0.687450822747327
# NN
# 0.7062965037479302
# NNS
# 0.5397003081709032
# VBP
# 0.38211638485655774
# VBG
# 0.4071980865326159
# PRP
# 0.28421879865363797
# VB
# 0.5577950431726684
# VBZ
# 0.4662185556862307
# VBN
# 0.6031926134469872
# FW
# 0.17368926584388986
# VBD
# 0.5210677975316697
# MD
# 0.9797542390208155
# JJR
# 0.7034415266677541
# DT
# 0.46185554781216176
# CD
# 1.0784124670433923
# RP
# 0.14210939932681899
# IN
# 0.7464735301717739
# JJS
# 0.37732495683327805
# WDT
# 0.46896101777850263
# :
# 0.055828692592678884
# NNP
# RBR
# 1.4515460074096511
# NNPS
# 0.3908008481487522
# WP$
# 0.0
# UH
# PRP$
# CC
# 0.7816016962975044

# %% [markdown]
# ## SENTIMENT ANALYSIS SPEAKING ABOUT NOUNS (and vocabulary used for sentiment expression):

# %% [markdown]
# ### Handling imports:

# %%
! pip install afinn
! pip install pandas
#! pip install colorama
! pip install seaborn

from afinn import Afinn
import pandas as pd
from nltk import pos_tag
#import colorama
#colorama.init(autoreset = True)
# Out:
# Requirement already satisfied: afinn in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (0.1)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (1.3.5)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (0.11.2)
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: pandas>=0.23 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %% [markdown]
# ### Defining functions:

# %%
def getNounTokens(tokens_given):
    acceptedTokens=[]
    posTaggedTokens=pos_tag(tokens_given)
    #for now, only nouns
    listAcceptablePosTags=['NN','NNP','NNPS','NNS'] #removed 'VB' for now at least.
    for x in posTaggedTokens:
        if(x[1] in listAcceptablePosTags):
            acceptedTokens.append(x[0])
    return acceptedTokens

# %%
def getTokenScoreSentimentDataframe(_tokens):
    #Filtering tokens to only have nouns.
    tokens=getNounTokens(_tokens)
    
    #Using Affin for sentiment analysis:
    afn = Afinn()
    scores = [afn.score(token) for token in tokens]
    sentiments = ['positive' if score > 0
                            else 'negative' if score < 0
                                else 'neutral'
                                    for score in scores]
    df = pd.DataFrame()
    df['token'] =  tokens
    df['score'] = scores
    df['sentiment'] = sentiments
    #print(df.head)
    return df

# %%
def getAndPrintAverageScoreAndPrintStats(df):
    print(f"Maximal score: {df['score'].max(axis=0)}")
    avg=df.sum(axis=0)['score']/df.count()['score']
    print(f"Average score: {avg}")
    print(f"Minimal score: {df['score'].min(axis=0)}")
    sumScore=df['score'].sum(axis=0)
    print(f"Cumulative score: {sumScore}")
    return [avg,sumScore]

# %%
def printVariousAnalytics(df):
    print("Count of tokens of each type:")
    print(df.groupby(['sentiment'])['score'].count().reset_index(name='count'))
    print()
    print("Breakdown of cumulative scores:")
    sentimentSumTable=df.groupby(['sentiment'])['score'].sum().reset_index(name='sum');
    print(sentimentSumTable)
    print()
    ratioNeg2PosSum=(abs(sentimentSumTable['sum'][0]/sentimentSumTable['sum'][2]))
    print(f"Ratio of sum of negative to positive (-/+) scores: {ratioNeg2PosSum}")
    print()
    print("Sentiment frequency breakdown:")
    sentimentCountTable= df.groupby(['sentiment'])['sentiment'].count().reset_index(name='count') #df.groupby(['sentiment']).size().reset_index
    totalSentimentCount=df['sentiment'].size #totalSentimentCount=df['sentiment'].count()
    print(f"Note that total sentimental tokens count is {totalSentimentCount}")
    # for x in sentimentCountTable:
    #     print(f"{x['sentiment']}: {x['counts' in range(0,2)

    for i in range(0,3):
        print(f"{sentimentCountTable['sentiment'][i]}: {sentimentCountTable['count'][i]/totalSentimentCount}")
    ratioNeg2PosCount=sentimentCountTable['count'][0]/sentimentCountTable['count'][2]
    print(f"Ratio number of negative to number of positive (-/+) tokens: {ratioNeg2PosCount}")
    # print(f"Negative: {sentimentCountTable['counts'][0]/totalSentimentCount}")
    # print(f"Neutral: {sentimentCountTable['counts'][1]/totalSentimentCount}")
    # print(f"Positive: {sentimentCountTable['counts'][2]/totalSentimentCount}")
    return[ratioNeg2PosSum,ratioNeg2PosCount]

# %%
def showcaseDataframeObtained(df):
    print()
    print("First 10 entries of data frame:")
    print(df.head(10))
    print()
    print("Last 10 entries of data frame:")
    print(df.tail(10))
    print()
    print("TOP 10 scored tokens:")
    print(df.sort_values('score',ascending=False).head(10))
    print()
    print("LOWEST 10 scored tokens:")
    print(df.sort_values('score',ascending=True).head(10))
    print()

# %% [markdown]
# ### Analyzing Republican Platform 1980:

# %%
df=getTokenScoreSentimentDataframe(tokens_rep_platform_1980)
# #Printing first 10 entries of obtained dataframe:
# print(df.head(10))
#Showcasing the data used:
showcaseDataframeObtained(df)
# Out:
# First 10 entries of data frame:
#         token  score sentiment
# 0  convention    0.0   neutral
# 1        july    0.0   neutral
# 2     detroit    0.0   neutral
# 3        mich    0.0   neutral
# 4       party    0.0   neutral
# 5    convenes    0.0   neutral
# 6    presents    0.0   neutral
# 7     selects    0.0   neutral
# 8        time    0.0   neutral
# 9      crisis   -3.0  negative
#
# Last 10 entries of data frame:
#             token  score sentiment
# 9701      defense    0.0   neutral
# 9702       access    0.0   neutral
# 9703    resources    0.0   neutral
# 9704      promote    1.0  positive
# 9705      defense    0.0   neutral
# 9706  cooperation    0.0   neutral
# 9707       assure    0.0   neutral
# 9708   protection    0.0   neutral
# 9709      threats   -2.0  negative
# 9710    resources    0.0   neutral
#
# TOP 10 scored tokens:
#            token  score sentiment
# 1578     supreme    4.0  positive
# 5049  excellence    3.0  positive
# 1112    vitality    3.0  positive
# 6331        love    3.0  positive
# 156   prosperity    3.0  positive
# 919       wealth    3.0  positive
# 6785  prosperity    3.0  positive
# 977    happiness    3.0  positive
# 9347  prosperity    3.0  positive
# 9370  prosperity    3.0  positive
#
# LOWEST 10 scored tokens:
#              token  score sentiment
# 6037         fraud   -4.0  negative
# 674          fraud   -4.0  negative
# 603          fraud   -4.0  negative
# 1923  catastrophic   -4.0  negative
# 4992         fraud   -4.0  negative
# 704          fraud   -4.0  negative
# 1973         fraud   -4.0  negative
# 2842         crime   -3.0  negative
# 7416          loss   -3.0  negative
# 7343       scandal   -3.0  negative

# %%
print()
listAvgSum_RepPlat1980=[]
listAvgSum_RepPlat1980=getAndPrintAverageScoreAndPrintStats(df)
avg=listAvgSum_RepPlat1980[0]
print()
print("Words with a score more negative than average:")
print(df.query(f'score<{avg}'))
print("Words with a score more positive than average:")
print(df.query(f'score>{avg}'))
print("Words with a score same as the average:")
print(df.query(f'score=={avg}'))
# Out:
# Maximal score: 4.0
# Average score: 0.033158274122129544
# Minimal score: -4.0
# Cumulative score: 322.0
#
# Words with a score more negative than average:
#             token  score sentiment
# 0      convention    0.0   neutral
# 1            july    0.0   neutral
# 2         detroit    0.0   neutral
# 3            mich    0.0   neutral
# 4           party    0.0   neutral
# ...           ...    ...       ...
# 9706  cooperation    0.0   neutral
# 9707       assure    0.0   neutral
# 9708   protection    0.0   neutral
# 9709      threats   -2.0  negative
# 9710    resources    0.0   neutral
#
# [8929 rows x 3 columns]
# Words with a score more positive than average:
#             token  score sentiment
# 53       vitality    3.0  positive
# 114    leadership    1.0  positive
# 117    confidence    2.0  positive
# 127        growth    2.0  positive
# 134       promise    1.0  positive
# ...           ...    ...       ...
# 9673  exploration    1.0  positive
# 9684    abilities    2.0  positive
# 9685     interest    1.0  positive
# 9700     interest    1.0  positive
# 9704      promote    1.0  positive
#
# [782 rows x 3 columns]
# Words with a score same as the average:
# Empty DataFrame
# Columns: [token, score, sentiment]
# Index: []

# %%
#Printing scores:
listRatioScoreCount_RepPlat1980=[]
listRatioScoreCount_RepPlat1980=printVariousAnalytics(df)
# df1.groupby(['sentiments'])['scores'].sum().reset_index()
# df1.groupby(['sentiments'])['scores'].sum().reset_index()['scores']
# df1.groupby(['sentiments'])['scores'].count().reset_index()['scores']
# Out:
# Count of tokens of each type:
#   sentiment  count
# 0  negative    515
# 1   neutral   8414
# 2  positive    782
#
# Breakdown of cumulative scores:
#   sentiment     sum
# 0  negative  -990.0
# 1   neutral     0.0
# 2  positive  1312.0
#
# Ratio of sum of negative to positive (-/+) scores: 0.7545731707317073
#
# Sentiment frequency breakdown:
# Note that total sentimental tokens count is 9711
# negative: 0.053032643394089175
# neutral: 0.8664401194521676
# positive: 0.08052723715374317
# Ratio number of negative to number of positive (-/+) tokens: 0.6585677749360613

# %% [markdown]
# ### Analyzing Democrat Platform 1980 :

# %%
df=getTokenScoreSentimentDataframe(tokens_dem_platform_1980)
#Showcasing the data we have:
showcaseDataframeObtained(df)
# Out:
# First 10 entries of data frame:
#         token  score sentiment
# 0     century    0.0   neutral
# 1     america    0.0   neutral
# 2  challenges    0.0   neutral
# 3      decade    0.0   neutral
# 4     america    0.0   neutral
# 5      enters    0.0   neutral
# 6   decisions    0.0   neutral
# 7         war   -2.0  negative
# 8       world    0.0   neutral
# 9        wars    0.0   neutral
#
# Last 10 entries of data frame:
#            token  score sentiment
# 10894       home    0.0   neutral
# 10895  restoring    1.0  positive
# 10896    america    0.0   neutral
# 10897      place    0.0   neutral
# 10898     nation    0.0   neutral
# 10899      world    0.0   neutral
# 10900     nation    0.0   neutral
# 10901   champion    2.0  positive
# 10902    justice    2.0  positive
# 10903    freedom    2.0  positive
#
# TOP 10 scored tokens:
#            token  score sentiment
# 8899      winner    4.0  positive
# 645   prosperity    3.0  positive
# 9834  prosperity    3.0  positive
# 419     vitality    3.0  positive
# 3738  excellence    3.0  positive
# 679   prosperity    3.0  positive
# 7658  prosperity    3.0  positive
# 7822    vitality    3.0  positive
# 633   prosperity    3.0  positive
# 4380        help    2.0  positive
#
# LOWEST 10 scored tokens:
#            token  score sentiment
# 6217       fraud   -4.0  negative
# 6195       fraud   -4.0  negative
# 965        fraud   -4.0  negative
# 903        fraud   -4.0  negative
# 2300  fatalities   -3.0  negative
# 2839     outrage   -3.0  negative
# 3712      crisis   -3.0  negative
# 2304       abuse   -3.0  negative
# 2309       abuse   -3.0  negative
# 2314       abuse   -3.0  negative

# %%
print()
listAvgSum_DemPlat1980=[]
listAvgSum_DemPlat1980=getAndPrintAverageScoreAndPrintStats(df)
avg=listAvgSum_DemPlat1980[0]
print()
print("Words with a score more negative than average:")
print(df.query(f'score<{avg}'))
print("Words with a score more positive than average:")
print(df.query(f'score>{avg}'))
print("Words with a score same as the average:")
print(df.query(f'score=={avg}'))
# Out:
# Maximal score: 4.0
# Average score: 0.07492663242846662
# Minimal score: -4.0
# Cumulative score: 817.0
#
# Words with a score more negative than average:
#             token  score sentiment
# 0         century    0.0   neutral
# 1         america    0.0   neutral
# 2      challenges    0.0   neutral
# 3          decade    0.0   neutral
# 4         america    0.0   neutral
# ...           ...    ...       ...
# 10896     america    0.0   neutral
# 10897       place    0.0   neutral
# 10898      nation    0.0   neutral
# 10899       world    0.0   neutral
# 10900      nation    0.0   neutral
#
# [9938 rows x 3 columns]
# Words with a score more positive than average:
#              token  score sentiment
# 17      confidence    2.0  positive
# 18            hope    2.0  positive
# 41     exploration    1.0  positive
# 43          spirit    1.0  positive
# 48      dedication    2.0  positive
# ...            ...    ...       ...
# 10885     strength    2.0  positive
# 10895    restoring    1.0  positive
# 10901     champion    2.0  positive
# 10902      justice    2.0  positive
# 10903      freedom    2.0  positive
#
# [966 rows x 3 columns]
# Words with a score same as the average:
# Empty DataFrame
# Columns: [token, score, sentiment]
# Index: []

# %%
#Printing scores:
listRatioScoreCount_DemPlat1980=[]
listRatioScoreCount_DemPlat1980=printVariousAnalytics(df)
# Out:
# Count of tokens of each type:
#   sentiment  count
# 0  negative    448
# 1   neutral   9490
# 2  positive    966
#
# Breakdown of cumulative scores:
#   sentiment     sum
# 0  negative  -855.0
# 1   neutral     0.0
# 2  positive  1672.0
#
# Ratio of sum of negative to positive (-/+) scores: 0.5113636363636364
#
# Sentiment frequency breakdown:
# Note that total sentimental tokens count is 10904
# negative: 0.041085840058694055
# neutral: 0.8703228173147469
# positive: 0.08859134262655906
# Ratio number of negative to number of positive (-/+) tokens: 0.463768115942029

# %% [markdown]
# ### What we have seen so far (Analysis 1):
# So far, we can see the Republicans used more negative vernacular/portrayed a slightly more negative outlook than the Democrats in the platforms. However, the discourse remains mostly positive overall. Both in ratio of intensity (negativescore/positivescore) and quantity (negativewordcount/positivewordcount).

# %% [markdown]
# ### Analyzing Republican debate from 1980:

# %%
df=getTokenScoreSentimentDataframe(tokens_rep_debate_1980)
#Showcasing the data we have:
showcaseDataframeObtained(df)
# Out:
# First 10 entries of data frame:
#          token  score sentiment
# 0         know    0.0   neutral
# 1  differences    0.0   neutral
# 2     policies    0.0   neutral
# 3          i'm    0.0   neutral
# 4         tell    0.0   neutral
# 5        heart    0.0   neutral
# 6     priority    0.0   neutral
# 7        world    0.0   neutral
# 8        peace    2.0  positive
# 9          use    0.0   neutral
#
# Last 10 entries of data frame:
#          token  score sentiment
# 2069  problems   -2.0  negative
# 2070    people    0.0   neutral
# 2071   country    0.0   neutral
# 2072     world    0.0   neutral
# 2073      meet    0.0   neutral
# 2074   destiny    0.0   neutral
# 2075     build    0.0   neutral
# 2076      land    0.0   neutral
# 2077      city    0.0   neutral
# 2078      hill    0.0   neutral
#
# TOP 10 scored tokens:
#            token  score sentiment
# 2001        love    3.0  positive
# 1472     benefit    2.0  positive
# 163       growth    2.0  positive
# 1600        kind    2.0  positive
# 1788  confidence    2.0  positive
# 1021      chance    2.0  positive
# 1553        fine    2.0  positive
# 42         peace    2.0  positive
# 108        peace    2.0  positive
# 1017    freedoms    2.0  positive
#
# LOWEST 10 scored tokens:
#          token  score sentiment
# 259      fraud   -4.0  negative
# 249      fraud   -4.0  negative
# 877   warnings   -3.0  negative
# 40      crisis   -3.0  negative
# 53      bloody   -3.0  negative
# 992      crime   -3.0  negative
# 398    despair   -3.0  negative
# 371    despair   -3.0  negative
# 924    destroy   -3.0  negative
# 1441    crisis   -3.0  negative

# %%
print()
listAvgSum_RepDeb1980=[]
listAvgSum_RepDeb1980=getAndPrintAverageScoreAndPrintStats(df)
avg=listAvgSum_RepDeb1980[0]
print()
print("Words with a score more negative than average:")
print(df.query(f'score<{avg}'))
print("Words with a score more positive than average:")
print(df.query(f'score>{avg}'))
print("Words with a score same as the average:")
print(df.query(f'score=={avg}'))
# Out:
# Maximal score: 3.0
# Average score: -0.01443001443001443
# Minimal score: -4.0
# Cumulative score: -30.0
#
# Words with a score more negative than average:
#          token  score sentiment
# 25      burden   -2.0  negative
# 30         war   -2.0  negative
# 31         war   -2.0  negative
# 40      crisis   -3.0  negative
# 45      crisis   -3.0  negative
# ...        ...    ...       ...
# 1978  failures   -2.0  negative
# 2019      fire   -2.0  negative
# 2034  problems   -2.0  negative
# 2038   retreat   -1.0  negative
# 2069  problems   -2.0  negative
#
# [108 rows x 3 columns]
# Words with a score more positive than average:
#             token  score sentiment
# 0            know    0.0   neutral
# 1     differences    0.0   neutral
# 2        policies    0.0   neutral
# 3             i'm    0.0   neutral
# 4            tell    0.0   neutral
# ...           ...    ...       ...
# 2074      destiny    0.0   neutral
# 2075        build    0.0   neutral
# 2076         land    0.0   neutral
# 2077         city    0.0   neutral
# 2078         hill    0.0   neutral
#
# [1971 rows x 3 columns]
# Words with a score same as the average:
# Empty DataFrame
# Columns: [token, score, sentiment]
# Index: []

# %%
#Printing scores:
listRatioScoreCount_RepDeb1980=[]
listRatioScoreCount_RepDeb1980=printVariousAnalytics(df)
# Out:
# Count of tokens of each type:
#   sentiment  count
# 0  negative    108
# 1   neutral   1852
# 2  positive    119
#
# Breakdown of cumulative scores:
#   sentiment    sum
# 0  negative -203.0
# 1   neutral    0.0
# 2  positive  173.0
#
# Ratio of sum of negative to positive (-/+) scores: 1.1734104046242775
#
# Sentiment frequency breakdown:
# Note that total sentimental tokens count is 2079
# negative: 0.05194805194805195
# neutral: 0.8908128908128908
# positive: 0.05723905723905724
# Ratio number of negative to number of positive (-/+) tokens: 0.907563025210084

# %% [markdown]
# ### Analyzing Democrat debate from 1980:

# %%
df=getTokenScoreSentimentDataframe(tokens_dem_debate_1980)
#Showcasing the data we have:
showcaseDataframeObtained(df)
# Out:
# First 10 entries of data frame:
#        token  score sentiment
# 0         mr    0.0   neutral
# 1      stone    0.0   neutral
# 2  thousands    0.0   neutral
# 3  decisions    0.0   neutral
# 4       i've    0.0   neutral
# 5  president    0.0   neutral
# 6     office    0.0   neutral
# 7  decisions    0.0   neutral
# 8    country    0.0   neutral
# 9        man    0.0   neutral
#
# Last 10 entries of data frame:
#            token  score sentiment
# 2262    campaign    0.0   neutral
# 2263      people    0.0   neutral
# 2264  government    0.0   neutral
# 2265        john    0.0   neutral
# 2266    anderson    0.0   neutral
# 2267       lucey    0.0   neutral
# 2268        kind    2.0  positive
# 2269   coalition    0.0   neutral
# 2270  government    0.0   neutral
# 2271    problems   -2.0  negative
#
# TOP 10 scored tokens:
#             token  score sentiment
# 2230      victory    3.0  positive
# 749    commitment    2.0  positive
# 1028  opportunity    2.0  positive
# 1622      respect    2.0  positive
# 1865         kind    2.0  positive
# 2196  opportunity    2.0  positive
# 807   opportunity    2.0  positive
# 1366      chances    2.0  positive
# 556        assets    2.0  positive
# 148      strength    2.0  positive
#
# LOWEST 10 scored tokens:
#               token  score sentiment
# 942      bankruptcy   -3.0  negative
# 1566         crisis   -3.0  negative
# 2271       problems   -2.0  negative
# 976          threat   -2.0  negative
# 1814       problems   -2.0  negative
# 452    unemployment   -2.0  negative
# 703             war   -2.0  negative
# 465   insensitivity   -2.0  negative
# 129        troubles   -2.0  negative
# 1586      emergency   -2.0  negative

# %%
print()
listAvgSum_DemDeb1980=[]
listAvgSum_DemDeb1980=getAndPrintAverageScoreAndPrintStats(df)
avg=listAvgSum_DemDeb1980[0]
print()
print("Words with a score more negative than average:")
print(df.query(f'score<{avg}'))
print("Words with a score more positive than average:")
print(df.query(f'score>{avg}'))
print("Words with a score same as the average:")
print(df.query(f'score=={avg}'))
# Out:
# Maximal score: 3.0
# Average score: 0.03697183098591549
# Minimal score: -3.0
# Cumulative score: 84.0
#
# Words with a score more negative than average:
#            token  score sentiment
# 0             mr    0.0   neutral
# 1          stone    0.0   neutral
# 2      thousands    0.0   neutral
# 3      decisions    0.0   neutral
# 4           i've    0.0   neutral
# ...          ...    ...       ...
# 2266    anderson    0.0   neutral
# 2267       lucey    0.0   neutral
# 2269   coalition    0.0   neutral
# 2270  government    0.0   neutral
# 2271    problems   -2.0  negative
#
# [2133 rows x 3 columns]
# Words with a score more positive than average:
#             token  score sentiment
# 25       strength    2.0  positive
# 34       increase    1.0  positive
# 35     commitment    2.0  positive
# 40       strength    2.0  positive
# 42          peace    2.0  positive
# ...           ...    ...       ...
# 2230      victory    3.0  positive
# 2237      resolve    2.0  positive
# 2244         kind    2.0  positive
# 2247  recognition    2.0  positive
# 2268         kind    2.0  positive
#
# [139 rows x 3 columns]
# Words with a score same as the average:
# Empty DataFrame
# Columns: [token, score, sentiment]
# Index: []

# %%
#Printing scores:
listRatioScoreCount_DemDeb1980=[]
listRatioScoreCount_DemDeb1980=printVariousAnalytics(df)
# Out:
# Count of tokens of each type:
#   sentiment  count
# 0  negative     88
# 1   neutral   2045
# 2  positive    139
#
# Breakdown of cumulative scores:
#   sentiment    sum
# 0  negative -152.0
# 1   neutral    0.0
# 2  positive  236.0
#
# Ratio of sum of negative to positive (-/+) scores: 0.6440677966101694
#
# Sentiment frequency breakdown:
# Note that total sentimental tokens count is 2272
# negative: 0.03873239436619718
# neutral: 0.9000880281690141
# positive: 0.061179577464788734
# Ratio number of negative to number of positive (-/+) tokens: 0.6330935251798561

# %% [markdown]
# ### What we have seen so far (Analysis 2):
# What we see here is almost akin to an exaggerated situation of Analysis 1 in some aspects. First thing we notice is Republican is significantly more negative in the debate than in the platform (as one might expect), however, the Democratic party has similar sentimental aspects to their vernacular as to what they had in the platform (as one might NOT have expected). Consequently, we see that the Republicans are slightly more negative than they are positive when it comes to the intensity (score). Meanwhile, Democrats have a similar ratio of scores and ratio of number of words of each type.

# %% [markdown]
# ### Analyzing Republican debate from 2016:

# %%
df=getTokenScoreSentimentDataframe(tokens_rep_debate_2016)
#Showcasing the data we have:
showcaseDataframeObtained(df)
# Out:
# First 10 entries of data frame:
#         token  score sentiment
# 0       thank    2.0  positive
# 1   everybody    0.0   neutral
# 2       court    0.0   neutral
# 3     country    0.0   neutral
# 4    justices    0.0   neutral
# 5   something    0.0   neutral
# 6     justice    2.0  positive
# 7    ginsburg    0.0   neutral
# 8  statements    0.0   neutral
# 9      number    0.0   neutral
#
# Last 10 entries of data frame:
#          token  score sentiment
# 2651      quit    0.0   neutral
# 2652   respect    2.0  positive
# 2653      tell    0.0   neutral
# 2654   fighter    0.0   neutral
# 2655  fighting   -2.0  negative
# 2656  judgment    0.0   neutral
# 2657     cases    0.0   neutral
# 2658      quit    0.0   neutral
# 2659  consider    0.0   neutral
# 2660     trait    0.0   neutral
#
# TOP 10 scored tokens:
#                 token  score sentiment
# 1461           winner    4.0  positive
# 901            winner    4.0  positive
# 22                win    4.0  positive
# 950            winner    4.0  positive
# 1513              win    4.0  positive
# 2596           wealth    3.0  positive
# 1497  super-delegates    3.0  positive
# 2317            medal    3.0  positive
# 691              love    3.0  positive
# 1000            loves    3.0  positive
#
# LOWEST 10 scored tokens:
#             token  score sentiment
# 1324         hell   -4.0  negative
# 1695        fraud   -4.0  negative
# 1707        fraud   -4.0  negative
# 982   catastrophe   -3.0  negative
# 731          hate   -3.0  negative
# 62       violence   -3.0  negative
# 66       violence   -3.0  negative
# 644      violence   -3.0  negative
# 85         damage   -3.0  negative
# 28         trauma   -3.0  negative

# %%
print()
listAvgSum_RepDeb2016=[]
listAvgSum_RepDeb2016=getAndPrintAverageScoreAndPrintStats(df)
avg=listAvgSum_RepDeb2016[0]
print()
print("Words with a score more negative than average:")
print(df.query(f'score<{avg}'))
print("Words with a score more positive than average:")
print(df.query(f'score>{avg}'))
print("Words with a score same as the average:")
print(df.query(f'score=={avg}'))
# Out:
# Maximal score: 4.0
# Average score: -0.013528748590755355
# Minimal score: -4.0
# Cumulative score: -36.0
#
# Words with a score more negative than average:
#             token  score sentiment
# 28         trauma   -3.0  negative
# 59            gun   -1.0  negative
# 62       violence   -3.0  negative
# 65            gun   -1.0  negative
# 66       violence   -3.0  negative
# ...           ...    ...       ...
# 2608          pay   -1.0  negative
# 2627  restrictive   -1.0  negative
# 2640     disgrace   -2.0  negative
# 2642     disgrace   -2.0  negative
# 2655     fighting   -2.0  negative
#
# [143 rows x 3 columns]
# Words with a score more positive than average:
#           token  score sentiment
# 0         thank    2.0  positive
# 1     everybody    0.0   neutral
# 2         court    0.0   neutral
# 3       country    0.0   neutral
# 4      justices    0.0   neutral
# ...         ...    ...       ...
# 2656   judgment    0.0   neutral
# 2657      cases    0.0   neutral
# 2658       quit    0.0   neutral
# 2659   consider    0.0   neutral
# 2660      trait    0.0   neutral
#
# [2518 rows x 3 columns]
# Words with a score same as the average:
# Empty DataFrame
# Columns: [token, score, sentiment]
# Index: []

# %%
#Printing scores:
listRatioScoreCount_RepDeb2016=[]
listRatioScoreCount_RepDeb2016=printVariousAnalytics(df)
# Out:
# Count of tokens of each type:
#   sentiment  count
# 0  negative    143
# 1   neutral   2387
# 2  positive    131
#
# Breakdown of cumulative scores:
#   sentiment    sum
# 0  negative -286.0
# 1   neutral    0.0
# 2  positive  250.0
#
# Ratio of sum of negative to positive (-/+) scores: 1.144
#
# Sentiment frequency breakdown:
# Note that total sentimental tokens count is 2661
# negative: 0.053739195791055995
# neutral: 0.8970311912814731
# positive: 0.04922961292747088
# Ratio number of negative to number of positive (-/+) tokens: 1.0916030534351144

# %% [markdown]
# ### Analyzing Democrat debate from 2016:

# %%
df=getTokenScoreSentimentDataframe(tokens_dem_debate_2016)
#Showcasing the data we have:
showcaseDataframeObtained(df)
# Out:
# First 10 entries of data frame:
#            token  score sentiment
# 0          chris    0.0   neutral
# 1         thanks    2.0  positive
# 2          court    0.0   neutral
# 3          issue    0.0   neutral
# 4       election    0.0   neutral
# 5           kind    2.0  positive
# 6        country    0.0   neutral
# 7           kind    2.0  positive
# 8  opportunities    2.0  positive
# 9       citizens    0.0   neutral
#
# Last 10 entries of data frame:
#            token  score sentiment
# 2703   president    0.0   neutral
# 2704      that's    0.0   neutral
# 2705      people    0.0   neutral
# 2706       years    0.0   neutral
# 2707        help    2.0  positive
# 2708        kids    0.0   neutral
# 2709    families    0.0   neutral
# 2710  experience    0.0   neutral
# 2711       house    0.0   neutral
# 2712         day    0.0   neutral
#
# TOP 10 scored tokens:
#           token  score sentiment
# 2694    supreme    4.0  positive
# 2499     wealth    3.0  positive
# 1548  celebrate    3.0  positive
# 2312       hope    2.0  positive
# 2637    support    2.0  positive
# 242       honor    2.0  positive
# 2064       gift    2.0  positive
# 784     justice    2.0  positive
# 1155    justice    2.0  positive
# 2061       care    2.0  positive
#
# LOWEST 10 scored tokens:
#            token  score sentiment
# 870        fraud   -4.0  negative
# 1016       fraud   -4.0  negative
# 881     violence   -3.0  negative
# 2491      crisis   -3.0  negative
# 1605      racist   -3.0  negative
# 2439    violence   -3.0  negative
# 2631     worries   -3.0  negative
# 1175  conspiracy   -3.0  negative
# 1176  conspiracy   -3.0  negative
# 2236     destroy   -3.0  negative

# %%
print()
listAvgSum_DemDeb2016=[]
listAvgSum_DemDeb2016=getAndPrintAverageScoreAndPrintStats(df)
avg=listAvgSum_DemDeb2016[0]
print()
print("Words with a score more negative than average:")
print(df.query(f'score<{avg}'))
print("Words with a score more positive than average:")
print(df.query(f'score>{avg}'))
print("Words with a score same as the average:")
print(df.query(f'score=={avg}'))
# Out:
# Maximal score: 4.0
# Average score: 0.010689273866568375
# Minimal score: -4.0
# Cumulative score: 29.0
#
# Words with a score more negative than average:
#            token  score sentiment
# 0          chris    0.0   neutral
# 2          court    0.0   neutral
# 3          issue    0.0   neutral
# 4       election    0.0   neutral
# 6        country    0.0   neutral
# ...          ...    ...       ...
# 2708        kids    0.0   neutral
# 2709    families    0.0   neutral
# 2710  experience    0.0   neutral
# 2711       house    0.0   neutral
# 2712         day    0.0   neutral
#
# [2549 rows x 3 columns]
# Words with a score more positive than average:
#               token  score sentiment
# 1            thanks    2.0  positive
# 5              kind    2.0  positive
# 7              kind    2.0  positive
# 8     opportunities    2.0  positive
# 10             kind    2.0  positive
# ...             ...    ...       ...
# 2665           hope    2.0  positive
# 2671        respect    2.0  positive
# 2677        respect    2.0  positive
# 2694        supreme    4.0  positive
# 2707           help    2.0  positive
#
# [164 rows x 3 columns]
# Words with a score same as the average:
# Empty DataFrame
# Columns: [token, score, sentiment]
# Index: []

# %%
#Printing scores:
listRatioScoreCount_DemDeb2016=[]
listRatioScoreCount_DemDeb2016=printVariousAnalytics(df)
# Out:
# Count of tokens of each type:
#   sentiment  count
# 0  negative    140
# 1   neutral   2409
# 2  positive    164
#
# Breakdown of cumulative scores:
#   sentiment    sum
# 0  negative -260.0
# 1   neutral    0.0
# 2  positive  289.0
#
# Ratio of sum of negative to positive (-/+) scores: 0.8996539792387543
#
# Sentiment frequency breakdown:
# Note that total sentimental tokens count is 2713
# negative: 0.05160339107998525
# neutral: 0.8879469222263178
# positive: 0.06044968669369701
# Ratio number of negative to number of positive (-/+) tokens: 0.8536585365853658

# %% [markdown]
# ### What we have seen so far (Analysis 3):
# Clearly, Democrats have gotten significantly more negative as compared to their debate in 1980, but not enough to be able to catch up to the Republicans, who have stayed relatively stagnant in their intensity of being negative scores but have increased a fair bit in the ratio of negative words used to ratio of positive words used.

# %% [markdown]
# ### Some relevant plots:

# %%
eventNames=["Platform 1980","Platform 1980", "Debate 1980", "Debate 1980", "Debate 2016", "Debate 2016"]
partyNames=["Republican", "Democratic", "Republican", "Democratic", "Republican", "Democratic"]
averages=[listAvgSum_RepPlat1980[0],listAvgSum_DemPlat1980[0],listAvgSum_RepDeb1980[0],listAvgSum_DemDeb1980[0],listAvgSum_RepDeb2016[0],listAvgSum_DemDeb2016[0]]
sums=[listAvgSum_RepPlat1980[1],listAvgSum_DemPlat1980[1],listAvgSum_RepDeb1980[1],listAvgSum_DemDeb1980[1],listAvgSum_RepDeb2016[1],listAvgSum_DemDeb2016[1]]

ratiosScore=[listRatioScoreCount_RepPlat1980[0],listRatioScoreCount_DemPlat1980[0],listRatioScoreCount_RepDeb1980[0],listRatioScoreCount_DemDeb1980[0],listRatioScoreCount_RepDeb2016[0],listRatioScoreCount_DemDeb2016[0]]
ratiosCount=[listRatioScoreCount_RepPlat1980[1],listRatioScoreCount_DemPlat1980[1],listRatioScoreCount_RepDeb1980[1],listRatioScoreCount_DemDeb1980[1],listRatioScoreCount_RepDeb2016[1],listRatioScoreCount_DemDeb2016[1]]



dataPlot={
    'Party': partyNames,
    'Type': eventNames,
    'AverageScore': averages,
    'SumOfScores': sums,
    'RatioNegative2Positive_ScoreSum':ratiosScore,
    'RatioNegative2Positive_WordCount':ratiosCount
}

dfPlot=pd.DataFrame(dataPlot)
print(dfPlot.groupby("Type").head(20))
# Out:
#         Party           Type  AverageScore  SumOfScores  \
# 0  Republican  Platform 1980      0.033158        322.0
# 1  Democratic  Platform 1980      0.074927        817.0
# 2  Republican    Debate 1980     -0.014430        -30.0
# 3  Democratic    Debate 1980      0.036972         84.0
# 4  Republican    Debate 2016     -0.013529        -36.0
# 5  Democratic    Debate 2016      0.010689         29.0
#
#    RatioNegative2Positive_ScoreSum  RatioNegative2Positive_WordCount
# 0                         0.754573                          0.658568
# 1                         0.511364                          0.463768
# 2                         1.173410                          0.907563
# 3                         0.644068                          0.633094
# 4                         1.144000                          1.091603
# 5                         0.899654                          0.853659

# %%
import seaborn as sns

# %% [markdown]
# #### Plot of Average Score of each party for various events
# Higher is positive, lower is negative.

# %%
matplotlib.rcParams.update(matplotlib.rcParamsDefault)
fig, axi = plt.subplots()
axi.set_title="Plot of Average Score of each party for various events"
axi.text(0.22, 0.22,'Higher is positive, lower is negative.', fontsize=9) #add text
sns.barplot(y='AverageScore',x='Type',hue='Party',data=dfPlot,ax=axi)
axi.set_ylim(-0.2,0.2)
plt.show()

# %% [markdown]
# #### Plot of Sum of Scores of each party for various events
# Higher is positive, lower is negative.

# %%
fig, axi = plt.subplots()
axi.set_ylim(-100,900)
sns.barplot(y='SumOfScores',x='Type',hue='Party',data=dfPlot,ax=axi)
plt.show()

# %% [markdown]
# #### Plot of Ratio of positive scores of each party to their negative score
# Lower is better because lower ratio means more positive score. If the ratio>1, the negative score was greater than positive score and vice-versa.

# %%
fig, axi = plt.subplots()
axi.set_ylim(-3,3)
sns.barplot(y='RatioNegative2Positive_ScoreSum',x='Type',hue='Party',data=dfPlot,ax=axi)
plt.show()

# %% [markdown]
# #### Plot of Ratio of number of positive tokens of each party to the number of their negative tokens.
# Lower is better because lower ratio means more positive words were used. If the ratio > 1, the number of negative tokens was greater than positive tokens (and vice-versa).

# %%
fig, axi = plt.subplots()
axi.set_ylim(-3,3)
sns.barplot(y='RatioNegative2Positive_WordCount',x='Type',hue='Party',data=dfPlot,ax=axi)
plt.show()
