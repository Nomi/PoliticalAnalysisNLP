# %%
from bs4 import BeautifulSoup
from nltk import word_tokenize, sent_tokenize
from nltk.tokenize import TweetTokenizer
from urllib import request
import string
import nltk
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context
from nltk.stem import WordNetLemmatizer

# %%
# nltk.download('punkt')
# nltk.download('omw-1.4')

# %% [markdown]
# ## Democratic Party Platform 2016

# %%
url_dem_platform_2016 = 'https://www.presidency.ucsb.edu/documents/2016-democratic-party-platform'
url_debate_las_vegas_2016 = 'https://www.presidency.ucsb.edu/documents/presidential-debate-the-university-nevada-las-vegas'
url_debate_st_louis_2016 = 'https://www.presidency.ucsb.edu/documents/presidential-debate-washington-university-st-louis-missouri'
url_rep_platform_2016 = 'https://www.presidency.ucsb.edu/documents/2016-republican-party-platform'
url_dem_platform_1980 = 'https://www.presidency.ucsb.edu/documents/1980-democratic-party-platform'
url_rep_platform_1980 = 'https://www.presidency.ucsb.edu/documents/republican-party-platform-1980'
url_debate_cleveland_1980 = 'https://www.presidency.ucsb.edu/documents/presidential-debate-cleveland'
url_debate_baltimore_1980 = 'https://www.presidency.ucsb.edu/documents/presidential-debate-baltimore-reagan-anderson'
en_stop = set(nltk.corpus.stopwords.words('english'))
tokenizer = TweetTokenizer()
lemmatizer = WordNetLemmatizer()

# %%
html_dem_platform_2016 = request.urlopen(url_dem_platform_2016).read().decode('utf8')
raw_dem_platform_2016 = BeautifulSoup(html_dem_platform_2016, 'html.parser')
raw_dem_platform_2016 = [p.get_text() for p in raw_dem_platform_2016.select('div.field-docs-content > p')]
raw_dem_platform_2016 = ' '.join(raw_dem_platform_2016)

tokens_dem_platform_2016 = tokenizer.tokenize(raw_dem_platform_2016)
tokens_dem_platform_2016 = [char.lower() for char in tokens_dem_platform_2016]
tokens_dem_platform_2016 = [char for char in tokens_dem_platform_2016 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_dem_platform_2016

lemmatized_tokens_dem_platform_2016 = [lemmatizer.lemmatize(word) for word in tokens_dem_platform_2016]
lemmatized_tokens_dem_platform_2016
# Out:
# ['preamble',
#  '2016',
#  'democrat',
#  'meet',
#  'philadelphia',
#  'basic',
#  'belief',
#  'animated',
#  'continental',
#  'congress',
#  'gathered',
#  '240',
#  'year',
#  'ago',
#  'many',
#  'one',
#  'president',
#  "obama's",
#  'leadership',
#  'thanks',
#  'hard',
#  'work',
#  'determination',
#  'american',
#  'people',
#  'come',
#  'long',
#  'way',
#  'great',
#  'recession',
#  'republican',
#  'policy',
#  'triggered',
#  'american',
#  'business',
#  'added',
#  '14.8',
#  'million',
#  'job',
#  'since',
#  'private-sector',
#  'job',
#  'growth',
#  'turned',
#  'positive',
#  'early',
#  '2010',
#  'twenty',
#  'million',
#  'people',
#  'gained',
#  'health',
#  'insurance',
#  'coverage',
#  'american',
#  'auto',
#  'industry',
#  'best',
#  'year',
#  'ever',
#  'getting',
#  'energy',
#  'sun',
#  'wind',
#  'importing',
#  'le',
#  'oil',
#  'overseas',
#  'many',
#  'american',
#  'left',
#  'left',
#  'behind',
#  'working',
#  'longer',
#  'hour',
#  'le',
#  'security',
#  'wage',
#  'barely',
#  'budged',
#  'racial',
#  'wealth',
#  'gap',
#  'remains',
#  'wide',
#  'cost',
#  'everything',
#  'childcare',
#  'college',
#  'education',
#  'continued',
#  'rise',
#  'many',
#  'family',
#  'dream',
#  'homeownership',
#  'reach',
#  'working',
#  'people',
#  'struggle',
#  'top',
#  'one',
#  'percent',
#  'accrues',
#  'wealth',
#  'power',
#  'republican',
#  'congress',
#  'chosen',
#  'gridlock',
#  'dysfunction',
#  'trying',
#  'find',
#  'solution',
#  'real',
#  'challenge',
#  'face',
#  'wonder',
#  'many',
#  'feel',
#  'like',
#  'system',
#  'rigged',
#  'democrat',
#  'believe',
#  'cooperation',
#  'better',
#  'conflict',
#  'unity',
#  'better',
#  'division',
#  'empowerment',
#  'better',
#  'resentment',
#  'bridge',
#  'better',
#  'wall',
#  'simple',
#  'powerful',
#  'idea',
#  'stronger',
#  'together',
#  'democrat',
#  'believe',
#  'stronger',
#  'economy',
#  'work',
#  'everyone',
#  'economy',
#  'grows',
#  'income',
#  'working',
#  'people',
#  'creates',
#  'good-paying',
#  'job',
#  'put',
#  'middle-class',
#  'life',
#  'within',
#  'reach',
#  'american',
#  'democrat',
#  'believe',
#  'spur',
#  'sustainable',
#  'economic',
#  'growth',
#  'create',
#  'good-paying',
#  'job',
#  'raise',
#  'wage',
#  'economic',
#  'fairness',
#  'reward',
#  'shared',
#  'broadly',
#  'top',
#  'need',
#  'economy',
#  'prioritizes',
#  'long-term',
#  'investment',
#  'short-term',
#  'profit-seeking',
#  'reward',
#  'common',
#  'interest',
#  'self-interest',
#  'promotes',
#  'innovation',
#  'entrepreneurship',
#  'believe',
#  "today's",
#  'extreme',
#  'level',
#  'income',
#  'wealth',
#  'inequality',
#  'majority',
#  'economic',
#  'gain',
#  'go',
#  'top',
#  'one',
#  'percent',
#  'richest',
#  '20',
#  'people',
#  'country',
#  'wealth',
#  'bottom',
#  '150',
#  'million',
#  'make',
#  'economy',
#  'weaker',
#  'community',
#  'poorer',
#  'politics',
#  'poisonous',
#  'know',
#  "nation's",
#  'long',
#  'struggle',
#  'race',
#  'far',
#  'half',
#  'century',
#  'rosa',
#  'park',
#  'sat',
#  'dr',
#  'king',
#  'marched',
#  'john',
#  'lewis',
#  'bled',
#  'half',
#  'century',
#  'césar',
#  'chávez',
#  'dolores',
#  'huerta',
#  'larry',
#  'itliong',
#  'organized',
#  'race',
#  'still',
#  'play',
#  'significant',
#  'role',
#  'determining',
#  'get',
#  'ahead',
#  'america',
#  'get',
#  'left',
#  'behind',
#  'must',
#  'face',
#  'reality',
#  'must',
#  'fix',
#  'believe',
#  'good',
#  'education',
#  'basic',
#  'right',
#  'american',
#  'matter',
#  'zip',
#  'code',
#  'live',
#  'end',
#  'school-to-prison',
#  'pipeline',
#  'build',
#  'cradle-to-college',
#  'pipeline',
#  'instead',
#  'every',
#  'child',
#  'live',
#  'god-given',
#  'potential',
#  'believe',
#  'helping',
#  'american',
#  'balance',
#  'work',
#  'family',
#  'without',
#  'fear',
#  'punishment',
#  'penalty',
#  'believe',
#  'last',
#  'guaranteeing',
#  'equal',
#  'pay',
#  'woman',
#  'party',
#  'created',
#  'social',
#  'security',
#  'believe',
#  'protecting',
#  'every',
#  "american's",
#  'right',
#  'retire',
#  'dignity',
#  'firmly',
#  'believe',
#  'greed',
#  'recklessness',
#  'illegal',
#  'behavior',
#  'wall',
#  'street',
#  'must',
#  'brought',
#  'end',
#  'wall',
#  'street',
#  'must',
#  'never',
#  'allowed',
#  'threaten',
#  'family',
#  'business',
#  'main',
#  'street',
#  'democrat',
#  'believe',
#  'stronger',
#  'protect',
#  'citizen',
#  'right',
#  'vote',
#  'stopping',
#  'corporation',
#  'outsized',
#  'influence',
#  'election',
#  'fight',
#  'end',
#  'broken',
#  'campaign',
#  'finance',
#  'system',
#  'overturn',
#  'disastrous',
#  'citizen',
#  'united',
#  'decision',
#  'restore',
#  'full',
#  'power',
#  'voting',
#  'right',
#  'act',
#  'return',
#  'control',
#  'election',
#  'american',
#  'people',
#  'democrat',
#  'believe',
#  'climate',
#  'change',
#  'pose',
#  'real',
#  'urgent',
#  'threat',
#  'economy',
#  'national',
#  'security',
#  "children's",
#  'health',
#  'future',
#  'american',
#  'deserve',
#  'job',
#  'security',
#  'come',
#  'becoming',
#  'clean',
#  'energy',
#  'superpower',
#  '21st',
#  'century',
#  'democrat',
#  'believe',
#  'stronger',
#  'safer',
#  'america',
#  'brings',
#  'world',
#  'together',
#  'lead',
#  'principle',
#  'purpose',
#  'believe',
#  'strengthen',
#  'alliance',
#  'weaken',
#  'believe',
#  'power',
#  'development',
#  'diplomacy',
#  'believe',
#  'military',
#  'best-trained',
#  'best-equipped',
#  'fighting',
#  'force',
#  'world',
#  'must',
#  'everything',
#  'honor',
#  'support',
#  'veteran',
#  'know',
#  'united',
#  'state',
#  'mobilize',
#  'common',
#  'action',
#  'truly',
#  'global',
#  'scale',
#  'take',
#  'challenge',
#  'transcend',
#  'border',
#  'international',
#  'terrorism',
#  'climate',
#  'change',
#  'health',
#  'pandemic',
#  'democrat',
#  'party',
#  'inclusion',
#  'know',
#  'diversity',
#  'problem',
#  'promise',
#  'democrat',
#  'respect',
#  'difference',
#  'perspective',
#  'belief',
#  'pledge',
#  'work',
#  'together',
#  'move',
#  'country',
#  'forward',
#  'even',
#  'disagree',
#  'platform',
#  'merely',
#  'seek',
#  'common',
#  'ground',
#  'strive',
#  'reach',
#  'higher',
#  'ground',
#  'proud',
#  'heritage',
#  'nation',
#  'immigrant',
#  'know',
#  "today's",
#  'immigrant',
#  "tomorrow's",
#  'teacher',
#  'doctor',
#  'lawyer',
#  'government',
#  'leader',
#  'soldier',
#  'entrepreneur',
#  'activist',
#  'pta',
#  'member',
#  'pillar',
#  'community',
#  'believe',
#  'protecting',
#  'civil',
#  'liberty',
#  'guaranteeing',
#  'civil',
#  'right',
#  'voting',
#  'right',
#  "women's",
#  'right',
#  'worker',
#  'right',
#  'lgbt',
#  'right',
#  'right',
#  'people',
#  'disability',
#  'believe',
#  'america',
#  'still',
#  'robert',
#  'kennedy',
#  'said',
#  'great',
#  'country',
#  'unselfish',
#  'country',
#  'compassionate',
#  'country',
#  'principle',
#  'stand',
#  'sharp',
#  'contrast',
#  'republican',
#  'nominated',
#  'standard-bearer',
#  'party',
#  'candidate',
#  'president',
#  'man',
#  'seek',
#  'appeal',
#  'american',
#  'basest',
#  'difference',
#  'rather',
#  'better',
#  'nature',
#  'stake',
#  'high',
#  'previous',
#  'election',
#  '2016',
#  'stake',
#  'measured',
#  'human',
#  'life',
#  'number',
#  'immigrant',
#  'would',
#  'torn',
#  'home',
#  'number',
#  'faithful',
#  'peaceful',
#  'muslim',
#  'would',
#  'barred',
#  'even',
#  'visiting',
#  'shore',
#  'number',
#  'ally',
#  'alienated',
#  'dictator',
#  'courted',
#  'number',
#  'american',
#  'would',
#  'lose',
#  'access',
#  'health',
#  'care',
#  'see',
#  'right',
#  'ripped',
#  'away',
#  'election',
#  'democrat',
#  'republican',
#  'nation',
#  'future',
#  'two',
#  'hundred',
#  'forty',
#  'year',
#  'ago',
#  'philadelphia',
#  'started',
#  'revolution',
#  'idea',
#  'action',
#  'continues',
#  'day',
#  'since',
#  'union',
#  'tested',
#  'many',
#  'time',
#  'bondage',
#  'civil',
#  'war',
#  'segregation',
#  'depression',
#  'two',
#  'world',
#  'war',
#  'threat',
#  'nuclear',
#  'annihilation',
#  'generation',
#  'american',
#  'fought',
#  'marched',
#  'organized',
#  'widen',
#  'circle',
#  'opportunity',
#  'dignity',
#  'fighting',
#  'still',
#  'despite',
#  'say',
#  'america',
#  'always',
#  'great',
#  'perfect',
#  'make',
#  'america',
#  'great',
#  'unerring',
#  'belief',
#  'make',
#  'better',
#  'build',
#  'economy',
#  'equal',
#  'society',
#  'perfect',
#  'union',
#  'stronger',
#  'together',
#  'raise',
#  'income',
#  'restore',
#  'economic',
#  'security',
#  'middle',
#  'class',
#  'democrat',
#  'believe',
#  'must',
#  'break',
#  'barrier',
#  'holding',
#  'american',
#  'back',
#  'restore',
#  'basic',
#  'bargain',
#  'built',
#  "america's",
#  'mighty',
#  'middle',
#  'class',
#  'work',
#  'hard',
#  'play',
#  'rule',
#  'get',
#  'ahead',
#  'stay',
#  'ahead',
#  'system',
#  'working',
#  'rigged',
#  'economy',
#  'ordinary',
#  'american',
#  'work',
#  'longer',
#  'hour',
#  'lower',
#  'wage',
#  'new',
#  'income',
#  'wealth',
#  'go',
#  'top',
#  'one',
#  'percent',
#  'republican',
#  'governor',
#  'legislature',
#  'corporate',
#  'ally',
#  'launched',
#  'attack',
#  'attack',
#  'worker',
#  'fundamental',
#  'right',
#  'organize',
#  'bargain',
#  'collectively',
#  'many',
#  'american',
#  'living',
#  'paycheck',
#  'paycheck',
#  'hallmark',
#  'middle',
#  'class',
#  'life',
#  'owning',
#  'home',
#  'access',
#  'affordable',
#  'quality',
#  'childcare',
#  'retiring',
#  'dignity',
#  'feel',
#  'reach',
#  'wonder',
#  'many',
#  'american',
#  'feel',
#  'like',
#  'deck',
#  'stacked',
#  'democratic',
#  'party',
#  'belief',
#  'supporting',
#  'worker',
#  'higher',
#  'wage',
#  'workplace',
#  'protection',
#  'policy',
#  'balance',
#  'work',
#  'family',
#  'investment',
#  'help',
#  'rebuild',
#  'middle',
#  'class',
#  '21st',
#  'century',
#  'raising',
#  'worker',
#  'wagesdemocrats',
#  'believe',
#  'current',
#  'minimum',
#  'wage',
#  'starvation',
#  'wage',
#  'must',
#  'increased',
#  'living',
#  'wage',
#  'one',
#  'work',
#  'full',
#  'time',
#  'raise',
#  'family',
#  'poverty',
#  'believe',
#  'american',
#  'earn',
#  'least',
#  '15',
#  'hour',
#  'right',
#  'form',
#  'join',
#  'union',
#  'work',
#  'every',
#  'way',
#  'congress',
#  'federal',
#  'government',
#  'state',
#  'private',
#  'sector',
#  'reach',
#  'goal',
#  'raise',
#  'federal',
#  'minimum',
#  'wage',
#  '15',
#  'hour',
#  'time',
#  'index',
#  'give',
#  'american',
#  'ability',
#  'join',
#  'union',
#  'regardless',
#  'work',
#  'create',
#  'new',
#  'way',
#  'worker',
#  'power',
#  'economy',
#  'every',
#  'worker',
#  'earn',
#  'least',
#  '15',
#  'hour',
#  'applaud',
#  'approach',
#  'taken',
#  'state',
#  'like',
#  'new',
#  'york',
#  'california',
#  'also',
#  'support',
#  'creating',
#  'one',
#  'fair',
#  'wage',
#  'worker',
#  'ending',
#  'sub-minimum',
#  'wage',
#  'tipped',
#  'worker',
#  'people',
#  'disability',
#  'democrat',
#  'support',
#  'model',
#  'employer',
#  'executive',
#  'order',
#  'vehicle',
#  'leverage',
#  'federal',
#  'dollar',
#  'support',
#  'employer',
#  'provide',
#  'worker',
#  'living',
#  'wage',
#  'good',
#  'benefit',
#  'opportunity',
#  'form',
#  'union',
#  'without',
#  'reprisal',
#  'one',
#  'trillion',
#  'dollar',
#  'spent',
#  'annually',
#  'government',
#  'contract',
#  'loan',
#  'grant',
#  'used',
#  'support',
#  'good',
#  'job',
#  'rebuild',
#  'middle',
#  'class',
#  'protecting',
#  'worker',
#  'fundamental',
#  'rightsthe',
#  'democratic',
#  'party',
#  'belief',
#  'worker',
#  'strong',
#  'america',
#  'strong',
#  'democrat',
#  'make',
#  'easier',
#  'worker',
#  'public',
#  'private',
#  'exercise',
#  'right',
#  'organize',
#  'join',
#  'union',
#  'fight',
#  'pas',
#  'law',
#  'direct',
#  'national',
#  'labor',
#  'relation',
#  'board',
#  'certify',
#  'union',
#  'simple',
#  'majority',
#  'eligible',
#  'worker',
#  'sign',
#  'valid',
#  'authorization',
#  'card',
#  'well',
#  'law',
#  'bring',
#  'company',
#  'negotiating',
#  'table',
#  'support',
#  'binding',
#  'arbitration',
#  'help',
#  'worker',
#  'voted',
#  'join',
#  'union',
#  'reach',
#  'first',
#  'contract',
#  'major',
#  'factor',
#  '40',
#  'year',
#  'decline',
#  'middle',
#  'class',
#  'right',
#  'worker',
#  'bargain',
#  'collectively',
#  'better',
#  'wage',
#  'benefit',
#  'attack',
#  'level',
#  'donald',
#  'trump',
#  'would',
#  'make',
#  'matter',
#  'worse',
#  'creating',
#  'race',
#  'bottom',
#  'middle',
#  'class',
#  'fighting',
#  'fewer',
#  'fewer',
#  'good-paying',
#  'job',
#  'fact',
#  'trump',
#  'rejected',
#  'attempt',
#  'employee',
#  'unionize',
#  'personally',
#  'hired',
#  'union-busting',
#  'firm',
#  'undermine',
#  'worker',
#  'right',
#  'democrat',
#  'believe',
#  'so-called',
#  'right',
#  'work',
#  'law',
#  'wrong',
#  'worker',
#  'teacher',
#  'public',
#  'employee',
#  'serve',
#  'community',
#  ...]

# %%
text_dem_platform_2016 = nltk.Text(tokens_dem_platform_2016)
type(text_dem_platform_2016)
# Out:
# nltk.text.Text

# %% [markdown]
# ## Republican Party Platform 2016

# %%
html_rep_platform_2016 = request.urlopen(url_rep_platform_2016).read().decode('utf8')
raw_rep_platform_2016 = BeautifulSoup(html_rep_platform_2016, 'html.parser')
raw_rep_platform_2016 = [p.get_text() for p in raw_rep_platform_2016.select('div.field-docs-content > p')]
raw_rep_platform_2016 = ' '.join(raw_rep_platform_2016)

tokens_rep_platform_2016 = tokenizer.tokenize(raw_rep_platform_2016)
tokens_rep_platform_2016 = [char.lower() for char in tokens_rep_platform_2016]
tokens_rep_platform_2016 = [char for char in tokens_rep_platform_2016 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_rep_platform_2016

lemmatized_tokens_rep_platform_2016 = [lemmatizer.lemmatize(word) for word in tokens_rep_platform_2016]
lemmatized_tokens_rep_platform_2016
# Out:
# ['believe',
#  'american',
#  'exceptionalism',
#  'believe',
#  'united',
#  'states',
#  'america',
#  'unlike',
#  'nation',
#  'earth',
#  'believe',
#  'america',
#  'exceptional',
#  'historic',
#  'role',
#  'first',
#  'refuge',
#  'defender',
#  'exemplar',
#  'liberty',
#  'world',
#  'see',
#  'affirm',
#  'declaration',
#  'independence',
#  'created',
#  'equal',
#  'endowed',
#  'creator',
#  'inalienable',
#  'rights',
#  'life',
#  'liberty',
#  'pursuit',
#  'happiness',
#  'believe',
#  'constitution',
#  'founding',
#  'document',
#  'believe',
#  'constitution',
#  'written',
#  'flexible',
#  'document',
#  'enduring',
#  'covenant',
#  'believe',
#  'constitutional',
#  'system',
#  'limited',
#  'government',
#  'separation',
#  'powers',
#  'federalism',
#  'rights',
#  'people',
#  'must',
#  'preserved',
#  'uncompromised',
#  'future',
#  'generations',
#  'believe',
#  'political',
#  'freedom',
#  'economic',
#  'freedom',
#  'indivisible',
#  'political',
#  'freedom',
#  'economic',
#  'freedom',
#  'separated',
#  'peril',
#  'united',
#  'invincible',
#  'believe',
#  'people',
#  'ultimate',
#  'resource',
#  'people',
#  'government',
#  'best',
#  'stewards',
#  "country's",
#  'god-given',
#  'natural',
#  'resources',
#  'americans',
#  'republicans',
#  'wish',
#  'peace',
#  'insist',
#  'strength',
#  'make',
#  'america',
#  'safe',
#  'seek',
#  'friendship',
#  'peoples',
#  'nations',
#  'recognize',
#  'prepared',
#  'deal',
#  'evil',
#  'world',
#  'based',
#  'principles',
#  'platform',
#  'invitation',
#  'roadmap',
#  'invites',
#  'every',
#  'american',
#  'join',
#  'us',
#  'shows',
#  'path',
#  'stronger',
#  'safer',
#  'prosperous',
#  'america',
#  'platform',
#  'optimistic',
#  'american',
#  'people',
#  'optimistic',
#  'platform',
#  'lays',
#  'clear',
#  'language',
#  'path',
#  'making',
#  'america',
#  'great',
#  'united',
#  'past',
#  '8',
#  'years',
#  'america',
#  'led',
#  'wrong',
#  'direction',
#  'economy',
#  'become',
#  'unnecessarily',
#  'weak',
#  'stagnant',
#  'wages',
#  'people',
#  'living',
#  'paycheck',
#  'paycheck',
#  'struggling',
#  'sacrificing',
#  'suffering',
#  'americans',
#  'earned',
#  'deserve',
#  'strong',
#  'healthy',
#  'economy',
#  'standing',
#  'world',
#  'affairs',
#  'declined',
#  'significantly',
#  'enemies',
#  'longer',
#  'fear',
#  'us',
#  'friends',
#  'long',
#  'trust',
#  'us',
#  'people',
#  'want',
#  'expect',
#  'america',
#  'powerful',
#  'respected',
#  'country',
#  'face',
#  'earth',
#  'men',
#  'women',
#  'military',
#  'remain',
#  "world's",
#  'best',
#  'shortchanged',
#  'numbers',
#  'equipment',
#  'benefits',
#  'commander',
#  'chief',
#  'treats',
#  'armed',
#  'forces',
#  'veterans',
#  'necessary',
#  'inconvenience',
#  'president',
#  'democratic',
#  'party',
#  'dismantled',
#  'americans',
#  'system',
#  'healthcare',
#  'replaced',
#  'costly',
#  'complicated',
#  'scheme',
#  'limits',
#  'choices',
#  'takes',
#  'away',
#  'freedom',
#  'president',
#  'democratic',
#  'party',
#  'abandoned',
#  'promise',
#  'accountable',
#  'american',
#  'people',
#  'nearly',
#  'doubled',
#  'size',
#  'national',
#  'debt',
#  'refuse',
#  'control',
#  'borders',
#  'try',
#  'control',
#  'schools',
#  'farms',
#  'businesses',
#  'even',
#  'religious',
#  'institutions',
#  'directly',
#  'attacked',
#  'production',
#  'american',
#  'energy',
#  'industry-related',
#  'jobs',
#  'sustained',
#  'families',
#  'communities',
#  'president',
#  'regulating',
#  'death',
#  'free',
#  'market',
#  'economy',
#  'like',
#  'understand',
#  'defies',
#  'laws',
#  'united',
#  'states',
#  'refusing',
#  'enforce',
#  'agree',
#  'appoints',
#  'judges',
#  'legislate',
#  'bench',
#  'rather',
#  'apply',
#  'law',
#  'republicans',
#  'americans',
#  'cannot',
#  'allow',
#  'continue',
#  'many',
#  'sections',
#  'platform',
#  'affirm',
#  'trust',
#  'people',
#  'faith',
#  'judgment',
#  'determination',
#  'help',
#  'take',
#  'back',
#  'country',
#  'means',
#  'removing',
#  'power',
#  'unelected',
#  'unaccountable',
#  'government',
#  'means',
#  'relieving',
#  'burden',
#  'expense',
#  'punishing',
#  'government',
#  'regulations',
#  'means',
#  'returning',
#  'people',
#  'states',
#  'control',
#  'belongs',
#  'control',
#  'power',
#  'make',
#  'decisions',
#  "what's",
#  'best',
#  'families',
#  'communities',
#  'platform',
#  'many',
#  'things',
#  'handbook',
#  'returning',
#  'decision-making',
#  'people',
#  'guide',
#  'constitutional',
#  'rights',
#  'every',
#  'american',
#  'manual',
#  'kind',
#  'sustained',
#  'growth',
#  'bring',
#  'opportunity',
#  'sidelines',
#  'society',
#  'every',
#  'time',
#  'sing',
#  'god',
#  'bless',
#  'america',
#  'asking',
#  'help',
#  'ask',
#  'divine',
#  'help',
#  'country',
#  'fulfill',
#  'promise',
#  'earn',
#  'help',
#  'recommitting',
#  'ideas',
#  'ideals',
#  'true',
#  'greatness',
#  'america',
#  'rebuilding',
#  'economy',
#  'creating',
#  'jobs',
#  'party',
#  'growing',
#  'economy',
#  'gives',
#  'everyone',
#  'chance',
#  'life',
#  'opportunity',
#  'learn',
#  'work',
#  'realize',
#  'prosperity',
#  'freedom',
#  'makes',
#  'possible',
#  'government',
#  'cannot',
#  'create',
#  'prosperity',
#  'though',
#  'government',
#  'limit',
#  'destroy',
#  'prosperity',
#  'product',
#  'self-discipline',
#  'enterprise',
#  'saving',
#  'investment',
#  'individuals',
#  'end',
#  'prosperity',
#  'provides',
#  'means',
#  'citizens',
#  'families',
#  'maintain',
#  'independence',
#  'government',
#  'raise',
#  'children',
#  'values',
#  'practice',
#  'faith',
#  'build',
#  'communities',
#  'cooperation',
#  'mutual',
#  'respect',
#  'also',
#  'foundation',
#  "nation's",
#  'global',
#  'leadership',
#  'vigor',
#  'economy',
#  'makes',
#  'possible',
#  'military',
#  'strength',
#  'national',
#  'security',
#  'pundits',
#  'democrats',
#  'tell',
#  'us',
#  'accept',
#  'new',
#  'normal',
#  'slow-growing',
#  'economy',
#  'consequences',
#  'dire',
#  'ever',
#  'accept',
#  'president',
#  'obama',
#  'party',
#  'set',
#  'record',
#  'first',
#  'modern',
#  'president',
#  'ever',
#  'leave',
#  'office',
#  'without',
#  'single',
#  'calendar',
#  'year',
#  'three',
#  'percent',
#  'economic',
#  'growth',
#  'result',
#  'number',
#  'americans',
#  'living',
#  'poverty',
#  'increased',
#  '7',
#  'million',
#  "nation's",
#  'economy',
#  'lost',
#  'nearly',
#  '8',
#  'trillion',
#  'cumulative',
#  'output',
#  'compared',
#  'average',
#  'recovery',
#  'economic',
#  'growth',
#  'shortfall',
#  'left',
#  'cumulative',
#  'real',
#  'after-tax',
#  'per',
#  'person',
#  'personal',
#  'income',
#  'shortfall',
#  'nearly',
#  '17,000',
#  'compared',
#  'average',
#  'recovery',
#  'president',
#  'obama',
#  'democrats',
#  'new',
#  'private-sector',
#  'jobs',
#  'three',
#  'million',
#  'average',
#  'modern',
#  'post-recession',
#  'growth',
#  'labor',
#  'force',
#  'participation',
#  'rate',
#  'plunged',
#  '63',
#  'percent',
#  'far',
#  'long',
#  'lows',
#  'last',
#  'seen',
#  'two',
#  'generations',
#  'ago',
#  'president',
#  'reagan',
#  'elected',
#  '1980',
#  'business',
#  'closures',
#  'exceeded',
#  'business',
#  'startups',
#  'throughout',
#  'obama',
#  'presidency',
#  'strong',
#  'growth',
#  'jobs',
#  'increasing',
#  'incomes',
#  'expanding',
#  'opportunity',
#  'short',
#  'supply',
#  'president',
#  'obama',
#  'democrats',
#  'repudiate',
#  'absurd',
#  'idea',
#  'best',
#  'america',
#  'american',
#  'people',
#  'rejected',
#  'nonsense',
#  'last',
#  'time',
#  'offered',
#  'historic',
#  'election',
#  '1980',
#  'ask',
#  'join',
#  'us',
#  'repudiate',
#  'false',
#  'gospel',
#  "america's",
#  'diminishment',
#  'retreat',
#  'offer',
#  'instead',
#  'vision',
#  'opportunity',
#  'society',
#  'based',
#  'economics',
#  'inclusion',
#  'fair',
#  'simple',
#  'taxes',
#  'growth',
#  'republicans',
#  'consider',
#  'establishment',
#  'pro-growth',
#  'tax',
#  'code',
#  'moral',
#  'imperative',
#  'public',
#  'policy',
#  'way',
#  'government',
#  'raises',
#  'revenue',
#  'much',
#  'rates',
#  'circumstances',
#  'greatest',
#  'impact',
#  "economy's",
#  'performance',
#  'powerfully',
#  'influences',
#  'level',
#  'economic',
#  'growth',
#  'job',
#  'creation',
#  'translates',
#  'level',
#  'opportunity',
#  'would',
#  'otherwise',
#  'left',
#  'behind',
#  'getting',
#  'tax',
#  'system',
#  'right',
#  'important',
#  'factor',
#  'driving',
#  'entire',
#  'economy',
#  'back',
#  'prosperity',
#  'current',
#  'tax',
#  'code',
#  'rightly',
#  'object',
#  'anger',
#  'mockery',
#  'length',
#  'exceeded',
#  'complexity',
#  'must',
#  'start',
#  'anew',
#  'enormous',
#  'undertaking',
#  'succeed',
#  'must',
#  'command',
#  'attention',
#  'approval',
#  'american',
#  'people',
#  'cannot',
#  'engineered',
#  'top',
#  'must',
#  'common',
#  'sense',
#  'approach',
#  'simplified',
#  'proposal',
#  'straightforward',
#  'wherever',
#  'tax',
#  'rates',
#  'penalize',
#  'thrift',
#  'discourage',
#  'investment',
#  'must',
#  'lowered',
#  'wherever',
#  'current',
#  'provisions',
#  'code',
#  'disincentives',
#  'economic',
#  'growth',
#  'must',
#  'changed',
#  'divide',
#  'american',
#  'people',
#  'winners',
#  'losers',
#  'eliminate',
#  'many',
#  'special',
#  'interest',
#  'provisions',
#  'loopholes',
#  'possible',
#  'curb',
#  'corporate',
#  'welfare',
#  'especially',
#  'erosion',
#  'tax',
#  'base',
#  'created',
#  'pressure',
#  'higher',
#  'rates',
#  'mindful',
#  'burdens',
#  'families',
#  'children',
#  'impact',
#  'aging',
#  'population',
#  'seek',
#  'simplicity',
#  'clarity',
#  'every',
#  'taxpayer',
#  'understand',
#  'much',
#  'income',
#  'consumed',
#  'federal',
#  'government',
#  'welcome',
#  'enterprise',
#  'discuss',
#  'debate',
#  'challenge',
#  'amend',
#  'together',
#  'restore',
#  'economic',
#  'growth',
#  'american',
#  'people',
#  'even',
#  'important',
#  'renew',
#  'faith',
#  'future',
#  'tax',
#  'principles',
#  'ensure',
#  'past',
#  'abuses',
#  'repeated',
#  'assert',
#  'fundamental',
#  'principles',
#  'oppose',
#  'retroactive',
#  'taxation',
#  'condemn',
#  'attempts',
#  'activist',
#  'judges',
#  'level',
#  'government',
#  'seize',
#  'power',
#  'purse',
#  "people's",
#  'elected',
#  'representatives',
#  'ordering',
#  'higher',
#  'taxes',
#  'oppose',
#  'tax',
#  'policies',
#  'deliberately',
#  'divide',
#  'americans',
#  'promote',
#  'class',
#  'warfare',
#  'vital',
#  'role',
#  'religious',
#  'organizations',
#  'charities',
#  'fraternal',
#  'benevolent',
#  'societies',
#  'fostering',
#  'generosity',
#  'patriotism',
#  'subject',
#  'taxation',
#  'donations',
#  'remain',
#  'deductible',
#  'guard',
#  'hypertaxation',
#  'american',
#  'people',
#  'restructuring',
#  'federal',
#  'tax',
#  'system',
#  'value',
#  'added',
#  'tax',
#  'national',
#  'sales',
#  'tax',
#  'must',
#  'tied',
#  'simultaneous',
#  'repeal',
#  'sixteenth',
#  'amendment',
#  'established',
#  'federal',
#  'income',
#  'tax',
#  'competitive',
#  'america',
#  'competitiveness',
#  'equals',
#  'jobs',
#  'equation',
#  'governs',
#  'policies',
#  'regarding',
#  'u',
#  'corporations',
#  'global',
#  'economy',
#  'private',
#  'investment',
#  'key',
#  'driver',
#  'economic',
#  'growth',
#  'job',
#  'creation',
#  'falling',
#  'dramatically',
#  'recession',
#  'private',
#  'investment',
#  'recovered',
#  'disappointing',
#  'pace',
#  'due',
#  'part',
#  'high',
#  'corporate',
#  'tax',
#  'rates',
#  'increasing',
#  'regulatory',
#  'burdens',
#  'uncertainty',
#  'american',
#  'businesses',
#  'face',
#  "world's",
#  'highest',
#  'corporate',
#  'tax',
#  'rates',
#  "that's",
#  'like',
#  'putting',
#  'lead',
#  'shoes',
#  'cross-country',
#  'team',
#  'reduces',
#  'companies',
#  'ability',
#  'compete',
#  'overseas',
#  'encourages',
#  'move',
#  'abroad',
#  'lessens',
#  'investment',
#  'cripples',
#  'job',
#  'creation',
#  'home',
#  'lowers',
#  'american',
#  'wages',
#  'fosters',
#  'avoidance',
#  'tax',
#  'liability',
#  'without',
#  'actually',
#  'increasing',
#  'tax',
#  'revenues',
#  'damaging',
#  'policy',
#  'hard',
#  'imagine',
#  'propose',
#  'level',
#  'international',
#  'playing',
#  'field',
#  'lowering',
#  'corporate',
#  'tax',
#  'rate',
#  'par',
#  'rates',
#  'industrial',
#  'nations',
#  'endorse',
#  'recommendation',
#  'national',
#  'commission',
#  'fiscal',
#  'responsibility',
#  'reform',
#  'well',
#  'current',
#  "administration's",
#  'export',
#  'council',
#  'switch',
#  'territorial',
#  'system',
#  'taxation',
#  'profits',
#  'earned',
#  'taxed',
#  'abroad',
#  'may',
#  'repatriated',
#  'job-creating',
#  'investment',
#  'home',
#  'believe',
#  'american',
#  'companies',
#  'headquartered',
#  'america',
#  'reduce',
#  'barriers',
#  'accomplishing',
#  'goal',
#  'winning',
#  'trade',
#  'policy',
#  'international',
#  'trade',
#  'crucial',
#  'sectors',
#  "america's",
#  'economy',
#  'massive',
#  'trade',
#  'deficits',
#  'envision',
#  'worldwide',
#  'multilateral',
#  'agreement',
#  'among',
#  'nations',
#  'committed',
#  'principles',
#  'open',
#  'markets',
#  'called',
#  'reagan',
#  'economic',
#  'zone',
#  'free',
#  'trade',
#  'truly',
#  'fair',
#  'trade',
#  'concerned',
#  'need',
#  'better',
#  'negotiated',
#  'trade',
#  'agreements',
#  'put',
#  'america',
#  'first',
#  'trade',
#  'agreements',
#  'carefully',
#  'negotiated',
#  'friendly',
#  'democracies',
#  'resulted',
#  'millions',
#  'new',
#  'jobs',
#  'home',
#  'supported',
#  'exports',
#  'agreements',
#  'adequately',
#  'protect',
#  'u',
#  'interests',
#  ...]

# %%
text_rep_platform_2016 = nltk.Text(tokens_rep_platform_2016)
type(text_rep_platform_2016)
# Out:
# nltk.text.Text

# %% [markdown]
# ## Debate Las Vegas 2016

# %%
html_debate_las_vegas_2016 = request.urlopen(url_debate_las_vegas_2016).read().decode('utf8')
raw_debate_las_vegas_2016 = BeautifulSoup(html_debate_las_vegas_2016, 'html.parser')

raw_dem_debate_las_vegas_2016 = []
dem_las_vegas_2016 = False
raw_rep_debate_las_vegas_2016 = []
rep_las_vegas_2016 = False

for p in raw_debate_las_vegas_2016.select('div.field-docs-content > p'):
    if p.get_text().startswith('CLINTON'):
        first, _, rest = p.get_text().partition(" ")
        raw_dem_debate_las_vegas_2016.append(rest)
        dem_las_vegas_2016 = True
        rep_las_vegas_2016 = False
    elif p.get_text().startswith('TRUMP'):
        first, _, rest = p.get_text().partition(" ")
        raw_rep_debate_las_vegas_2016.append(rest)
        dem_las_vegas_2016 = False
        rep_las_vegas_2016 = True
    elif p.get_text().startswith('WALLACE'):
        dem_las_vegas_2016 = False
        rep_las_vegas_2016 = False
    elif rep_las_vegas_2016:
        raw_rep_debate_las_vegas_2016.append(p.get_text())
    elif dem_las_vegas_2016:
        raw_dem_debate_las_vegas_2016.append(p.get_text())
        
raw_rep_debate_las_vegas_2016 = ' '.join(raw_rep_debate_las_vegas_2016)
tokens_rep_debate_las_vegas_2016 = tokenizer.tokenize(raw_rep_debate_las_vegas_2016)
tokens_rep_debate_las_vegas_2016

raw_dem_debate_las_vegas_2016 = ' '.join(raw_dem_debate_las_vegas_2016)
tokens_dem_debate_las_vegas_2016 = tokenizer.tokenize(raw_dem_debate_las_vegas_2016)
tokens_rep_debate_las_vegas_2016
# Out:
# ['Well',
#  ',',
#  'first',
#  'of',
#  'all',
#  ',',
#  "it's",
#  'great',
#  'to',
#  'be',
#  'with',
#  'you',
#  ',',
#  'and',
#  'thank',
#  'you',
#  ',',
#  'everybody',
#  '.',
#  'The',
#  'Supreme',
#  'Court',
#  ':',
#  "It's",
#  'what',
#  "it's",
#  'all',
#  'about',
#  '.',
#  'Our',
#  'country',
#  'is',
#  'so',
#  ',',
#  'so',
#  '—',
#  "it's",
#  'just',
#  'so',
#  'imperative',
#  'that',
#  'we',
#  'have',
#  'the',
#  'right',
#  'justices',
#  '.',
#  'Something',
#  'happened',
#  'recently',
#  'where',
#  'Justice',
#  'Ginsburg',
#  'made',
#  'some',
#  'very',
#  ',',
#  'very',
#  'inappropriate',
#  'statements',
#  'toward',
#  'me',
#  'and',
#  'toward',
#  'a',
#  'tremendous',
#  'number',
#  'of',
#  'people',
#  ',',
#  'many',
#  ',',
#  'many',
#  'millions',
#  'of',
#  'people',
#  'that',
#  'I',
#  'represent',
#  '.',
#  'And',
#  'she',
#  'was',
#  'forced',
#  'to',
#  'apologize',
#  '.',
#  'And',
#  'apologize',
#  'she',
#  'did',
#  '.',
#  'But',
#  'these',
#  'were',
#  'statements',
#  'that',
#  'should',
#  'never',
#  ',',
#  'ever',
#  'have',
#  'been',
#  'made',
#  '.',
#  'We',
#  'need',
#  'a',
#  'Supreme',
#  'Court',
#  'that',
#  'in',
#  'my',
#  'opinion',
#  'is',
#  'going',
#  'to',
#  'uphold',
#  'the',
#  'Second',
#  'Amendment',
#  ',',
#  'and',
#  'all',
#  'amendments',
#  ',',
#  'but',
#  'the',
#  'Second',
#  'Amendment',
#  ',',
#  'which',
#  'is',
#  'under',
#  'absolute',
#  'siege',
#  '.',
#  'I',
#  'believe',
#  'if',
#  'my',
#  'opponent',
#  'should',
#  'win',
#  'this',
#  'race',
#  ',',
#  'which',
#  'I',
#  'truly',
#  "don't",
#  'think',
#  'will',
#  'happen',
#  ',',
#  'we',
#  'will',
#  'have',
#  'a',
#  'Second',
#  'Amendment',
#  'which',
#  'will',
#  'be',
#  'a',
#  'very',
#  ',',
#  'very',
#  'small',
#  'replica',
#  'of',
#  'what',
#  'it',
#  'is',
#  'right',
#  'now',
#  '.',
#  'But',
#  'I',
#  'feel',
#  'that',
#  "it's",
#  'absolutely',
#  'important',
#  'that',
#  'we',
#  'uphold',
#  ',',
#  'because',
#  'of',
#  'the',
#  'fact',
#  'that',
#  'it',
#  'is',
#  'under',
#  'such',
#  'trauma',
#  '.',
#  'I',
#  'feel',
#  'that',
#  'the',
#  'justices',
#  'that',
#  'I',
#  'am',
#  'going',
#  'to',
#  'appoint',
#  '—',
#  'and',
#  "I've",
#  'named',
#  '20',
#  'of',
#  'them',
#  '—',
#  'the',
#  'justices',
#  'that',
#  "I'm",
#  'going',
#  'to',
#  'appoint',
#  'will',
#  'be',
#  'pro-life',
#  '.',
#  'They',
#  'will',
#  'have',
#  'a',
#  'conservative',
#  'bent',
#  '.',
#  'They',
#  'will',
#  'be',
#  'protecting',
#  'the',
#  'Second',
#  'Amendment',
#  '.',
#  'They',
#  'are',
#  'great',
#  'scholars',
#  'in',
#  'all',
#  'cases',
#  ',',
#  'and',
#  "they're",
#  'people',
#  'of',
#  'tremendous',
#  'respect',
#  '.',
#  'They',
#  'will',
#  'interpret',
#  'the',
#  'Constitution',
#  'the',
#  'way',
#  'the',
#  'founders',
#  'wanted',
#  'it',
#  'interpreted',
#  '.',
#  'And',
#  'I',
#  'believe',
#  "that's",
#  'very',
#  ',',
#  'very',
#  'important',
#  '.',
#  'I',
#  "don't",
#  'think',
#  'we',
#  'should',
#  'have',
#  'justices',
#  'appointed',
#  'that',
#  'decide',
#  'what',
#  'they',
#  'want',
#  'to',
#  'hear',
#  '.',
#  "It's",
#  'all',
#  'about',
#  'the',
#  'Constitution',
#  'of',
#  '—',
#  'of',
#  '—',
#  'and',
#  'so',
#  'important',
#  ',',
#  'the',
#  'Constitution',
#  'the',
#  'way',
#  'it',
#  'was',
#  'meant',
#  'to',
#  'be',
#  '.',
#  'And',
#  'those',
#  'are',
#  'the',
#  'people',
#  'that',
#  'I',
#  'will',
#  'appoint',
#  '.',
#  'Well',
#  ',',
#  'the',
#  'D',
#  '.',
#  'C',
#  '.',
#  'vs',
#  '.',
#  'Heller',
#  'decision',
#  'was',
#  'very',
#  'strongly',
#  '—',
#  'and',
#  'she',
#  'was',
#  'extremely',
#  'angry',
#  'about',
#  'it',
#  '.',
#  'I',
#  'watched',
#  '.',
#  'I',
#  'mean',
#  ',',
#  'she',
#  'was',
#  'very',
#  ',',
#  'very',
#  'angry',
#  'when',
#  'upheld',
#  '.',
#  'And',
#  'Justice',
#  'Scalia',
#  'was',
#  'so',
#  'involved',
#  '.',
#  'And',
#  'it',
#  'was',
#  'a',
#  'well-crafted',
#  'decision',
#  '.',
#  'But',
#  'Hillary',
#  'was',
#  'extremely',
#  'upset',
#  ',',
#  'extremely',
#  'angry',
#  '.',
#  'And',
#  'people',
#  'that',
#  'believe',
#  'in',
#  'the',
#  'Second',
#  'Amendment',
#  'and',
#  'believe',
#  'in',
#  'it',
#  'very',
#  'strongly',
#  'were',
#  'very',
#  'upset',
#  'with',
#  'what',
#  'she',
#  'had',
#  'to',
#  'say',
#  '.',
#  'Well',
#  ',',
#  'let',
#  'me',
#  'just',
#  'tell',
#  'you',
#  'before',
#  'we',
#  'go',
#  'any',
#  'further',
#  '.',
#  'In',
#  'Chicago',
#  ',',
#  'which',
#  'has',
#  'the',
#  'toughest',
#  'gun',
#  'laws',
#  'in',
#  'the',
#  'United',
#  'States',
#  ',',
#  'probably',
#  'you',
#  'could',
#  'say',
#  'by',
#  'far',
#  ',',
#  'they',
#  'have',
#  'more',
#  'gun',
#  'violence',
#  'than',
#  'any',
#  'other',
#  'city',
#  '.',
#  'So',
#  'we',
#  'have',
#  'the',
#  'toughest',
#  'laws',
#  ',',
#  'and',
#  'you',
#  'have',
#  'tremendous',
#  'gun',
#  'violence',
#  '.',
#  'I',
#  'am',
#  'a',
#  'very',
#  'strong',
#  'supporter',
#  'of',
#  'the',
#  'Second',
#  'Amendment',
#  '.',
#  'And',
#  'I',
#  'am',
#  '—',
#  'I',
#  "don't",
#  'know',
#  'if',
#  'Hillary',
#  'was',
#  'saying',
#  'it',
#  'in',
#  'a',
#  'sarcastic',
#  'manner',
#  ',',
#  'but',
#  "I'm",
#  'very',
#  'proud',
#  'to',
#  'have',
#  'the',
#  'endorsement',
#  'of',
#  'the',
#  'NRA',
#  '.',
#  'And',
#  "it's",
#  'the',
#  'earliest',
#  'endorsement',
#  "they've",
#  'ever',
#  'given',
#  'to',
#  'anybody',
#  'who',
#  'ran',
#  'for',
#  'president',
#  '.',
#  'So',
#  "I'm",
#  'very',
#  'honored',
#  'by',
#  'all',
#  'of',
#  'that',
#  '.',
#  'We',
#  'are',
#  'going',
#  'to',
#  'appoint',
#  'justices',
#  '—',
#  'this',
#  'is',
#  'the',
#  'best',
#  'way',
#  'to',
#  'help',
#  'the',
#  'Second',
#  'Amendment',
#  '.',
#  'We',
#  'are',
#  'going',
#  'to',
#  'appoint',
#  'justices',
#  'that',
#  'will',
#  'feel',
#  'very',
#  'strongly',
#  'about',
#  'the',
#  'Second',
#  'Amendment',
#  ',',
#  'that',
#  'will',
#  'not',
#  'do',
#  'damage',
#  'to',
#  'the',
#  'Second',
#  'Amendment',
#  '.',
#  'Right',
#  '.',
#  'Well',
#  ',',
#  'if',
#  'that',
#  'would',
#  'happen',
#  ',',
#  'because',
#  'I',
#  'am',
#  'pro-life',
#  ',',
#  'and',
#  'I',
#  'will',
#  'be',
#  'appointing',
#  'pro-life',
#  'judges',
#  ',',
#  'I',
#  'would',
#  'think',
#  'that',
#  'that',
#  'will',
#  'go',
#  'back',
#  'to',
#  'the',
#  'individual',
#  'states',
#  '.',
#  'If',
#  'they',
#  'overturned',
#  'it',
#  ',',
#  'it',
#  'will',
#  'go',
#  'back',
#  'to',
#  'the',
#  'states',
#  '.',
#  'Well',
#  ',',
#  'if',
#  'we',
#  'put',
#  'another',
#  'two',
#  'or',
#  'perhaps',
#  'three',
#  'justice',
#  'on',
#  ',',
#  "that's",
#  'really',
#  "what's",
#  'going',
#  'to',
#  'be',
#  '—',
#  'that',
#  'will',
#  'happen',
#  '.',
#  'And',
#  "that'll",
#  'happen',
#  'automatically',
#  ',',
#  'in',
#  'my',
#  'opinion',
#  ',',
#  'because',
#  'I',
#  'am',
#  'putting',
#  'pro-life',
#  'justices',
#  'on',
#  'the',
#  'court',
#  '.',
#  'I',
#  'will',
#  'say',
#  'this',
#  ':',
#  'It',
#  'will',
#  'go',
#  'back',
#  'to',
#  'the',
#  'states',
#  ',',
#  'and',
#  'the',
#  'states',
#  'will',
#  'then',
#  'make',
#  'a',
#  'determination',
#  '.',
#  'Well',
#  ',',
#  'I',
#  'think',
#  "it's",
#  'terrible',
#  '.',
#  'If',
#  'you',
#  'go',
#  'with',
#  'what',
#  'Hillary',
#  'is',
#  'saying',
#  ',',
#  'in',
#  'the',
#  'ninth',
#  'month',
#  ',',
#  'you',
#  'can',
#  'take',
#  'the',
#  'baby',
#  'and',
#  'rip',
#  'the',
#  'baby',
#  'out',
#  'of',
#  'the',
#  'womb',
#  'of',
#  'the',
#  'mother',
#  'just',
#  'prior',
#  'to',
#  'the',
#  'birth',
#  'of',
#  'the',
#  'baby',
#  '.',
#  'Now',
#  ',',
#  'you',
#  'can',
#  'say',
#  'that',
#  "that's",
#  'OK',
#  'and',
#  'Hillary',
#  'can',
#  'say',
#  'that',
#  "that's",
#  'OK',
#  '.',
#  'But',
#  "it's",
#  'not',
#  'OK',
#  'with',
#  'me',
#  ',',
#  'because',
#  'based',
#  'on',
#  'what',
#  "she's",
#  'saying',
#  ',',
#  'and',
#  'based',
#  'on',
#  'where',
#  "she's",
#  'going',
#  ',',
#  'and',
#  'where',
#  "she's",
#  'been',
#  ',',
#  'you',
#  'can',
#  'take',
#  'the',
#  'baby',
#  'and',
#  'rip',
#  'the',
#  'baby',
#  'out',
#  'of',
#  'the',
#  'womb',
#  'in',
#  'the',
#  'ninth',
#  'month',
#  'on',
#  'the',
#  'final',
#  'day',
#  '.',
#  'And',
#  "that's",
#  'not',
#  'acceptable',
#  '.',
#  'And',
#  ',',
#  'honestly',
#  ',',
#  'nobody',
#  'has',
#  'business',
#  'doing',
#  'what',
#  'I',
#  'just',
#  'said',
#  ',',
#  'doing',
#  'that',
#  ',',
#  'as',
#  'late',
#  'as',
#  'one',
#  'or',
#  'two',
#  'or',
#  'three',
#  'or',
#  'four',
#  'days',
#  'prior',
#  'to',
#  'birth',
#  '.',
#  'Nobody',
#  'has',
#  'that',
#  '.',
#  'Well',
#  ',',
#  'first',
#  'of',
#  'all',
#  ',',
#  'she',
#  'wants',
#  'to',
#  'give',
#  'amnesty',
#  ',',
#  'which',
#  'is',
#  'a',
#  'disaster',
#  'and',
#  'very',
#  'unfair',
#  'to',
#  'all',
#  'of',
#  'the',
#  'people',
#  'that',
#  'are',
#  'waiting',
#  'on',
#  'line',
#  'for',
#  'many',
#  ',',
#  'many',
#  'years',
#  '.',
#  'We',
#  'need',
#  'strong',
#  'borders',
#  '.',
#  'In',
#  'the',
#  'audience',
#  'tonight',
#  ',',
#  'we',
#  'have',
#  'four',
#  'mothers',
#  'of',
#  '—',
#  'I',
#  'mean',
#  ',',
#  'these',
#  'are',
#  'unbelievable',
#  'people',
#  'that',
#  "I've",
#  'gotten',
#  'to',
#  'know',
#  'over',
#  'a',
#  'period',
#  'of',
#  'years',
#  'whose',
#  'children',
#  'have',
#  'been',
#  'killed',
#  ',',
#  'brutally',
#  'killed',
#  'by',
#  'people',
#  'that',
#  'came',
#  'into',
#  'the',
#  'country',
#  'illegally',
#  '.',
#  'You',
#  'have',
#  'thousands',
#  'of',
#  'mothers',
#  'and',
#  'fathers',
#  'and',
#  'relatives',
#  'all',
#  'over',
#  'the',
#  'country',
#  '.',
#  "They're",
#  'coming',
#  'in',
#  'illegally',
#  '.',
#  'Drugs',
#  'are',
#  'pouring',
#  'in',
#  'through',
#  'the',
#  'border',
#  '.',
#  'We',
#  'have',
#  'no',
#  'country',
#  'if',
#  'we',
#  'have',
#  'no',
#  'border',
#  '.',
#  'Hillary',
#  'wants',
#  'to',
#  'give',
#  'amnesty',
#  '.',
#  'She',
#  'wants',
#  'to',
#  'have',
#  'open',
#  'borders',
#  '.',
#  'The',
#  'border',
#  '—',
#  'as',
#  'you',
#  'know',
#  ',',
#  'the',
#  'Border',
#  'Patrol',
#  'agents',
#  ',',
#  '16,500-',
#  'plus',
#  'ICE',
#  'last',
#  'week',
#  ',',
#  'endorsed',
#  'me',
#  '.',
#  ...]

# %% [markdown]
# ## Debate St. Louis 2016

# %%
html_debate_st_louis_2016 = request.urlopen(url_debate_st_louis_2016).read().decode('utf8')
raw_debate_st_louis_2016 = BeautifulSoup(html_debate_st_louis_2016, 'html.parser')

raw_dem_debate_st_louis_2016 = []
dem_st_louis_2016 = False
raw_rep_debate_st_louis_2016 = []
rep_st_louis_2016 = False

for p in raw_debate_st_louis_2016.select('div.field-docs-content > p'):
    if p.get_text().startswith('CLINTON'):
        first, _, rest = p.get_text().partition(" ")
        raw_dem_debate_st_louis_2016.append(rest)
        dem_st_louis_2016 = True
        rep_st_louis_2016 = False
    elif p.get_text().startswith('TRUMP'):
        first, _, rest = p.get_text().partition(" ")
        raw_rep_debate_st_louis_2016.append(rest)
        dem_st_louis_2016 = False
        rep_st_louis_2016 = True
    elif p.get_text().startswith('COOPER') or p.get_text().startswith('RADDATZ'):
        dem_st_louis_2016 = False
        rep_st_louis_2016 = False
    elif rep_st_louis_2016:
        raw_rep_debate_st_louis_2016.append(p.get_text())
    elif dem_st_louis_2016:
        raw_dem_debate_st_louis_2016.append(p.get_text())
        
raw_rep_debate_st_louis_2016 = ' '.join(raw_rep_debate_st_louis_2016)
tokens_rep_debate_st_louis_2016 = tokenizer.tokenize(raw_rep_debate_st_louis_2016)
tokens_rep_debate_st_louis_2016

raw_dem_debate_st_louis_2016 = ' '.join(raw_dem_debate_st_louis_2016)
tokens_dem_debate_st_louis_2016 = tokenizer.tokenize(raw_dem_debate_st_louis_2016)
tokens_dem_debate_st_louis_2016
# Out:
# ['Well',
#  ',',
#  'thank',
#  'you',
#  '.',
#  'Are',
#  'you',
#  'a',
#  'teacher',
#  '?',
#  'Yes',
#  ',',
#  'I',
#  'think',
#  'that',
#  "that's",
#  'a',
#  'very',
#  'good',
#  'question',
#  ',',
#  'because',
#  "I've",
#  'heard',
#  'from',
#  'lots',
#  'of',
#  'teachers',
#  'and',
#  'parents',
#  'about',
#  'some',
#  'of',
#  'their',
#  'concerns',
#  'about',
#  'some',
#  'of',
#  'the',
#  'things',
#  'that',
#  'are',
#  'being',
#  'said',
#  'and',
#  'done',
#  'in',
#  'this',
#  'campaign',
#  '.',
#  'And',
#  'I',
#  'think',
#  'it',
#  'is',
#  'very',
#  'important',
#  'for',
#  'us',
#  'to',
#  'make',
#  'clear',
#  'to',
#  'our',
#  'children',
#  'that',
#  'our',
#  'country',
#  'really',
#  'is',
#  'great',
#  'because',
#  "we're",
#  'good',
#  '.',
#  'And',
#  'we',
#  'are',
#  'going',
#  'to',
#  'respect',
#  'one',
#  'another',
#  ',',
#  'lift',
#  'each',
#  'other',
#  'up',
#  '.',
#  'We',
#  'are',
#  'going',
#  'to',
#  'be',
#  'looking',
#  'for',
#  'ways',
#  'to',
#  'celebrate',
#  'our',
#  'diversity',
#  ',',
#  'and',
#  'we',
#  'are',
#  'going',
#  'to',
#  'try',
#  'to',
#  'reach',
#  'out',
#  'to',
#  'every',
#  'boy',
#  'and',
#  'girl',
#  ',',
#  'as',
#  'well',
#  'as',
#  'every',
#  'adult',
#  ',',
#  'to',
#  'bring',
#  'them',
#  'in',
#  'to',
#  'working',
#  'on',
#  'behalf',
#  'of',
#  'our',
#  'country',
#  '.',
#  'I',
#  'have',
#  'a',
#  'very',
#  'positive',
#  'and',
#  'optimistic',
#  'view',
#  'about',
#  'what',
#  'we',
#  'can',
#  'do',
#  'together',
#  '.',
#  "That's",
#  'why',
#  'the',
#  'slogan',
#  'of',
#  'my',
#  'campaign',
#  'is',
#  '"',
#  'Stronger',
#  'Together',
#  ',',
#  '"',
#  'because',
#  'I',
#  'think',
#  'if',
#  'we',
#  'work',
#  'together',
#  ',',
#  'if',
#  'we',
#  'overcome',
#  'the',
#  'divisiveness',
#  'that',
#  'sometimes',
#  'sets',
#  'Americans',
#  'against',
#  'one',
#  'another',
#  ',',
#  'and',
#  'instead',
#  'we',
#  'make',
#  'some',
#  'big',
#  'goals',
#  '—',
#  'and',
#  "I've",
#  'set',
#  'forth',
#  'some',
#  'big',
#  'goals',
#  ',',
#  'getting',
#  'the',
#  'economy',
#  'to',
#  'work',
#  'for',
#  'everyone',
#  ',',
#  'not',
#  'just',
#  'those',
#  'at',
#  'the',
#  'top',
#  ',',
#  'making',
#  'sure',
#  'that',
#  'we',
#  'have',
#  'the',
#  'best',
#  'education',
#  'system',
#  'from',
#  'preschool',
#  'through',
#  'college',
#  'and',
#  'making',
#  'it',
#  'affordable',
#  ',',
#  'and',
#  'so',
#  'much',
#  'else',
#  '.',
#  'If',
#  'we',
#  'set',
#  'those',
#  'goals',
#  'and',
#  'we',
#  'go',
#  'together',
#  'to',
#  'try',
#  'to',
#  'achieve',
#  'them',
#  ',',
#  "there's",
#  'nothing',
#  'in',
#  'my',
#  'opinion',
#  'that',
#  'America',
#  "can't",
#  'do',
#  '.',
#  'So',
#  "that's",
#  'why',
#  'I',
#  'hope',
#  'that',
#  'we',
#  'will',
#  'come',
#  'together',
#  'in',
#  'this',
#  'campaign',
#  '.',
#  'Obviously',
#  ',',
#  "I'm",
#  'hoping',
#  'to',
#  'earn',
#  'your',
#  'vote',
#  ',',
#  "I'm",
#  'hoping',
#  'to',
#  'be',
#  'elected',
#  'in',
#  'November',
#  ',',
#  'and',
#  'I',
#  'can',
#  'promise',
#  'you',
#  ',',
#  'I',
#  'will',
#  'work',
#  'with',
#  'every',
#  'American',
#  '.',
#  'I',
#  'want',
#  'to',
#  'be',
#  'the',
#  'president',
#  'for',
#  'all',
#  'Americans',
#  ',',
#  'regardless',
#  'of',
#  'your',
#  'political',
#  'beliefs',
#  ',',
#  'where',
#  'you',
#  'come',
#  'from',
#  ',',
#  'what',
#  'you',
#  'look',
#  'like',
#  ',',
#  'your',
#  'religion',
#  '.',
#  'I',
#  'want',
#  'us',
#  'to',
#  'heal',
#  'our',
#  'country',
#  'and',
#  'bring',
#  'it',
#  'together',
#  'because',
#  "that's",
#  ',',
#  'I',
#  'think',
#  ',',
#  'the',
#  'best',
#  'way',
#  'for',
#  'us',
#  'to',
#  'get',
#  'the',
#  'future',
#  'that',
#  'our',
#  'children',
#  'and',
#  'our',
#  'grandchildren',
#  'deserve',
#  '.',
#  'Well',
#  ',',
#  'like',
#  'everyone',
#  'else',
#  ',',
#  "I've",
#  'spent',
#  'a',
#  'lot',
#  'of',
#  'time',
#  'thinking',
#  'over',
#  'the',
#  'last',
#  '48',
#  'hours',
#  'about',
#  'what',
#  'we',
#  'heard',
#  'and',
#  'saw',
#  '.',
#  'You',
#  'know',
#  ',',
#  'with',
#  'prior',
#  'Republican',
#  'nominees',
#  'for',
#  'president',
#  ',',
#  'I',
#  'disagreed',
#  'with',
#  'them',
#  'on',
#  'politics',
#  ',',
#  'policies',
#  ',',
#  'principles',
#  ',',
#  'but',
#  'I',
#  'never',
#  'questioned',
#  'their',
#  'fitness',
#  'to',
#  'serve',
#  '.',
#  'Donald',
#  'Trump',
#  'is',
#  'different',
#  '.',
#  'I',
#  'said',
#  'starting',
#  'back',
#  'in',
#  'June',
#  'that',
#  'he',
#  'was',
#  'not',
#  'fit',
#  'to',
#  'be',
#  'president',
#  'and',
#  'commander-in-chief',
#  '.',
#  'And',
#  'many',
#  'Republicans',
#  'and',
#  'independents',
#  'have',
#  'said',
#  'the',
#  'same',
#  'thing',
#  '.',
#  'What',
#  'we',
#  'all',
#  'saw',
#  'and',
#  'heard',
#  'on',
#  'Friday',
#  'was',
#  'Donald',
#  'talking',
#  'about',
#  'women',
#  ',',
#  'what',
#  'he',
#  'thinks',
#  'about',
#  'women',
#  ',',
#  'what',
#  'he',
#  'does',
#  'to',
#  'women',
#  '.',
#  'And',
#  'he',
#  'has',
#  'said',
#  'that',
#  'the',
#  'video',
#  "doesn't",
#  'represent',
#  'who',
#  'he',
#  'is',
#  '.',
#  'But',
#  'I',
#  'think',
#  "it's",
#  'clear',
#  'to',
#  'anyone',
#  'who',
#  'heard',
#  'it',
#  'that',
#  'it',
#  'represents',
#  'exactly',
#  'who',
#  'he',
#  'is',
#  '.',
#  'Because',
#  "we've",
#  'seen',
#  'this',
#  'throughout',
#  'the',
#  'campaign',
#  '.',
#  'We',
#  'have',
#  'seen',
#  'him',
#  'insult',
#  'women',
#  '.',
#  "We've",
#  'seen',
#  'him',
#  'rate',
#  'women',
#  'on',
#  'their',
#  'appearance',
#  ',',
#  'ranking',
#  'them',
#  'from',
#  'one',
#  'to',
#  'ten',
#  '.',
#  "We've",
#  'seen',
#  'him',
#  'embarrass',
#  'women',
#  'on',
#  'TV',
#  'and',
#  'on',
#  'Twitter',
#  '.',
#  'We',
#  'saw',
#  'him',
#  'after',
#  'the',
#  'first',
#  'debate',
#  'spend',
#  'nearly',
#  'a',
#  'week',
#  'denigrating',
#  'a',
#  'former',
#  'Miss',
#  'Universe',
#  'in',
#  'the',
#  'harshest',
#  ',',
#  'most',
#  'personal',
#  'terms',
#  '.',
#  'So',
#  ',',
#  'yes',
#  ',',
#  'this',
#  'is',
#  'who',
#  'Donald',
#  'Trump',
#  'is',
#  '.',
#  'But',
#  "it's",
#  'not',
#  'only',
#  'women',
#  ',',
#  'and',
#  "it's",
#  'not',
#  'only',
#  'this',
#  'video',
#  'that',
#  'raises',
#  'questions',
#  'about',
#  'his',
#  'fitness',
#  'to',
#  'be',
#  'our',
#  'president',
#  ',',
#  'because',
#  'he',
#  'has',
#  'also',
#  'targeted',
#  'immigrants',
#  ',',
#  'African',
#  '-',
#  'Americans',
#  ',',
#  'Latinos',
#  ',',
#  'people',
#  'with',
#  'disabilities',
#  ',',
#  'POWs',
#  ',',
#  'Muslims',
#  ',',
#  'and',
#  'so',
#  'many',
#  'others',
#  '.',
#  'So',
#  'this',
#  'is',
#  'who',
#  'Donald',
#  'Trump',
#  'is',
#  '.',
#  'And',
#  'the',
#  'question',
#  'for',
#  'us',
#  ',',
#  'the',
#  'question',
#  'our',
#  'country',
#  'must',
#  'answer',
#  'is',
#  'that',
#  'this',
#  'is',
#  'not',
#  'who',
#  'we',
#  'are',
#  '.',
#  "That's",
#  'why',
#  '—',
#  'to',
#  'go',
#  'back',
#  'to',
#  'your',
#  'question',
#  '—',
#  'I',
#  'want',
#  'to',
#  'send',
#  'a',
#  'message',
#  '—',
#  'we',
#  'all',
#  'should',
#  '—',
#  'to',
#  'every',
#  'boy',
#  'and',
#  'girl',
#  'and',
#  ',',
#  'indeed',
#  ',',
#  'to',
#  'the',
#  'entire',
#  'world',
#  'that',
#  'America',
#  'already',
#  'is',
#  'great',
#  ',',
#  'but',
#  'we',
#  'are',
#  'great',
#  'because',
#  'we',
#  'are',
#  'good',
#  ',',
#  'and',
#  'we',
#  'will',
#  'respect',
#  'one',
#  'another',
#  ',',
#  'and',
#  'we',
#  'will',
#  'work',
#  'with',
#  'one',
#  'another',
#  ',',
#  'and',
#  'we',
#  'will',
#  'celebrate',
#  'our',
#  'diversity',
#  '.',
#  'These',
#  'are',
#  'very',
#  'important',
#  'values',
#  'to',
#  'me',
#  ',',
#  'because',
#  'this',
#  'is',
#  'the',
#  'America',
#  'that',
#  'I',
#  'know',
#  'and',
#  'love',
#  '.',
#  'And',
#  'I',
#  'can',
#  'pledge',
#  'to',
#  'you',
#  'tonight',
#  'that',
#  'this',
#  'is',
#  'the',
#  'America',
#  'that',
#  'I',
#  'will',
#  'serve',
#  'if',
#  "I'm",
#  'so',
#  'fortunate',
#  'enough',
#  'to',
#  'become',
#  'your',
#  'president',
#  '.',
#  'Well',
#  ',',
#  'first',
#  ',',
#  'let',
#  'me',
#  'start',
#  'by',
#  'saying',
#  'that',
#  'so',
#  'much',
#  'of',
#  'what',
#  "he's",
#  'just',
#  'said',
#  'is',
#  'not',
#  'right',
#  ',',
#  'but',
#  'he',
#  'gets',
#  'to',
#  'run',
#  'his',
#  'campaign',
#  'any',
#  'way',
#  'he',
#  'chooses',
#  '.',
#  'He',
#  'gets',
#  'to',
#  'decide',
#  'what',
#  'he',
#  'wants',
#  'to',
#  'talk',
#  'about',
#  '.',
#  'Instead',
#  'of',
#  'answering',
#  "people's",
#  'questions',
#  ',',
#  'talking',
#  'about',
#  'our',
#  'agenda',
#  ',',
#  'laying',
#  'out',
#  'the',
#  'plans',
#  'that',
#  'we',
#  'have',
#  'that',
#  'we',
#  'think',
#  'can',
#  'make',
#  'a',
#  'better',
#  'life',
#  'and',
#  'a',
#  'better',
#  'country',
#  ',',
#  "that's",
#  'his',
#  'choice',
#  '.',
#  'When',
#  'I',
#  'hear',
#  'something',
#  'like',
#  'that',
#  ',',
#  'I',
#  'am',
#  'reminded',
#  'of',
#  'what',
#  'my',
#  'friend',
#  ',',
#  'Michelle',
#  'Obama',
#  ',',
#  'advised',
#  'us',
#  'all',
#  ':',
#  'When',
#  'they',
#  'go',
#  'low',
#  ',',
#  'you',
#  'go',
#  'high',
#  '.',
#  '[',
#  'applause',
#  ']',
#  'And',
#  ',',
#  'look',
#  ',',
#  'if',
#  'this',
#  'were',
#  'just',
#  'about',
#  'one',
#  'video',
#  ',',
#  'maybe',
#  'what',
#  "he's",
#  'saying',
#  'tonight',
#  'would',
#  'be',
#  'understandable',
#  ',',
#  'but',
#  'everyone',
#  'can',
#  'draw',
#  'their',
#  'own',
#  'conclusions',
#  'at',
#  'this',
#  'point',
#  'about',
#  'whether',
#  'or',
#  'not',
#  'the',
#  'man',
#  'in',
#  'the',
#  'video',
#  'or',
#  'the',
#  'man',
#  'on',
#  'the',
#  'stage',
#  'respects',
#  'women',
#  '.',
#  'But',
#  'he',
#  'never',
#  'apologizes',
#  'for',
#  'anything',
#  'to',
#  'anyone',
#  '.',
#  'He',
#  'never',
#  'apologized',
#  'to',
#  'Mr',
#  '.',
#  'and',
#  'Mrs',
#  '.',
#  'Khan',
#  ',',
#  'the',
#  'Gold',
#  'Star',
#  'family',
#  'whose',
#  'son',
#  ',',
#  'Captain',
#  'Khan',
#  ',',
#  'died',
#  'in',
#  'the',
#  'line',
#  'of',
#  'duty',
#  'in',
#  'Iraq',
#  '.',
#  'And',
#  'Donald',
#  'insulted',
#  'and',
#  'attacked',
#  'them',
#  'for',
#  'weeks',
#  'over',
#  'their',
#  'religion',
#  '.',
#  'He',
#  ...]

# %% [markdown]
# ## Debates 2016 combined

# %%
tokens_dem_debate_2016 = tokens_dem_debate_las_vegas_2016 + tokens_dem_debate_st_louis_2016
tokens_rep_debate_2016 = tokens_rep_debate_las_vegas_2016 + tokens_rep_debate_st_louis_2016

tokens_dem_debate_2016 = [char.lower() for char in tokens_dem_debate_2016]
tokens_dem_debate_2016 = [char for char in tokens_dem_debate_2016 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_dem_debate_2016
lemmatized_tokens_dem_debate_2016 = [lemmatizer.lemmatize(word) for word in tokens_dem_debate_2016]
lemmatized_tokens_dem_debate_2016

tokens_rep_debate_2016 = [char.lower() for char in tokens_rep_debate_2016]
tokens_rep_debate_2016 = [char for char in tokens_rep_debate_2016 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_rep_debate_2016
lemmatized_tokens_rep_debate_2016 = [lemmatizer.lemmatize(word) for word in tokens_rep_debate_2016]
lemmatized_tokens_rep_debate_2016

text_rep_debate_2016 = nltk.Text(tokens_rep_debate_2016)
text_dem_debate_2016 = nltk.Text(tokens_dem_debate_2016)

# %% [markdown]
# ## Democratic Party Platform 1980

# %%
html_dem_platform_1980 = request.urlopen(url_dem_platform_1980).read().decode('utf8')
raw_dem_platform_1980 = BeautifulSoup(html_dem_platform_1980, 'html.parser')
raw_dem_platform_1980 = [p.get_text() for p in raw_dem_platform_1980.select('div.field-docs-content > p')]
raw_dem_platform_1980 = ' '.join(raw_dem_platform_1980)

tokens_dem_platform_1980 = tokenizer.tokenize(raw_dem_platform_1980)
tokens_dem_platform_1980 = [char.lower() for char in tokens_dem_platform_1980]
tokens_dem_platform_1980 = [char for char in tokens_dem_platform_1980 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_dem_platform_1980

lemmatized_tokens_dem_platform_1980 = [lemmatizer.lemmatize(word) for word in tokens_dem_platform_1980]
lemmatized_tokens_dem_platform_1980
# Out:
# ['third',
#  'century',
#  'america',
#  'face',
#  'great',
#  'challenge',
#  'uncertain',
#  'future',
#  'decade',
#  'america',
#  'enters',
#  'present',
#  'u',
#  'decision',
#  'monumental',
#  'fundamental',
#  'faced',
#  'civil',
#  'war',
#  'two',
#  'world',
#  'war',
#  'great',
#  'depression',
#  'current',
#  'task',
#  'different',
#  'historic',
#  'challenge',
#  'many',
#  'way',
#  'challenge',
#  'marshall',
#  'talent',
#  'spirit',
#  'american',
#  'people',
#  'harness',
#  'enormous',
#  'resource',
#  'face',
#  'future',
#  'confidence',
#  'hope',
#  'task',
#  'u',
#  'global',
#  'worldwide',
#  'energy',
#  'shortage',
#  'local',
#  'plight',
#  'child',
#  'appalachia',
#  'reach',
#  'condition',
#  'older',
#  'eastern',
#  'city',
#  'industry',
#  'snowbelt',
#  'complex',
#  'new',
#  'demand',
#  'sunbelt',
#  'region',
#  'special',
#  'need',
#  'western',
#  'state',
#  'basic',
#  'entitlement',
#  'minority',
#  'woman',
#  'real',
#  'equality',
#  'every',
#  'aspect',
#  "nation's",
#  'life',
#  'immediate',
#  'refugee',
#  'crisis',
#  'miami',
#  'natural',
#  'disaster',
#  'mount',
#  'st',
#  'helen',
#  'futuristic',
#  'exploration',
#  'space',
#  'ocean',
#  'idealistic',
#  'spirit',
#  'liberty',
#  'imbues',
#  'constitution',
#  'requires',
#  'nothing',
#  'le',
#  'continued',
#  'dedication',
#  'democratic',
#  'principle',
#  'element',
#  'society',
#  'government',
#  'business',
#  'labor',
#  'every',
#  'citizen',
#  'promise',
#  'potential',
#  'nation',
#  'live',
#  'time',
#  'effective',
#  'policy',
#  'requires',
#  'understanding',
#  'web',
#  'competing',
#  'value',
#  'interest',
#  'exist',
#  'country',
#  'must',
#  'combine',
#  'compassion',
#  'self-discipline',
#  'must',
#  'forego',
#  'simplistic',
#  'answer',
#  'long-term',
#  'solution',
#  'problem',
#  'republican',
#  'leadership',
#  'closing',
#  'eye',
#  'reality',
#  'time',
#  'running',
#  'presidency',
#  'program',
#  'easy',
#  'answer',
#  'pleasant-sounding',
#  'political',
#  'promise',
#  'time',
#  'take',
#  'page',
#  'adlai',
#  "stevenson's",
#  '1952',
#  'presidential',
#  'campaign',
#  'time',
#  'talk',
#  'sense',
#  'american',
#  'people',
#  'time',
#  'talk',
#  'bluntly',
#  'candidly',
#  'problem',
#  'proposed',
#  'solution',
#  'face',
#  'problem',
#  'respond',
#  'fail',
#  'important',
#  'task',
#  '...',
#  'fail',
#  'lay',
#  'issue',
#  'squarely',
#  'american',
#  'people',
#  'could',
#  'well',
#  'allow',
#  'federal',
#  'government',
#  'revert',
#  'four',
#  'year',
#  'republicanism',
#  'neglect',
#  'poor',
#  'disadvantaged',
#  'disdain',
#  'working',
#  'men',
#  'woman',
#  'compassion',
#  'rich',
#  'privileged',
#  'failure',
#  'meet',
#  'challenge',
#  'energy',
#  'inflation',
#  'unemployment',
#  'breakdown',
#  'partnership',
#  'among',
#  'local',
#  'state',
#  'federal',
#  'government',
#  'democrat',
#  'must',
#  'let',
#  'happen',
#  'nearly',
#  'four',
#  'year',
#  'office',
#  'democrat',
#  'solved',
#  "america's",
#  'problem',
#  'problem',
#  'inherited',
#  'eight',
#  'year',
#  'republican',
#  'politics',
#  'left',
#  'nation',
#  'weak',
#  'rudderless',
#  'unrespected',
#  'deeply',
#  'divided',
#  'result',
#  'legacy',
#  'despite',
#  'progress',
#  'inflation',
#  'still',
#  'erodes',
#  'standard',
#  'living',
#  'every',
#  'american',
#  'result',
#  'legacy',
#  'despite',
#  'progress',
#  'many',
#  'american',
#  'work',
#  'result',
#  'legacy',
#  'despite',
#  'progress',
#  'complete',
#  'equality',
#  'citizen',
#  'yet',
#  'achieved',
#  'result',
#  'legacy',
#  'despite',
#  'progress',
#  'still',
#  'live',
#  'dangerous',
#  'world',
#  'competing',
#  'ideology',
#  'age-old',
#  'animosity',
#  'daily',
#  'threaten',
#  'peace',
#  'result',
#  'legacy',
#  'nation',
#  'still',
#  'subject',
#  'oil',
#  'pricing',
#  'production',
#  'decision',
#  'foreign',
#  'country',
#  'run',
#  'problem',
#  'fail',
#  'record',
#  'past',
#  'four',
#  'year',
#  'testament',
#  'democrat',
#  'working',
#  'together',
#  'time',
#  'time',
#  'past',
#  'four',
#  'year',
#  'democratic',
#  'congress',
#  'democratic',
#  'president',
#  'proved',
#  'willing',
#  'make',
#  'tough',
#  'decision',
#  'today',
#  'democratic',
#  'partnership',
#  'stronger',
#  'nation',
#  'today',
#  'democratic',
#  'partnership',
#  'peace',
#  'today',
#  'democratic',
#  'partnership',
#  'nation',
#  'today',
#  'democratic',
#  'partnership',
#  'honor',
#  'truth',
#  'integrity',
#  'restored',
#  'government',
#  'political',
#  'process',
#  'party',
#  'look',
#  'future',
#  'determination',
#  'confidence',
#  'shall',
#  'remain',
#  'party',
#  'american',
#  'seek',
#  'solution',
#  'meet',
#  'need',
#  'many',
#  'reaffirm',
#  'commitment',
#  'improve',
#  'condition',
#  'least',
#  'fortunate',
#  'society',
#  'platform',
#  'offer',
#  'program',
#  'solution',
#  'represent',
#  'dedication',
#  'democratic',
#  'principle',
#  'define',
#  'spirit',
#  'well',
#  'program',
#  '...',
#  'set',
#  'belief',
#  'well',
#  'set',
#  'idea',
#  'time',
#  'event',
#  'may',
#  'alter',
#  'priority',
#  'prospect',
#  'nothing',
#  'alter',
#  'defining',
#  'spirit',
#  'value',
#  'thee',
#  'democratic',
#  'party',
#  'platform',
#  'democratic',
#  'party',
#  'contract',
#  'people',
#  'believe',
#  'accountability',
#  'democratic',
#  'principle',
#  'go',
#  'hand',
#  'hand',
#  'dedication',
#  'principle',
#  'democratic',
#  'party',
#  'proud',
#  'historic',
#  'heritage',
#  'commitment',
#  'people',
#  'america',
#  'fulfilling',
#  'platform',
#  'permit',
#  'u',
#  'keep',
#  'faith',
#  'tradition',
#  'democratic',
#  'party',
#  'take',
#  'action',
#  'whose',
#  'effect',
#  'significant',
#  'increase',
#  'unemployment',
#  'fiscal',
#  'action',
#  'monetary',
#  'action',
#  'budgetary',
#  'action',
#  'assessment',
#  'either',
#  'council',
#  'economic',
#  'adviser',
#  'congressional',
#  'budget',
#  'office',
#  'action',
#  'cause',
#  'significantly',
#  'greater',
#  'unemployment',
#  'economic',
#  'program',
#  'one',
#  'overriding',
#  'principle',
#  'must',
#  'fairness',
#  'american',
#  'must',
#  'bear',
#  'fair',
#  'share',
#  'economic',
#  'burden',
#  'reap',
#  'fair',
#  'share',
#  'economic',
#  'benefit',
#  'high',
#  'interest',
#  'rate',
#  'impose',
#  'unfair',
#  'burden',
#  'farmer',
#  'small',
#  'business',
#  'younger',
#  'family',
#  'buying',
#  'home',
#  'recession',
#  'imposes',
#  'unfair',
#  'burden',
#  'least',
#  'able',
#  'bear',
#  'democratic',
#  'economic',
#  'policy',
#  'must',
#  'assure',
#  'fairness',
#  'worker',
#  'elderly',
#  'woman',
#  'poor',
#  'minority',
#  'majority',
#  'middle',
#  'income',
#  'american',
#  '1980',
#  'pledge',
#  'truly',
#  'democratic',
#  'economic',
#  'policy',
#  'secure',
#  'prosperous',
#  'economic',
#  'future',
#  'past',
#  'three',
#  'half',
#  'year',
#  'democratic',
#  'leadership',
#  'year',
#  'growth',
#  'economy',
#  'find',
#  'recession',
#  'democratic',
#  'party',
#  'committed',
#  'taking',
#  'necessary',
#  'step',
#  'combat',
#  'current',
#  'recession',
#  'however',
#  'cannot',
#  'abandon',
#  'fight',
#  'inflation',
#  'must',
#  'fight',
#  'problem',
#  'time',
#  'committed',
#  'continue',
#  'pursue',
#  'fight',
#  'inflation',
#  'way',
#  'designed',
#  'intended',
#  'increase',
#  'unemployment',
#  'current',
#  'economic',
#  'situation',
#  'unique',
#  '1977',
#  'inherited',
#  'severe',
#  'recession',
#  'republican',
#  'democratic',
#  'administration',
#  'democratic',
#  'congress',
#  'acted',
#  'quickly',
#  'reduce',
#  'unacceptably',
#  'high',
#  'level',
#  'unemployment',
#  'stimulate',
#  'economy',
#  'succeeded',
#  'recovered',
#  'deep',
#  'recession',
#  'economy',
#  'strengthened',
#  'revitalized',
#  'fight',
#  'enormous',
#  'increase',
#  'foreign',
#  'oil',
#  'price',
#  '120',
#  'percent',
#  'last',
#  'year',
#  'declining',
#  'productivity',
#  'fueled',
#  'inflationary',
#  'spiral',
#  'also',
#  'fought',
#  'democrat',
#  'inflation',
#  'begun',
#  'recede',
#  'working',
#  'combat',
#  'dual',
#  'problem',
#  'significant',
#  'economic',
#  'action',
#  'taken',
#  'two',
#  'tax',
#  'cut',
#  'enacted',
#  '1977',
#  '1978',
#  'reducing',
#  'tax',
#  'individual',
#  'business',
#  'amount',
#  'equal',
#  'year',
#  '40',
#  'billion',
#  'meeting',
#  'national',
#  'security',
#  'pressing',
#  'domestic',
#  'need',
#  'democratic',
#  'partnership',
#  'restrained',
#  'increase',
#  'government',
#  'spending',
#  'way',
#  'steadily',
#  'reduced',
#  'deficit',
#  'inherited',
#  'airline',
#  'banking',
#  'regulatory',
#  'reform',
#  'enacted',
#  'regulatory',
#  'reform',
#  'consideration',
#  'effort',
#  'restrain',
#  'inflation',
#  'voluntary',
#  'pay',
#  'advisory',
#  'committee',
#  'established',
#  'labor',
#  'business',
#  'public',
#  'representative',
#  'pursuant',
#  'national',
#  'accord',
#  'first',
#  'national',
#  'export',
#  'policy',
#  'developed',
#  'export',
#  'trade',
#  'responsibility',
#  'reorganized',
#  'strengthened',
#  'multilateral',
#  'trade',
#  'negotiation',
#  'completed',
#  'mtn',
#  'agreement',
#  'approved',
#  'congress',
#  'ensure',
#  'greater',
#  'impact',
#  'scarce',
#  'federal',
#  'dollar',
#  'grant',
#  'loan',
#  'program',
#  'redirected',
#  'area',
#  'greatest',
#  'need',
#  'formula',
#  'program',
#  'redesigned',
#  'target',
#  'area',
#  'serious',
#  'problem',
#  'result',
#  'economic',
#  'action',
#  'employment',
#  '8.5',
#  'million',
#  'new',
#  'job',
#  'added',
#  'work',
#  'force',
#  '1',
#  'million',
#  'job',
#  'held',
#  'black',
#  'nearly',
#  'additional',
#  '1',
#  'million',
#  'held',
#  'hispanic',
#  'gain',
#  'made',
#  'group',
#  'men',
#  'woman',
#  'minority',
#  'young',
#  'people',
#  'working',
#  'ever',
#  'history',
#  'despite',
#  'gain',
#  'current',
#  'unemployment',
#  'high',
#  'must',
#  'lowered',
#  'inflation',
#  'strong',
#  'anti-inflation',
#  'program',
#  'initiated',
#  'pursued',
#  'aggressively',
#  'deal',
#  'short-term',
#  'inflation',
#  'problem',
#  'long-term',
#  'cause',
#  'inflation',
#  'effect',
#  'short-term',
#  'effort',
#  'evident',
#  'inflation',
#  'beginning',
#  'come',
#  'although',
#  'interest',
#  'rate',
#  'remain',
#  'high',
#  'falling',
#  'record',
#  'rate',
#  'progress',
#  'continue',
#  'short-term',
#  'action',
#  'continue',
#  'work',
#  'long-term',
#  'initiative',
#  'begin',
#  'take',
#  'hold',
#  'economic',
#  'growth',
#  'despite',
#  'economic',
#  'decline',
#  'past',
#  'month',
#  'first',
#  'three',
#  'year',
#  'carter',
#  'administration',
#  'economy',
#  'strong',
#  '1977',
#  '1979',
#  'period',
#  'gross',
#  'national',
#  'product',
#  'increased',
#  '11.8',
#  'percent',
#  'real',
#  'term',
#  'real',
#  'after-tax',
#  'income',
#  'per',
#  'person',
#  'increased',
#  '10.3',
#  'percent',
#  'industrial',
#  'production',
#  'increased',
#  '14.8',
#  'percent',
#  'dividend',
#  'increased',
#  '36',
#  'percent',
#  'real',
#  'business',
#  'fixed',
#  'investment',
#  'increased',
#  '22.9',
#  'percent',
#  'energy',
#  'dependence',
#  'foreign',
#  'decreased',
#  '1977',
#  'imported',
#  '8.8',
#  'million',
#  'barrel',
#  'oil',
#  'per',
#  'day',
#  'nation',
#  'importing',
#  'approximately',
#  '6.5',
#  'million',
#  'per',
#  'day',
#  'decline',
#  '26',
#  'percent',
#  'democratic',
#  'party',
#  'commits',
#  'strong',
#  'economic',
#  'program',
#  'one',
#  'build',
#  'progress',
#  'made',
#  'date',
#  'one',
#  'corrects',
#  'real',
#  'problem',
#  'face',
#  'one',
#  'responsible',
#  'one',
#  'offer',
#  'realistic',
#  'hope',
#  'one',
#  'unify',
#  'party',
#  'democratic',
#  'program',
#  'would',
#  'contrast',
#  'dramatically',
#  'simplistic',
#  'rhetoric',
#  'traditional',
#  'economic',
#  'policy',
#  'republican',
#  'party',
#  'full',
#  'employment',
#  'specifically',
#  'reaffirm',
#  'commitment',
#  'achieve',
#  'goal',
#  'humphrey-hawkins',
#  'full',
#  'employment',
#  'act',
#  'within',
#  'currently',
#  'prescribed',
#  'date',
#  'act',
#  'especially',
#  'relating',
#  'joint',
#  'reduction',
#  'unemployment',
#  'inflation',
#  'full',
#  'employment',
#  'important',
#  'achievement',
#  'rising',
#  'standard',
#  'living',
#  'pursuit',
#  'sound',
#  'justice',
#  'strength',
#  'vitality',
#  'america',
#  'anti-recession',
#  'assistance',
#  'immediately',
#  'must',
#  'undertake',
#  'short-term',
#  'anti-recession',
#  'program',
#  'reverse',
#  'tide',
#  'deepening',
#  'recession',
#  'rising',
#  'unemployment',
#  'percentage',
#  'point',
#  'increase',
#  'unemployment',
#  'rate',
#  'add',
#  '25',
#  'billion',
#  'federal',
#  'deficit',
#  'democratic',
#  'anti-recession',
#  'program',
#  'must',
#  'recognize',
#  'black',
#  'hispanic',
#  'minority',
#  'woman',
#  'older',
#  'worker',
#  'bear',
#  'brunt',
#  'recession',
#  'pledge',
#  '12',
#  'billion',
#  'anti-recession',
#  'job',
#  'program',
#  'providing',
#  'least',
#  '800,000',
#  'additional',
#  'job',
#  'including',
#  'full',
#  'funding',
#  'counter-cyclical',
#  'assistance',
#  'program',
#  'city',
#  'major',
#  'expansion',
#  'youth',
#  'employment',
#  'training',
#  'program',
#  'give',
#  'young',
#  'people',
#  'inner',
#  'city',
#  'new',
#  'hope',
#  'expanded',
#  ...]

# %% [markdown]
# ## Republican Party Platform 1980

# %%
html_rep_platform_1980 = request.urlopen(url_rep_platform_1980).read().decode('utf8')
raw_rep_platform_1980 = BeautifulSoup(html_rep_platform_1980, 'html.parser')
raw_rep_platform_1980 = [p.get_text() for p in raw_rep_platform_1980.select('div.field-docs-content > p')]
raw_rep_platform_1980 = ' '.join(raw_rep_platform_1980)

tokens_rep_platform_1980 = tokenizer.tokenize(raw_rep_platform_1980)
tokens_rep_platform_1980 = [char.lower() for char in tokens_rep_platform_1980]
tokens_rep_platform_1980 = [char for char in tokens_rep_platform_1980 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_rep_platform_1980

lemmatized_tokens_rep_platform_1980 = [lemmatizer.lemmatize(word) for word in tokens_rep_platform_1980]
lemmatized_tokens_rep_platform_1980
# Out:
# ['adopted',
#  'republican',
#  'national',
#  'convention',
#  'july',
#  '15',
#  '1980',
#  'detroit',
#  'mich',
#  'republican',
#  'party',
#  'convenes',
#  'present',
#  'platform',
#  'selects',
#  'nominee',
#  'time',
#  'crisis',
#  'america',
#  'adrift',
#  'country',
#  'move',
#  'agonizingly',
#  'aimlessly',
#  'almost',
#  'helplessly',
#  'one',
#  'dangerous',
#  'disorderly',
#  'period',
#  'history',
#  'home',
#  'economy',
#  'careen',
#  'whiplashed',
#  'one',
#  'extreme',
#  'another',
#  'earlier',
#  'year',
#  'inflation',
#  'skyrocketed',
#  'highest',
#  'level',
#  'century',
#  'week',
#  'later',
#  'economy',
#  'plummeted',
#  'suffering',
#  'steepest',
#  'slide',
#  'record',
#  'price',
#  'escalate',
#  '10',
#  'percent',
#  'year',
#  'eight',
#  'million',
#  'people',
#  'seek',
#  'employment',
#  'manufacturing',
#  'plant',
#  'lie',
#  'idle',
#  'across',
#  'country',
#  'hope',
#  'aspiration',
#  'people',
#  'smothered',
#  'overseas',
#  'condition',
#  'already',
#  'perilous',
#  'deteriorate',
#  'soviet',
#  'union',
#  'first',
#  'time',
#  'acquiring',
#  'mean',
#  'obliterate',
#  'cripple',
#  'land-based',
#  'missile',
#  'system',
#  'blackmail',
#  'u',
#  'submission',
#  'marxist',
#  'tyranny',
#  'spread',
#  'rapidly',
#  'third',
#  'world',
#  'latin',
#  'america',
#  'alliance',
#  'frayed',
#  'europe',
#  'elsewhere',
#  'energy',
#  'supply',
#  'become',
#  'even',
#  'dependent',
#  'uncertain',
#  'foreign',
#  'supplier',
#  'ultimate',
#  'humiliation',
#  'militant',
#  'terrorist',
#  'iran',
#  'continue',
#  'toy',
#  'life',
#  'american',
#  'event',
#  'isolated',
#  'unrelated',
#  'signpost',
#  'mark',
#  'continuing',
#  'downward',
#  'spiral',
#  'economic',
#  'vitality',
#  'international',
#  'influence',
#  'trend',
#  'continue',
#  '1980s',
#  'promise',
#  'dangerous',
#  'year',
#  'since',
#  'world',
#  'war',
#  'ii',
#  'history',
#  'could',
#  'record',
#  'let',
#  'drift',
#  'go',
#  'american',
#  'experiment',
#  'marvelously',
#  'successful',
#  '200',
#  'year',
#  'came',
#  'strangely',
#  'needlessly',
#  'tragically',
#  'dismal',
#  'end',
#  'early',
#  'third',
#  'century',
#  'far',
#  'galling',
#  'aspect',
#  'chief',
#  'architect',
#  'decline',
#  'democratic',
#  'politician',
#  'without',
#  'program',
#  'idea',
#  'reverse',
#  'divided',
#  'leaderless',
#  'unseeing',
#  'uncomprehending',
#  'plod',
#  'listless',
#  'offering',
#  'pale',
#  'imitation',
#  'policy',
#  'pursued',
#  'long',
#  'knowing',
#  'full',
#  'well',
#  'futility',
#  'carter',
#  'administration',
#  'unhappy',
#  'inevitable',
#  'consequence',
#  'decade',
#  'increasingly',
#  'outmoded',
#  'democratic',
#  'domination',
#  'national',
#  'life',
#  'past',
#  'four',
#  'year',
#  'repeatedly',
#  'demonstrated',
#  'basic',
#  'goal',
#  'perpetuation',
#  'rule',
#  'guiding',
#  'principle',
#  'fleeting',
#  'insight',
#  'provided',
#  'latest',
#  'opinion',
#  'poll',
#  'policy',
#  'announced',
#  'one',
#  'day',
#  'disavowed',
#  'ignored',
#  'next',
#  'sowing',
#  'confusion',
#  'among',
#  'american',
#  'home',
#  'havoc',
#  'among',
#  'friend',
#  'abroad',
#  'republican',
#  'democrat',
#  'independent',
#  'watching',
#  'reading',
#  'sign',
#  'watching',
#  'incredulously',
#  'disaster',
#  'disaster',
#  'unfolds',
#  'enough',
#  'rising',
#  '1980',
#  'say',
#  'confusion',
#  'must',
#  'end',
#  'drift',
#  'must',
#  'end',
#  'must',
#  'pull',
#  'together',
#  'people',
#  'slide',
#  'irretrievably',
#  'abyss',
#  'way',
#  'stay',
#  'way',
#  'republican',
#  'party',
#  'hold',
#  'forth',
#  'party',
#  'best',
#  'able',
#  'arrest',
#  'reverse',
#  'decline',
#  'offer',
#  'new',
#  'idea',
#  'candidate',
#  'top',
#  'ticket',
#  'bottom',
#  'bring',
#  'local',
#  'national',
#  'leadership',
#  'firm',
#  'steady',
#  'hand',
#  'confidence',
#  'eagerness',
#  'unparalleled',
#  'unity',
#  'within',
#  'rank',
#  'especially',
#  'presidential',
#  'nominee',
#  'congressional',
#  'membership',
#  'important',
#  'go',
#  'forth',
#  'people',
#  'idea',
#  'program',
#  'future',
#  'powerful',
#  'compelling',
#  'fresh',
#  'together',
#  'offer',
#  'new',
#  'beginning',
#  'america',
#  'foremost',
#  'goal',
#  'home',
#  'simple',
#  'economic',
#  'growth',
#  'full',
#  'employment',
#  'without',
#  'inflation',
#  'sweeping',
#  'change',
#  'economic',
#  'policy',
#  'america',
#  'needed',
#  'mr',
#  "carter's",
#  'promise',
#  'hard',
#  'time',
#  'austerity',
#  'one',
#  'promise',
#  'well',
#  'kept',
#  'replaced',
#  'republican',
#  'policy',
#  'promise',
#  'economic',
#  'growth',
#  'job',
#  'creation',
#  'belief',
#  'stagflation',
#  'recent',
#  'year',
#  'consigned',
#  'million',
#  'citizen',
#  'hardship',
#  'also',
#  'bottled',
#  'enormous',
#  'ingenuity',
#  'creative',
#  'power',
#  'people',
#  'energy',
#  'released',
#  'sterile',
#  'policy',
#  'past',
#  'specifically',
#  'reject',
#  'carter',
#  'doctrine',
#  'inflation',
#  'reduced',
#  'throwing',
#  'people',
#  'work',
#  'prosperity',
#  'regained',
#  'simply',
#  'government',
#  'fiat',
#  'rather',
#  'must',
#  'offer',
#  'broad',
#  'new',
#  'incentive',
#  'labor',
#  'capital',
#  'stimulate',
#  'great',
#  'outpouring',
#  'private',
#  'good',
#  'service',
#  'create',
#  'abundance',
#  'job',
#  "america's",
#  'grass',
#  'root',
#  'white',
#  'house',
#  'stand',
#  'united',
#  'party',
#  'behind',
#  'bold',
#  'program',
#  'tax',
#  'rate',
#  'reduction',
#  'spending',
#  'restraint',
#  'regulatory',
#  'reform',
#  'inject',
#  'new',
#  'life',
#  'economic',
#  'bloodstream',
#  'country',
#  'overseas',
#  'goal',
#  'equally',
#  'simple',
#  'direct',
#  'preserve',
#  'world',
#  'peace',
#  'keeping',
#  'america',
#  'strong',
#  'philosophy',
#  'occupied',
#  'hallowed',
#  'place',
#  'american',
#  'diplomacy',
#  'casually',
#  'even',
#  'cavalierly',
#  'dismissed',
#  'outset',
#  'carter',
#  'administration',
#  'result',
#  'shattering',
#  'never',
#  'modern',
#  'history',
#  'united',
#  'state',
#  'endured',
#  'many',
#  'humiliation',
#  'insult',
#  'defeat',
#  'past',
#  'four',
#  'year',
#  'ambassador',
#  'murdered',
#  'embassy',
#  'burned',
#  'warning',
#  'ignored',
#  'diplomacy',
#  'scorned',
#  'diplomat',
#  'kidnapped',
#  'carter',
#  'administration',
#  'shown',
#  'neither',
#  'understands',
#  'totalitarianism',
#  'appreciates',
#  'way',
#  'tyrant',
#  'take',
#  'advantage',
#  'weakness',
#  'brutal',
#  'invasion',
#  'afghanistan',
#  'promise',
#  'forerunner',
#  'much',
#  'serious',
#  'threat',
#  'west',
#  'world',
#  'peace',
#  'carter',
#  'administration',
#  'somehow',
#  'cling',
#  'power',
#  'republican',
#  'united',
#  'belief',
#  "america's",
#  'international',
#  'humiliation',
#  'decline',
#  'reversed',
#  'strong',
#  'presidential',
#  'leadership',
#  'consistent',
#  'far-sighted',
#  'foreign',
#  'policy',
#  'supported',
#  'major',
#  'upgrading',
#  'military',
#  'force',
#  'strengthening',
#  'commitment',
#  'ally',
#  'resolve',
#  'national',
#  'interest',
#  'vigorously',
#  'protected',
#  'ultimately',
#  'practice',
#  'strength',
#  'firmness',
#  'truly',
#  'guard',
#  'peace',
#  'platform',
#  'address',
#  'many',
#  'concern',
#  'party',
#  'seek',
#  'restore',
#  'family',
#  'neighborhood',
#  'community',
#  'workplace',
#  'vital',
#  'alternative',
#  'national',
#  'life',
#  'ever-expanding',
#  'federal',
#  'power',
#  'affirm',
#  'deep',
#  'commitment',
#  'fulfillment',
#  'hope',
#  'aspiration',
#  'american',
#  'black',
#  'white',
#  'woman',
#  'men',
#  'young',
#  'old',
#  'rural',
#  'urban',
#  'many',
#  'year',
#  'political',
#  'debate',
#  'america',
#  'conducted',
#  'term',
#  'set',
#  'democrat',
#  'believe',
#  'every',
#  'time',
#  'new',
#  'problem',
#  'arise',
#  'beyond',
#  'power',
#  'men',
#  'woman',
#  'individual',
#  'solve',
#  'becomes',
#  'duty',
#  'government',
#  'solve',
#  'never',
#  'alternative',
#  'republican',
#  'disagree',
#  'always',
#  'taken',
#  'side',
#  'individual',
#  'whose',
#  'freedom',
#  'threatened',
#  'big',
#  'government',
#  'democratic',
#  'idea',
#  'spawned',
#  'case',
#  'individual',
#  'stronger',
#  'ever',
#  'defense',
#  'individual',
#  'government',
#  'never',
#  'needed',
#  'continue',
#  'mount',
#  'redefine',
#  'broaden',
#  'debate',
#  'transcending',
#  'narrow',
#  'term',
#  'government',
#  'individual',
#  'two',
#  'reality',
#  'america',
#  'society',
#  'consists',
#  'political',
#  'debate',
#  'reemphasize',
#  'vital',
#  'community',
#  'like',
#  'family',
#  'neighborhood',
#  'workplace',
#  'others',
#  'found',
#  'center',
#  'society',
#  'government',
#  'individual',
#  'restore',
#  'strengthen',
#  'ability',
#  'solve',
#  'problem',
#  'place',
#  'people',
#  'spend',
#  'daily',
#  'life',
#  'turn',
#  'support',
#  'help',
#  'seek',
#  'energy',
#  'independence',
#  'economic',
#  'policy',
#  'free',
#  'energy',
#  'production',
#  'encourage',
#  'conservation',
#  'seek',
#  'improvement',
#  'health',
#  'care',
#  'education',
#  'housing',
#  'opportunity',
#  'youth',
#  'seek',
#  'new',
#  'avenue',
#  'needy',
#  'break',
#  'tragic',
#  'cycle',
#  'dependency',
#  'goal',
#  'many',
#  'others',
#  'confidently',
#  'expect',
#  'achieve',
#  'rebirth',
#  'liberty',
#  'resurgence',
#  'private',
#  'initiative',
#  'believe',
#  'root',
#  'trouble',
#  'today',
#  'misguided',
#  'discredited',
#  'philosophy',
#  'all-powerful',
#  'government',
#  'ceaselessly',
#  'striving',
#  'subsidize',
#  'manipulate',
#  'control',
#  'individual',
#  'individual',
#  'government',
#  'reign',
#  'center',
#  'republican',
#  'philosophy',
#  'democrat',
#  'say',
#  'american',
#  'must',
#  'content',
#  'passively',
#  'accept',
#  'gradual',
#  'inexorable',
#  'decline',
#  'america',
#  'answer',
#  'american',
#  'people',
#  'hardly',
#  'begun',
#  'marshal',
#  'talent',
#  'resource',
#  'realize',
#  'accomplishment',
#  'dream',
#  'freedom',
#  'inspire',
#  'democrat',
#  'say',
#  'face',
#  'age',
#  'limit',
#  'ask',
#  'know',
#  'limit',
#  'american',
#  'capacity',
#  'work',
#  'creativity',
#  'optimism',
#  'faith',
#  'enhanced',
#  'supported',
#  'strong',
#  'responsive',
#  'political',
#  'leadership',
#  'ideal',
#  'mr',
#  'carter',
#  'say',
#  'american',
#  'people',
#  'suffer',
#  'national',
#  'malaise',
#  'respond',
#  'malaise',
#  'country',
#  'found',
#  'leadership',
#  'democratic',
#  'party',
#  'white',
#  'house',
#  'congress',
#  'symptom',
#  'incompetence',
#  'lead',
#  'refusal',
#  'change',
#  'reluctance',
#  'act',
#  'malaise',
#  'become',
#  'epidemic',
#  'washington',
#  'cure',
#  'government',
#  'led',
#  'republican',
#  'share',
#  'value',
#  'majority',
#  'american',
#  'republican',
#  'pledge',
#  'restoration',
#  'balance',
#  'american',
#  'society',
#  'society',
#  'cannot',
#  'balanced',
#  'action',
#  'government',
#  'individual',
#  'alone',
#  'balance',
#  'found',
#  "society's",
#  'vital',
#  'center',
#  'find',
#  'family',
#  'neighborhood',
#  'workplace',
#  'america',
#  'however',
#  'achieve',
#  'goal',
#  'present',
#  'course',
#  'present',
#  'leadership',
#  'uncharted',
#  'course',
#  'mr',
#  'carter',
#  'lead',
#  'surely',
#  'catastrophe',
#  'reversing',
#  'economic',
#  'decline',
#  'reversing',
#  'international',
#  'decline',
#  'resurrect',
#  'dream',
#  '1980',
#  'republican',
#  'platform',
#  'call',
#  'american',
#  'people',
#  "god's",
#  'help',
#  'let',
#  'u',
#  'together',
#  'make',
#  'america',
#  'great',
#  'let',
#  'u',
#  'together',
#  'make',
#  'new',
#  'beginning',
#  'long',
#  'fundamental',
#  'conviction',
#  'republican',
#  'party',
#  'government',
#  'foster',
#  'society',
#  'climate',
#  'maximum',
#  'individual',
#  'liberty',
#  'freedom',
#  'choice',
#  'properly',
#  'informed',
#  'people',
#  'individual',
#  'acting',
#  'instrument',
#  'popular',
#  'consultation',
#  'make',
#  'right',
#  'decision',
#  'affecting',
#  'personal',
#  'general',
#  'welfare',
#  'free',
#  'pervasive',
#  'heavy-handed',
#  'intrusion',
#  'central',
#  'government',
#  'decisionmaking',
#  'process',
#  'tenet',
#  'genius',
#  'representative',
#  'democracy',
#  'republican',
#  'also',
#  'treasure',
#  'ethnic',
#  'cultural',
#  'regional',
#  'diversity',
#  'people',
#  'diversity',
#  'foster',
#  'dynamism',
#  'american',
#  'society',
#  'envy',
#  'world',
#  'elsewhere',
#  'platform',
#  'discus',
#  'benefit',
#  'society',
#  'whole',
#  'reduced',
#  'taxation',
#  'particularly',
#  'term',
#  'economic',
#  'growth',
#  'believe',
#  'essential',
#  'cut',
#  'personal',
#  'tax',
#  'rate',
#  'fairness',
#  'individual',
#  'presently',
#  'aggregate',
#  'burden',
#  'taxation',
#  'great',
#  'average',
#  'american',
#  'spends',
#  'substantial',
#  'part',
#  'every',
#  'year',
#  'effect',
#  'working',
#  'government',
#  'substantial',
#  'tax',
#  'rate',
#  'reduction',
#  'needed',
#  'offset',
#  'massive',
#  'tax',
#  'increase',
#  'facing',
#  'working',
#  'men',
#  'woman',
#  'country',
#  'next',
#  'four',
#  'year',
#  'federal',
#  'tax',
#  'projected',
#  'increase',
#  '500',
#  'billion',
#  'due',
#  'carter',
#  "administration's",
#  'policy',
#  'american',
#  'family',
#  'already',
#  'paying',
#  'tax',
#  'higher',
#  'rate',
#  'ever',
#  'history',
#  'result',
#  'carter',
#  'policy',
#  ...]

# %% [markdown]
# ## Debate Cleveland 1980

# %%
html_debate_cleveland_1980 = request.urlopen(url_debate_cleveland_1980).read().decode('utf8')
raw_debate_cleveland_1980 = BeautifulSoup(html_debate_cleveland_1980, 'html.parser')

raw_dem_debate_cleveland_1980 = []
dem_cleveland_1980 = False
raw_rep_debate_cleveland_1980 = []
rep_cleveland_1980 = False

for p in raw_debate_cleveland_1980.select('div.field-docs-content > p'):
    if p.get_text().startswith('THE PRESIDENT'):
        first, _, rest = p.get_text().partition(" ")
        first, _, rest = rest.partition(" ")
        raw_dem_debate_cleveland_1980.append(rest)
        dem_cleveland_1980 = True
        rep_cleveland_1980 = False
    elif p.get_text().startswith('GOVERNOR REAGAN'):
        first, _, rest = p.get_text().partition(" ")
        first, _, rest = rest.partition(" ")
        raw_rep_debate_cleveland_1980.append(rest)
        dem_cleveland_1980 = False
        rep_cleveland_1980 = True
    elif p.get_text().upper().startswith('MR. SMITH') or p.get_text().upper().startswith('MR. STONE') or p.get_text().startswith('MR. ELLIS') or p.get_text().startswith('MR. HILLIARD') or p.get_text().startswith('MS. WALTERS'):
        dem_cleveland_1980 = False
        rep_cleveland_1980 = False
    elif rep_cleveland_1980:
        raw_rep_debate_cleveland_1980.append(p.get_text())
    elif dem_cleveland_1980:
        raw_dem_debate_cleveland_1980.append(p.get_text())
        
raw_rep_debate_cleveland_1980 = ' '.join(raw_rep_debate_cleveland_1980)
tokens_rep_debate_cleveland_1980 = tokenizer.tokenize(raw_rep_debate_cleveland_1980)
tokens_rep_debate_cleveland_1980

raw_dem_debate_cleveland_1980 = ' '.join(raw_dem_debate_cleveland_1980)
tokens_dem_debate_cleveland_1980 = tokenizer.tokenize(raw_dem_debate_cleveland_1980)
tokens_dem_debate_cleveland_1980
# Out:
# ['Yes',
#  '.',
#  'Mr',
#  '.',
#  'Stone',
#  ',',
#  "I've",
#  'had',
#  'to',
#  'make',
#  'thousands',
#  'of',
#  'decisions',
#  'since',
#  "I've",
#  'been',
#  'President',
#  ',',
#  'serving',
#  'in',
#  'the',
#  'Oval',
#  'Office',
#  '.',
#  'And',
#  'with',
#  'each',
#  'one',
#  'of',
#  'those',
#  'decisions',
#  'that',
#  'affect',
#  'the',
#  'future',
#  'of',
#  'my',
#  'country',
#  ',',
#  'I',
#  'have',
#  'learned',
#  'in',
#  'the',
#  'process',
#  '.',
#  'I',
#  'think',
#  "I'm",
#  'a',
#  'much',
#  'wiser',
#  'and',
#  'more',
#  'experienced',
#  'man',
#  'than',
#  'I',
#  'was',
#  'when',
#  'I',
#  'debated',
#  '4',
#  'years',
#  'ago',
#  'against',
#  'President',
#  'Ford',
#  '.',
#  "I've",
#  'also',
#  'learned',
#  'that',
#  'there',
#  'are',
#  'no',
#  'simple',
#  'answers',
#  'to',
#  'complicated',
#  'questions',
#  '.',
#  'H',
#  '.',
#  'L',
#  '.',
#  'Mencken',
#  'said',
#  'that',
#  'for',
#  'every',
#  'problem',
#  "there's",
#  'a',
#  'simple',
#  'answer',
#  '.',
#  'It',
#  'would',
#  'be',
#  'neat',
#  'and',
#  'plausible',
#  '—',
#  'and',
#  'wrong',
#  '.',
#  'The',
#  'fact',
#  'is',
#  'that',
#  'this',
#  'Nation',
#  ',',
#  'in',
#  'the',
#  '8',
#  'years',
#  'before',
#  'I',
#  'became',
#  'President',
#  ',',
#  'had',
#  'its',
#  'own',
#  'military',
#  'strength',
#  'decreased',
#  '.',
#  'Seven',
#  'out',
#  'of',
#  'eight',
#  'years',
#  ',',
#  'the',
#  'budget',
#  'commitments',
#  'for',
#  'defense',
#  'went',
#  'down',
#  ',',
#  '37',
#  'percent',
#  ',',
#  'in',
#  'all',
#  '.',
#  'Since',
#  "I've",
#  'been',
#  'in',
#  'office',
#  ',',
#  "we've",
#  'had',
#  'a',
#  'steady',
#  ',',
#  'carefully',
#  'planned',
#  ',',
#  'methodical',
#  'but',
#  'very',
#  'effective',
#  'increase',
#  'in',
#  'our',
#  'commitment',
#  'for',
#  'defense',
#  '.',
#  'But',
#  'what',
#  "we've",
#  'done',
#  'is',
#  'to',
#  'use',
#  'that',
#  'enormous',
#  'power',
#  'and',
#  'prestige',
#  'and',
#  'military',
#  'strength',
#  'of',
#  'the',
#  'United',
#  'States',
#  'to',
#  'preserve',
#  'the',
#  'peace',
#  '.',
#  "We've",
#  'not',
#  'only',
#  'kept',
#  'peace',
#  'for',
#  'our',
#  'own',
#  'country',
#  ',',
#  'but',
#  "we've",
#  'been',
#  'able',
#  'to',
#  'extend',
#  'the',
#  'benefits',
#  'of',
#  'peace',
#  'to',
#  'others',
#  '.',
#  'In',
#  'the',
#  'Middle',
#  'East',
#  ',',
#  "we've",
#  'worked',
#  'for',
#  'a',
#  'peace',
#  'treaty',
#  'between',
#  'Israel',
#  'and',
#  'Egypt',
#  ',',
#  'successfully',
#  ',',
#  'and',
#  'have',
#  'tied',
#  'ourselves',
#  'together',
#  'with',
#  'Israel',
#  'and',
#  'Egypt',
#  'in',
#  'a',
#  'common',
#  'defense',
#  'capability',
#  '.',
#  'This',
#  'is',
#  'a',
#  'very',
#  'good',
#  'step',
#  'forward',
#  'for',
#  'our',
#  "Nation's",
#  'security',
#  ',',
#  'and',
#  "we'll",
#  'continue',
#  'to',
#  'do',
#  'as',
#  "we've",
#  'done',
#  'in',
#  'the',
#  'past',
#  '.',
#  'I',
#  'might',
#  'also',
#  'add',
#  'that',
#  'there',
#  'are',
#  'decisions',
#  'that',
#  'are',
#  'made',
#  'in',
#  'the',
#  'Oval',
#  'Office',
#  'by',
#  'every',
#  'President',
#  'which',
#  'are',
#  'profound',
#  'in',
#  'nature',
#  '.',
#  'There',
#  'are',
#  'always',
#  'troublespots',
#  'in',
#  'the',
#  'world',
#  ',',
#  'and',
#  'how',
#  'those',
#  'troubled',
#  'areas',
#  'are',
#  'addressed',
#  'by',
#  'a',
#  'President',
#  ',',
#  'alone',
#  'in',
#  'that',
#  'Oval',
#  'Office',
#  ',',
#  'affects',
#  'our',
#  'Nation',
#  'directly',
#  ',',
#  'the',
#  'involvement',
#  'of',
#  'the',
#  'United',
#  'States',
#  'and',
#  'also',
#  'our',
#  'American',
#  'interests',
#  '.',
#  'That',
#  'is',
#  'a',
#  'basic',
#  'decision',
#  'that',
#  'has',
#  'to',
#  'be',
#  'made',
#  'so',
#  'frequently',
#  'by',
#  'every',
#  'President',
#  'who',
#  'serves',
#  '.',
#  "That's",
#  'what',
#  "I've",
#  'tried',
#  'to',
#  'do',
#  ',',
#  'successfully',
#  ',',
#  'by',
#  'keeping',
#  'our',
#  'country',
#  'at',
#  'peace',
#  '.',
#  'Mr',
#  '.',
#  'Stone',
#  ',',
#  'in',
#  'my',
#  'State',
#  'of',
#  'the',
#  'Union',
#  'address',
#  'earlier',
#  'this',
#  'year',
#  ',',
#  'I',
#  'pointed',
#  'out',
#  'that',
#  'any',
#  'threat',
#  'to',
#  'the',
#  'stability',
#  'or',
#  'security',
#  'of',
#  'the',
#  'Persian',
#  'Gulf',
#  'would',
#  'be',
#  'a',
#  'threat',
#  'to',
#  'the',
#  'security',
#  'of',
#  'our',
#  'own',
#  'country',
#  '.',
#  'In',
#  'the',
#  'past',
#  ',',
#  "we've",
#  'not',
#  'had',
#  'an',
#  'adequate',
#  'military',
#  'presence',
#  'in',
#  'that',
#  'region',
#  '.',
#  'Now',
#  'we',
#  'have',
#  'two',
#  'major',
#  'carrier',
#  'task',
#  'forces',
#  '.',
#  'We',
#  'have',
#  'access',
#  'to',
#  'facilities',
#  'in',
#  'five',
#  'different',
#  'areas',
#  'of',
#  'that',
#  'region',
#  '.',
#  'And',
#  "we've",
#  'made',
#  'it',
#  'clear',
#  'that',
#  'working',
#  'with',
#  'our',
#  'allies',
#  'and',
#  'others',
#  ',',
#  'that',
#  'we',
#  'are',
#  'prepared',
#  'to',
#  'address',
#  'any',
#  'foreseeable',
#  'eventuality',
#  'which',
#  'might',
#  'interrupt',
#  'commerce',
#  'with',
#  'that',
#  'crucial',
#  'area',
#  'of',
#  'the',
#  'world',
#  '.',
#  'But',
#  'in',
#  'doing',
#  'this',
#  ',',
#  'we',
#  'have',
#  'made',
#  'sure',
#  'that',
#  'we',
#  'address',
#  'this',
#  'question',
#  'peacefully',
#  ',',
#  'not',
#  'injecting',
#  'American',
#  'military',
#  'forces',
#  'into',
#  'combat',
#  ',',
#  'but',
#  'letting',
#  'the',
#  'strength',
#  'of',
#  'our',
#  'Nation',
#  'be',
#  'felt',
#  'in',
#  'a',
#  'beneficial',
#  'way',
#  '.',
#  'This',
#  ',',
#  'I',
#  'believe',
#  ',',
#  'has',
#  'assured',
#  'that',
#  'our',
#  'interests',
#  'will',
#  'be',
#  'protected',
#  'in',
#  'the',
#  'Persian',
#  'Gulf',
#  'region',
#  ',',
#  'as',
#  "we've",
#  'done',
#  'in',
#  'the',
#  'Middle',
#  'East',
#  'and',
#  'throughout',
#  'the',
#  'world',
#  '.',
#  'Well',
#  ',',
#  'there',
#  'are',
#  'various',
#  'elements',
#  'of',
#  'defense',
#  '.',
#  'One',
#  'is',
#  'to',
#  'control',
#  'nuclear',
#  'weapons',
#  ',',
#  'which',
#  'I',
#  'hope',
#  "we'll",
#  'get',
#  'to',
#  'later',
#  'on',
#  ',',
#  'because',
#  "that's",
#  'the',
#  'most',
#  'important',
#  'single',
#  'issue',
#  'in',
#  'this',
#  'campaign',
#  '.',
#  'Another',
#  'one',
#  'is',
#  'how',
#  'to',
#  'address',
#  'troubled',
#  'areas',
#  'of',
#  'the',
#  'world',
#  '.',
#  'I',
#  'think',
#  ',',
#  'habitually',
#  ',',
#  'Governor',
#  'Reagan',
#  'has',
#  'advocated',
#  'the',
#  'injection',
#  'of',
#  'military',
#  'forces',
#  'into',
#  'troubled',
#  'areas',
#  ',',
#  'when',
#  'I',
#  'and',
#  'my',
#  'predecessors',
#  'both',
#  'Democrats',
#  'and',
#  'Republicans',
#  '—',
#  'have',
#  'advocated',
#  'resolving',
#  'those',
#  'troubles',
#  'and',
#  'those',
#  'difficult',
#  'areas',
#  'of',
#  'the',
#  'world',
#  'peacefully',
#  ',',
#  'diplomatically',
#  ',',
#  'and',
#  'through',
#  'negotiation',
#  '.',
#  'In',
#  'addition',
#  'to',
#  'that',
#  ',',
#  'the',
#  'buildup',
#  'of',
#  'military',
#  'forces',
#  'is',
#  'good',
#  'for',
#  'our',
#  'country',
#  ',',
#  'because',
#  "we've",
#  'got',
#  'to',
#  'have',
#  'military',
#  'strength',
#  'in',
#  'order',
#  'to',
#  'preserve',
#  'the',
#  'peace',
#  '.',
#  'But',
#  "I'll",
#  'always',
#  'remember',
#  'that',
#  'the',
#  'best',
#  'weapons',
#  'are',
#  'the',
#  'ones',
#  'that',
#  'are',
#  'never',
#  'fired',
#  'in',
#  'combat',
#  ',',
#  'and',
#  'the',
#  'best',
#  'soldier',
#  'is',
#  'one',
#  'who',
#  'never',
#  'has',
#  'to',
#  'lay',
#  'his',
#  'life',
#  'down',
#  'on',
#  'the',
#  'field',
#  'of',
#  'battle',
#  '.',
#  'Strength',
#  'is',
#  'imperative',
#  'for',
#  'peace',
#  ',',
#  'but',
#  'the',
#  'two',
#  'must',
#  'go',
#  'hand',
#  'in',
#  'hand',
#  '.',
#  'Again',
#  "it's",
#  'important',
#  'to',
#  'put',
#  'the',
#  'situation',
#  'into',
#  'perspective',
#  '.',
#  'In',
#  '1974',
#  'we',
#  'had',
#  'a',
#  'so-called',
#  'oil',
#  'shock',
#  ',',
#  'wherein',
#  'the',
#  'price',
#  'of',
#  'OPEC',
#  'oil',
#  'was',
#  'raised',
#  'to',
#  'an',
#  'extraordinary',
#  'degree',
#  '.',
#  'We',
#  'had',
#  'an',
#  'even',
#  'worse',
#  'oil',
#  'shock',
#  'in',
#  '1979',
#  '.',
#  'In',
#  '1974',
#  'we',
#  'had',
#  'the',
#  'worst',
#  'recession',
#  ',',
#  'the',
#  'deepest',
#  'and',
#  'most',
#  'penetrating',
#  'recession',
#  'since',
#  'the',
#  'Second',
#  'World',
#  'War',
#  '.',
#  'The',
#  'recession',
#  'that',
#  'resulted',
#  'this',
#  'time',
#  'was',
#  'the',
#  'briefest',
#  "we've",
#  'had',
#  'since',
#  'the',
#  'Second',
#  'World',
#  'War',
#  '.',
#  'In',
#  'addition',
#  ',',
#  "we've",
#  'brought',
#  'down',
#  'inflation',
#  '.',
#  'Earlier',
#  'this',
#  'year',
#  ',',
#  'the',
#  'first',
#  'quarter',
#  ',',
#  'we',
#  'did',
#  'have',
#  'a',
#  'very',
#  'severe',
#  'inflation',
#  'pressure',
#  ',',
#  'brought',
#  'about',
#  'by',
#  'the',
#  'OPEC',
#  'price',
#  'increase',
#  '.',
#  'It',
#  'averaged',
#  'about',
#  '18',
#  'percent',
#  'the',
#  'first',
#  'quarter',
#  'of',
#  'this',
#  'year',
#  '.',
#  'The',
#  'second',
#  'quarter',
#  ',',
#  'we',
#  'had',
#  'dropped',
#  'it',
#  'down',
#  'to',
#  'about',
#  '13',
#  'percent',
#  '.',
#  'The',
#  'most',
#  'recent',
#  'figures',
#  ',',
#  'the',
#  'last',
#  '3',
#  'months',
#  ',',
#  'or',
#  'the',
#  'third',
#  'quarter',
#  'of',
#  'this',
#  'year',
#  ',',
#  'the',
#  'inflation',
#  'rate',
#  'is',
#  '7',
#  'percent',
#  '—',
#  'still',
#  'too',
#  'high',
#  ',',
#  'but',
#  'it',
#  'illustrates',
#  'very',
#  'vividly',
#  'that',
#  'in',
#  'addition',
#  'to',
#  'providing',
#  'an',
#  'enormous',
#  'number',
#  'of',
#  'jobs',
#  '—',
#  '9',
#  'million',
#  'new',
#  'jobs',
#  'in',
#  'the',
#  'last',
#  '3',
#  '1/2',
#  'years',
#  '—',
#  'that',
#  'the',
#  'inflationary',
#  'threat',
#  'is',
#  'still',
#  'urgent',
#  'on',
#  'us',
#  '.',
#  'I',
#  'noticed',
#  'that',
#  'Governor',
#  'Reagan',
#  'recently',
#  'mentioned',
#  'the',
#  'Reagan-Kemp-Roth',
#  'proposal',
#  ',',
#  'which',
#  'his',
#  'own',
#  'running',
#  'mate',
#  ',',
#  'George',
#  'Bush',
#  ',',
#  'described',
#  'as',
#  'voodoo',
#  'economics',
#  ',',
#  'and',
#  'said',
#  'that',
#  'it',
#  'would',
#  'result',
#  'in',
#  'a',
#  '30',
#  '-',
#  'percent',
#  'inflation',
#  'rate',
#  '.',
#  'And',
#  'Business',
#  'Week',
#  ',',
#  'which',
#  'is',
#  'not',
#  'a',
#  'Democratic',
#  'publication',
#  ',',
#  'said',
#  'that',
#  'this',
#  'Reagan-Kemp-Roth',
#  'proposal',
#  '—',
#  ...]

# %% [markdown]
# ## Debate Baltimore 1980

# %%
html_debate_baltimore_1980 = request.urlopen(url_debate_baltimore_1980).read().decode('utf8')
raw_debate_baltimore_1980 = BeautifulSoup(html_debate_baltimore_1980, 'html.parser')

raw_dem_debate_baltimore_1980 = []
dem_baltimore_1980 = False
raw_rep_debate_baltimore_1980 = []
rep_baltimore_1980 = False

for p in raw_debate_baltimore_1980.select('div.field-docs-content > p'):
    if p.get_text().startswith('REP. JOHN B. ANDERSON') or p.get_text().startswith('ANDERSON'):
        first, _, rest = p.get_text().partition(" ")
        raw_dem_debate_baltimore_1980.append(rest)
        dem_baltimore_1980 = True
        rep_baltimore_1980 = False
    elif p.get_text().startswith('GOV. RONALD REAGAN') or p.get_text().startswith('REAGAN'):
        first, _, rest = p.get_text().partition(" ")
        raw_rep_debate_baltimore_1980.append(rest)
        dem_baltimore_1980 = False
        rep_baltimore_1980 = True
    elif p.get_text().upper().startswith('MOYERS') or p.get_text().upper().startswith('LOOMIS') or p.get_text().startswith('GREENBERG') or p.get_text().startswith('CHARLES CORDDRY') or p.get_text().startswith('CORDDRY') or p.get_text().startswith('LEE MAY') or p.get_text().startswith('MAY') or p.get_text().startswith('JANE BRYANT QUINN') or p.get_text().startswith('QUINN') or p.get_text().startswith('GOLDEN'):
        dem_baltimore_1980 = False
        rep_baltimore_1980 = False
    elif rep_baltimore_1980:
        raw_rep_debate_baltimore_1980.append(p.get_text())
    elif dem_baltimore_1980:
        raw_dem_debate_baltimore_1980.append(p.get_text())
        
raw_rep_debate_baltimore_1980 = ' '.join(raw_rep_debate_baltimore_1980)
tokens_rep_debate_baltimore_1980 = tokenizer.tokenize(raw_rep_debate_baltimore_1980)
tokens_rep_debate_baltimore_1980

raw_dem_debate_baltimore_1980 = ' '.join(raw_dem_debate_baltimore_1980)
tokens_dem_debate_baltimore_1980 = tokenizer.tokenize(raw_dem_debate_baltimore_1980)
tokens_dem_debate_baltimore_1980
# Out:
# ['JOHN',
#  'B',
#  '.',
#  'ANDERSON',
#  ':',
#  'Miss',
#  'Loomis',
#  ',',
#  'I',
#  'think',
#  "it's",
#  'very',
#  'appropriate',
#  'that',
#  'the',
#  'first',
#  'question',
#  'in',
#  'this',
#  'first',
#  'debate',
#  'of',
#  'Campaign',
#  "'",
#  '80',
#  'should',
#  'relate',
#  'to',
#  'the',
#  'economy',
#  'of',
#  'the',
#  'country',
#  ',',
#  'because',
#  'it',
#  'seems',
#  'to',
#  'me',
#  'that',
#  'the',
#  'people',
#  'who',
#  'are',
#  'watching',
#  'us',
#  'tonight',
#  '-',
#  '221',
#  'million',
#  'Americans',
#  '-',
#  'are',
#  'truly',
#  'concerned',
#  'about',
#  'the',
#  'poor',
#  'rate',
#  'of',
#  'performance',
#  'of',
#  'the',
#  'American',
#  'economy',
#  'over',
#  'the',
#  'last',
#  'four',
#  'years',
#  '.',
#  'Governor',
#  'Reagan',
#  'is',
#  'not',
#  'responsible',
#  'for',
#  'what',
#  'has',
#  'happened',
#  'over',
#  'the',
#  'last',
#  'four',
#  'years',
#  ',',
#  'nor',
#  'am',
#  'I',
#  '.',
#  'The',
#  'man',
#  'who',
#  'should',
#  'be',
#  'here',
#  'tonight',
#  'to',
#  'respond',
#  'to',
#  'those',
#  'charges',
#  'chose',
#  'not',
#  'to',
#  'attend',
#  '.',
#  'But',
#  'I',
#  'want',
#  'to',
#  'answer',
#  'as',
#  'specifically',
#  'as',
#  'I',
#  'can',
#  'the',
#  'question',
#  'that',
#  'you',
#  'have',
#  'just',
#  'put',
#  'to',
#  'me',
#  '.',
#  'Let',
#  'me',
#  'tell',
#  'you',
#  'that',
#  'I',
#  ',',
#  'first',
#  'of',
#  'all',
#  ',',
#  'oppose',
#  'an',
#  'election',
#  'year',
#  'tax',
#  'cut',
#  ',',
#  'whether',
#  'it',
#  'is',
#  'the',
#  '10',
#  '%',
#  'across-the-board',
#  'tax',
#  'cut',
#  'promised',
#  'to',
#  'the',
#  'taxpayers',
#  'by',
#  'my',
#  'opponent',
#  'in',
#  'this',
#  'debate',
#  'tonight',
#  ',',
#  'or',
#  'whether',
#  'it',
#  'is',
#  'the',
#  '$',
#  '27.5',
#  'billion',
#  'tax',
#  'cut',
#  'promised',
#  'on',
#  'the',
#  '20th',
#  'of',
#  'August',
#  'by',
#  'President',
#  'Carter',
#  '.',
#  'I',
#  'simply',
#  'think',
#  'that',
#  'when',
#  'we',
#  'are',
#  'confronting',
#  'a',
#  'budget',
#  'deficit',
#  'this',
#  'year',
#  '-',
#  'and',
#  'this',
#  'fiscal',
#  'year',
#  'will',
#  'end',
#  'in',
#  'about',
#  '10',
#  'days',
#  ',',
#  'and',
#  'we',
#  'are',
#  'confronted',
#  'with',
#  'the',
#  'possibility',
#  'of',
#  'a',
#  'deficit',
#  'of',
#  '$',
#  '60',
#  'billion',
#  ',',
#  'perhaps',
#  'as',
#  'much',
#  'as',
#  '$',
#  '63',
#  'billion',
#  '-',
#  'that',
#  'that',
#  'simply',
#  'would',
#  'be',
#  'irresponsible',
#  '.',
#  'That',
#  ',',
#  'once',
#  'again',
#  ',',
#  'the',
#  'printing',
#  'presses',
#  'will',
#  'start',
#  'to',
#  'roll',
#  ';',
#  'once',
#  'again',
#  'we',
#  'will',
#  'see',
#  'the',
#  'monetization',
#  'of',
#  'that',
#  'debt',
#  'result',
#  'in',
#  'a',
#  'higher',
#  'rate',
#  'of',
#  'inflation',
#  '.',
#  'Even',
#  'though',
#  "we've",
#  'seen',
#  'some',
#  'hopeful',
#  'signs',
#  ',',
#  'perhaps',
#  ',',
#  'in',
#  'the',
#  'flash',
#  'report',
#  'on',
#  'the',
#  'third',
#  'quarter',
#  ',',
#  'that',
#  'perhaps',
#  'the',
#  'economy',
#  'is',
#  'coming',
#  'out',
#  'of',
#  'the',
#  'recession',
#  ',',
#  "we've",
#  'also',
#  'seen',
#  'the',
#  'rise',
#  'in',
#  'the',
#  'rate',
#  'of',
#  'the',
#  'prime',
#  ';',
#  'we',
#  'have',
#  'seen',
#  'mortgage',
#  'rates',
#  'back',
#  'up',
#  'again',
#  ',',
#  'a',
#  'sure',
#  'sign',
#  'of',
#  'inflation',
#  'in',
#  'the',
#  'housing',
#  'industry',
#  '.',
#  'What',
#  'I',
#  'would',
#  'propose',
#  ',',
#  'and',
#  'I',
#  'proposed',
#  'it',
#  'way',
#  'back',
#  'in',
#  'March',
#  'when',
#  'I',
#  'was',
#  'a',
#  'candidate',
#  'in',
#  'my',
#  'own',
#  'state',
#  'of',
#  'Illinois',
#  ',',
#  'I',
#  'proposed',
#  '$',
#  '11.3',
#  'billion',
#  ',',
#  'specifically',
#  ',',
#  'in',
#  'cuts',
#  'in',
#  'the',
#  'Federal',
#  'budget',
#  '.',
#  'I',
#  'think',
#  "we've",
#  'got',
#  'to',
#  'have',
#  'fiscal',
#  'restraint',
#  '.',
#  'And',
#  'I',
#  'said',
#  'at',
#  'that',
#  'time',
#  'that',
#  'one',
#  'of',
#  'the',
#  'things',
#  'that',
#  'we',
#  'could',
#  'do',
#  ',',
#  'that',
#  'perhaps',
#  'would',
#  'save',
#  'as',
#  'much',
#  'as',
#  '$',
#  '5',
#  'billion',
#  'to',
#  '$',
#  '7',
#  'billion',
#  ',',
#  'according',
#  ',',
#  'to',
#  'one',
#  'of',
#  'the',
#  'leading',
#  'members',
#  'of',
#  'the',
#  'House',
#  'Budget',
#  'Committee',
#  ',',
#  'was',
#  'to',
#  'recalculate',
#  'the',
#  'index',
#  'that',
#  'is',
#  'used',
#  'to',
#  'determine',
#  'the',
#  'cost',
#  'of',
#  'living',
#  'benefits',
#  'that',
#  'are',
#  'paid',
#  'to',
#  'civil',
#  'service',
#  'retirees',
#  ',',
#  'to',
#  'military',
#  'retirees',
#  '.',
#  'That',
#  'we',
#  'ought',
#  'to',
#  '...',
#  'in',
#  'addition',
#  'to',
#  'that',
#  ',',
#  'we',
#  'ought',
#  'to',
#  'pay',
#  'those',
#  'retirement',
#  'benefits',
#  'on',
#  'the',
#  'basis',
#  'of',
#  'once',
#  'a',
#  'year',
#  ',',
#  'rather',
#  'than',
#  'twice',
#  'a',
#  'year',
#  ',',
#  'and',
#  'save',
#  '$',
#  '750',
#  'billion',
#  '.',
#  'In',
#  'other',
#  'words',
#  '...',
#  'fiscal',
#  'restraint',
#  ',',
#  'I',
#  'think',
#  'is',
#  'necessary',
#  '.',
#  'Mr',
#  '.',
#  'Movers',
#  ',',
#  'in',
#  'addition',
#  'to',
#  'saying',
#  'that',
#  'this',
#  'is',
#  'no',
#  'time',
#  'for',
#  'a',
#  'tax',
#  'cut',
#  ',',
#  'in',
#  'view',
#  'of',
#  'the',
#  'incipient',
#  'signs',
#  'of',
#  'renewed',
#  'inflation',
#  ',',
#  'in',
#  'addition',
#  'to',
#  'calling',
#  'for',
#  'restraint',
#  'in',
#  'Federal',
#  'spending',
#  ',',
#  '15',
#  'months',
#  'ago',
#  ',',
#  'I',
#  'also',
#  'suggested',
#  'we',
#  'ought',
#  'to',
#  'have',
#  'an',
#  'emergency',
#  'excise',
#  'tax',
#  'on',
#  'gasoline',
#  '.',
#  'I',
#  'say',
#  'that',
#  'because',
#  'I',
#  'think',
#  ',',
#  'this',
#  'year',
#  ',',
#  'we',
#  'will',
#  'send',
#  '$',
#  '90',
#  'billion',
#  'out',
#  'of',
#  'this',
#  'country',
#  'to',
#  'pay',
#  'for',
#  'imported',
#  'oil',
#  ',',
#  'even',
#  'though',
#  'that',
#  '.',
#  'those',
#  'imports',
#  'have',
#  'been',
#  'reduced',
#  '.',
#  'And',
#  'since',
#  'I',
#  'first',
#  'made',
#  'that',
#  'proposal',
#  '15',
#  'months',
#  'ago',
#  ',',
#  'the',
#  'price',
#  'of',
#  'gasoline',
#  ',',
#  'which',
#  'was',
#  'then',
#  '$',
#  '.',
#  '80',
#  ',',
#  'has',
#  'gone',
#  'up',
#  'to',
#  'about',
#  '$',
#  '1.30',
#  '.',
#  'In',
#  'other',
#  'words',
#  ',',
#  "we've",
#  'had',
#  'a',
#  'huge',
#  'increase',
#  'of',
#  'about',
#  '$',
#  '.',
#  '50',
#  'a',
#  'gallon',
#  'since',
#  'that',
#  'time',
#  ',',
#  'and',
#  'all',
#  'of',
#  'that',
#  'increase',
#  'has',
#  'gone',
#  'out',
#  'of',
#  'this',
#  'country',
#  '-',
#  'or',
#  'much',
#  'of',
#  'it',
#  '-',
#  'into',
#  'the',
#  'pockets',
#  'of',
#  'OPEC',
#  'oil',
#  'producers',
#  '.',
#  'Whereas',
#  'I',
#  'have',
#  'proposed',
#  'we',
#  'ought',
#  'to',
#  'take',
#  '.',
#  'put',
#  'that',
#  'tax',
#  'on',
#  'here',
#  'at',
#  'home',
#  ',',
#  'reduce',
#  'our',
#  'consumption',
#  'of',
#  'that',
#  'imported',
#  'oil',
#  '.',
#  'Recycle',
#  'those',
#  'proceeds',
#  ',',
#  'then',
#  ',',
#  'back',
#  'into',
#  'the',
#  'pockets',
#  'of',
#  'the',
#  'American',
#  'workers',
#  'by',
#  'reducing',
#  'their',
#  'tax',
#  'payments',
#  '.',
#  'their',
#  'Social',
#  'Security',
#  'tax',
#  'payments',
#  'by',
#  '50',
#  '%',
#  '.',
#  'That',
#  ',',
#  'I',
#  'think',
#  ',',
#  'in',
#  'addition',
#  ',',
#  'would',
#  'be',
#  'an',
#  'anti-inflationary',
#  'measure',
#  'that',
#  'would',
#  'strengthen',
#  'the',
#  'economy',
#  'of',
#  'this',
#  'country',
#  '.',
#  'Well',
#  ',',
#  'Mr',
#  '.',
#  'Greenberg',
#  ',',
#  'I',
#  'simply',
#  'cannot',
#  'allow',
#  'to',
#  'go',
#  'unpassed',
#  'the',
#  'statements',
#  'that',
#  'have',
#  'just',
#  'been',
#  'made',
#  'by',
#  'Mr',
#  '.',
#  'Reagan',
#  ',',
#  'who',
#  'once',
#  'again',
#  ',',
#  'has',
#  'demonstrated',
#  ',',
#  'I',
#  'think',
#  ',',
#  'a',
#  'total',
#  'misunderstanding',
#  'of',
#  'the',
#  'energy',
#  'crisis',
#  'that',
#  'confronts',
#  ',',
#  'not',
#  'only',
#  'this',
#  'country',
#  ',',
#  'but',
#  'the',
#  'world',
#  ',',
#  'when',
#  'he',
#  'suggests',
#  'that',
#  'we',
#  'have',
#  '27',
#  'years',
#  "'",
#  'supply',
#  'of',
#  'natural',
#  'gas',
#  ',',
#  '47',
#  'years',
#  "'",
#  'supply',
#  'of',
#  'oil',
#  ',',
#  'and',
#  'all',
#  'the',
#  'rest',
#  ',',
#  'and',
#  'that',
#  'we',
#  'really',
#  '.',
#  'all',
#  'we',
#  'have',
#  'to',
#  'do',
#  'is',
#  'to',
#  'get',
#  'the',
#  'Government',
#  'off',
#  'the',
#  'back',
#  'of',
#  'the',
#  'oil',
#  'industry',
#  ',',
#  'and',
#  "that's",
#  'going',
#  'to',
#  'be',
#  'enough',
#  '.',
#  'I',
#  'agree',
#  'with',
#  'what',
#  'I',
#  'think',
#  'is',
#  'the',
#  'major',
#  'premise',
#  'of',
#  'your',
#  'question',
#  ',',
#  'sir',
#  ',',
#  'that',
#  'we',
#  'are',
#  'going',
#  'to',
#  'have',
#  'to',
#  'create',
#  'a',
#  'new',
#  'conservation',
#  'ethic',
#  'in',
#  'the',
#  'minds',
#  'of',
#  'the',
#  'American',
#  'people',
#  '.',
#  'and',
#  "that's",
#  'simply',
#  'why',
#  'I',
#  'proposed',
#  ',',
#  '15',
#  'months',
#  'ago',
#  ',',
#  'the',
#  'emergency',
#  'excise',
#  'tax',
#  'on',
#  'gasoline',
#  'that',
#  'I',
#  'did',
#  '.',
#  'I',
#  'did',
#  'it',
#  'as',
#  'a',
#  'security',
#  'measure',
#  'to',
#  'be',
#  'sure',
#  ',',
#  'because',
#  'I',
#  'would',
#  'rather',
#  'see',
#  'us',
#  'reduce',
#  'the',
#  'consumption',
#  'of',
#  'imported',
#  'oil',
#  'than',
#  'have',
#  'to',
#  'send',
#  'American',
#  'boys',
#  'to',
#  'fight',
#  'in',
#  'the',
#  'Persian',
#  'Gulf',
#  '.',
#  'But',
#  'at',
#  'the',
#  'same',
#  'time',
#  ',',
#  'I',
#  'think',
#  "it's",
#  'going',
#  'to',
#  'take',
#  'a',
#  'dramatic',
#  'measure',
#  'of',
#  'that',
#  'kind',
#  'to',
#  'convince',
#  'the',
#  'American',
#  'people',
#  'that',
#  'we',
#  'will',
#  'have',
#  'to',
#  'reduce',
#  'the',
#  'use',
#  'of',
#  'the',
#  'private',
#  'automobile',
#  '.',
#  'We',
#  'simply',
#  'cannot',
#  'have',
#  'people',
#  'sitting',
#  'one',
#  'behind',
#  'the',
#  'wheel',
#  'of',
#  'a',
#  'car',
#  'in',
#  ...]

# %% [markdown]
# ## Debates 1980 combined

# %%
tokens_dem_debate_1980 = tokens_dem_debate_cleveland_1980 + tokens_dem_debate_baltimore_1980
tokens_rep_debate_1980 = tokens_rep_debate_cleveland_1980 + tokens_rep_debate_baltimore_1980

tokens_dem_debate_1980 = [char.lower() for char in tokens_dem_debate_1980]
tokens_dem_debate_1980 = [char for char in tokens_dem_debate_1980 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_dem_debate_1980
lemmatized_tokens_dem_debate_1980 = [lemmatizer.lemmatize(word) for word in tokens_dem_debate_1980]
lemmatized_tokens_dem_debate_1980

tokens_rep_debate_1980 = [char.lower() for char in tokens_rep_debate_1980]
tokens_rep_debate_1980 = [char for char in tokens_rep_debate_1980 if char not in string.punctuation and char not in en_stop and char != "—"]
tokens_rep_debate_1980
lemmatized_tokens_rep_debate_1980 = [lemmatizer.lemmatize(word) for word in tokens_rep_debate_2016]
lemmatized_tokens_rep_debate_1980

text_rep_debate_1980 = nltk.Text(tokens_rep_debate_1980)
text_dem_debate_1980 = nltk.Text(tokens_dem_debate_1980)
